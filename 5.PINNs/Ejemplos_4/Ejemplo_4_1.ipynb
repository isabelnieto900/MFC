# %%
import torch
import torch.autograd as autograd         # computation graph
from torch import Tensor                  # tensor node in the computation graph
import torch.nn as nn                     # neural networks
import torch.optim as optim               # optimizers e.g. gradient descent, ADAM, etc.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import imageio
import imageio.v2 as imageio
from google.colab import drive
from google.colab import files
drive.mount('/content/drive')
import os
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Parameters and Basic settings

# %%
E_real = 10.
nu_real = 0.3
G_real = E_real/(2*(1+nu_real))
nu_init = 0.2
E_init = 4.
Force = 1.

Train_with_ADAM = False
Train_with_LBFGS = True

seed_id = 1234

################################################ COMPLETAR
ADAM_steps =
lr =
nneurons =
nhiden_layers =
w_loss_f =
w_loss_bc =
w_loss_d =
Nf_x =  # Number of collocation points in x direction
Nf_y =  # Number of collocation points in y direction
N_bc =  # Number of boundary points
###########################################################

print('E_real is: ', E_real)
print("Our guess of E is :", E_init)


# Set default dtype to float32
torch.set_default_dtype(torch.float)
# PyTorch random number generator
torch.manual_seed(seed_id)
# Random number generators in other libraries
np.random.seed(seed_id)
# Out:
# E_real is:  10.0
# Our guess of E is : 4.0

# %% [markdown]
# ## Normalization

# %%
def normalize(X_tensor, X_min, X_max):
    """
    Normalize a tensor by columns given a max and min of each column.

    Parameters:
    X_tensor(numpy array): Tensor to be normalized.
    """
    # Normalize input vector X by each feature
    (num_row_X, num_col_X) = X_tensor.shape
    normalized_X_tensor = torch.zeros_like(X_tensor)

    # Fill the copy vector
    for col in range(num_col_X):
        min_X_col = X_min[col]
        max_X_col = X_max[col]
        normalized_X_tensor[:,col] = (X_tensor[:,col]-min_X_col)*2/(max_X_col-min_X_col) -1

    return normalized_X_tensor

def unnormalize(X_tensor, X_min, X_max):
    """
    Unnormalize a tensor by columns given a max and min of each column.

    Parameters:
    X_tensor(numpy array): Tensor to be unnormalized.
    X_max(numpy array): Max of each column of the tensor to be unnormalized.
    X_min(numpy array): Min of each column of the tensor to be unnormalized.
    """
    # Unnormalize input vector X by each feature
    (num_row_X, num_col_X) = X_tensor.shape
    unnormalized_X_tensor = torch.zeros_like(X_tensor)

    # Fill the copy vector
    for col in range(num_col_X):
        unnormalized_X_tensor[:,col] = (X_tensor[:,col]+1)*(X_max[col]-X_min[col])/2 + X_min[col]

    return unnormalized_X_tensor

# %% [markdown]
# ## Loading data

# %%
displacement_data_path = relative_csv_path =  "/content/drive/MyDrive/Taller PINNs/Calse_4/Displacement.csv"                 # path to displacement data
ititialPosition_data_path = "/content/drive/MyDrive/Taller PINNs/Calse_4/InitialPosition.csv"                # path to initial position data
displacement_header= ['Node','u','v','w']                               # header of displacement data
initialPosition_header = ['Node','x','y','z']                           # header of initial position data

displacement_df = pd.read_csv(displacement_data_path,header=None)       # Reading data
displacement_df.columns = displacement_header                           # Assigning column names
initialPosition_df = pd.read_csv(ititialPosition_data_path,header=None) # Reading data
initialPosition_df.columns = initialPosition_header                     # Assigning column names

# Extracting data

fields_u_extended = ['u','v', 'w']                              # Not considering the z component
fields_x = ['x','y']                                            # Not considering the z component
fields_x_extended = ['x','y','z']                               # Considering the z component

X_real_extended = initialPosition_df[fields_x_extended]         # All the coordinates
front_b = max(X_real_extended.z)                                # Max z coordinate
back_b = min(X_real_extended.z)                                 # Min z coordinate
X_real_extended = X_real_extended[X_real_extended.z != front_b] # Remove duplicates in z direction
X_real = X_real_extended.drop(columns=['z'])                    # Remove z component

X_real_extended = X_real_extended.to_numpy()                    # Convert to numpy array
X_real_extended = X_real_extended.astype(np.float32)            # Convert to float32
X_real = X_real.to_numpy()                                      # Convert to numpy array
X_real = X_real.astype(np.float32)                              # Convert to float32
X_real = torch.tensor(X_real)                                   # Convert to tensor

# # Geometrical bounds
left_b = min(X_real_extended[:,0])
right_b = max(X_real_extended[:,0])
bottom_b = min(X_real_extended[:,1])
top_b = max(X_real_extended[:,1])
height = top_b - bottom_b
depth = front_b - back_b
length = right_b - left_b
A_front = depth*height
X_min = torch.tensor([left_b, bottom_b, back_b])
X_max = torch.tensor([right_b, top_b, front_b])
print('The boundaries are: left =',left_b,'right =',right_b,'bottom =',bottom_b,'top =',top_b, 'front =',front_b, 'back =',back_b)
print("The applied force is:",Force, "over an area of:",A_front, "resulting in a stress of:",Force/A_front)

# Obtaining the displacement data
U_real = displacement_df[fields_u_extended]                     # All the displacements
U_real['w'].round(decimals=1)                                   # round 'w' column
max_Uw = max(U_real.w)                                          # Max w displacement
min_Uw = min(U_real.w)                                          # Min w displacement
U_real = U_real[U_real.w != min_Uw]                             # Remove duplicates in w displacement
U_real = U_real.drop(columns=['w'])                             # Remove w component

U_real = U_real.to_numpy()                                      # Convert to numpy array
U_real = U_real.astype(np.float32)                              # Convert to float32
U_real = torch.from_numpy(U_real)                               # Convert to tensor
# Out:
# The boundaries are: left = -15.0 right = 15.0 bottom = -5.0 top = 5.0 front = 1 back = 0
# The applied force is: 1.0 over an area of: 10.0 resulting in a stress of: 0.1

# %% [markdown]
# ## Collocation points and auxiliary vectors

# %%
## Collocation points for PDF
X_f = np.random.uniform(left_b, right_b, (Nf_x, 1))                     # Random points in x direction
Y_f = np.random.uniform(bottom_b, top_b, (Nf_y, 1))                     # Random points in y direction
comb_array = np.array(np.meshgrid(X_f, Y_f)).T.reshape(-1, 2)           # Combine the two arrays
comb_array = comb_array.astype(np.float32)                              # Convert to float32
X_train_f = torch.tensor(comb_array)                       # Convert to tensor the collocation points

# Collocation point for BC
distance = height/(N_bc-1)
X_bc_y = np.linspace(bottom_b+distance/2, top_b-distance/2, N_bc).reshape(N_bc,1)       # Equispaced points in y direction
X_bc_x = np.ones(N_bc)*right_b                                                          # Boundary conditions indexes
X_bc_x = X_bc_x.reshape(N_bc,1)                                                         # Reshape
X_bc = np.concatenate((X_bc_x, X_bc_y), axis=1)                                         # Combine the two arrays
X_bc = X_bc.astype(np.float32)                                                          # Convert to float32
X_bc = torch.from_numpy(X_bc)                                                           # Convert to tensor

s_x = Force/A_front
Stress_bc = torch.ones_like(X_bc[:,0])*s_x
Stress_bc = Stress_bc.reshape(N_bc,1)


f_hat = torch.zeros(Nf_x*Nf_y, 2)
print("The number of collocation points for the PDE is:",Nf_x*Nf_y)
print("The number of collocation points for the BC is:", N_bc)
# Out:
# The number of collocation points for the PDE is: 4000
# The number of collocation points for the BC is: 50

# %% [markdown]
# ## Plot of the data set

# %%
## Plot the data
plt.figure()
plt.scatter(X_real[:,0], X_real[:,1], label='Initial position')
plt.scatter(X_bc[:,0], X_bc[:,1], label='Boundary condition')
plt.scatter(X_train_f[:,0], X_train_f[:,1], label='Collocation points')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Undeformed configuration')
# set size of the figure
plt.gcf().set_size_inches(15, 5)
plt.legend()
plt.show()

# %% [markdown]
# ## Defining architecture

# %%
input_dim = X_real.shape[1]
output_dim = U_real.shape[1]
layers = np.array([input_dim] + [ nneurons for i in range(nhiden_layers)] + [output_dim])

# %% [markdown]
# ## Deep NN class

# %%
#  Deep Neural Network
class DNN(nn.Module):
    def __init__(self,layers):
        super().__init__() #call __init__ from parent class

        'activation function'
        self.activation = nn.Tanh()

        'Initialize neural network as a list using nn.Modulelist'
        self.linears = nn.ModuleList([nn.Linear(layers[i], layers[i+1]) for i in range(len(layers) - 1)])

        'Xavier Normal Initialization'
        for i in range(len(layers)-1):

            # set standard deviation for initialization
            nn.init.xavier_normal_(self.linears[i].weight.data, gain=1.0)

            # set biases to zero
            nn.init.zeros_(self.linears[i].bias.data)

    'foward pass'
    def forward(self,x):

        if torch.is_tensor(x) != True:
            x = torch.from_numpy(x)

        #convert to float
        a = x.float()

        # inpunt and hidden layers forward computation
        for i in range(len(layers)-2):

            z = self.linears[i](a)

            a = self.activation(z)

        # output layer forward computation
        a = self.linears[-1](a)

        return a

# %% [markdown]
# ## PINN class

# %%
class PINN():
    def __init__(self, layers):

        'Define loss function'
        self.loss_function = nn.MSELoss(reduction ='mean')

        'Initialize iterator'
        self.iter = 0

        'Initialize our new parameter as tensor (Inverse problem)'
        self.E = torch.tensor([float(E_init)], requires_grad=True).float()

        'Register parametes to be optimized'
        self.E = nn.Parameter(self.E)

        'Initialize our DNN'
        self.dnn = DNN(layers)

        'Register our new parameter'
        self.dnn.register_parameter('E', self.E)

        'History of losses'
        self.loss_history = {"Data": [],
                             "PDE": [],
                             "BC": [],
                             "Total":[]}

        'Parameters trials'
        self.params_history = {"E": [] }

    def loss_data(self, x, u_real, save = False):

        ################################################ COMPLETAR


        save and self.loss_history["Data"].append(loss_d.to('cpu').detach().numpy())

        return loss_d

    def loss_PDE(self, pos_f, save = False):

        # extract the PDE parameters
        E = self.E
        nu = nu_real
        # G = E/(2*(1+nu))

        # clone the input data and add AD
        pos = pos_f.clone()
        pos.requires_grad = True

        # predict u
        U = self.dnn(pos)

        ################################################ COMPLETAR

        u_xx = ddU[:,0].reshape(-1,1)
        v_yy = ddU[:,1].reshape(-1,1)

        # Shift columns of du tensor
        dU_shifted = torch.roll(dU, 1, 1)

        u_xy = cross_ddU[:,1].reshape(-1,1)
        v_yx = cross_ddU[:,0].reshape(-1,1)


        ################################################ COMPLETAR
        # PDE f = 0


        f_tensor= torch.cat((f[0] , f[1]), dim=1).to(torch.float32)

        ################################################ COMPLETAR
        # Compute the loss_f


        save and self.loss_history["PDE"].append(loss_f.to('cpu').detach().numpy())

        return loss_f

    def loss_BC(self, pos_bc, save = False):

        # extract the PDE parameters
        E = self.E
        nu = nu_real
        # G = E/(2*(1+nu))

        # clone the input data and add AD
        pos = pos_bc.clone()
        pos.requires_grad = True

        # predict U
        U = self.dnn(pos)

        ################################################ COMPLETAR
        # compute the derivatives togheter


        ################################################ COMPLETAR
        # compute s11_pred


        ################################################ COMPLETAR
        # Compute the loss_bc

        save and self.loss_history["BC"].append(loss_bc.to('cpu').detach().numpy())

        return loss_bc

    def loss(self, pos_real, despl_real, pos_f, pos_bc, save = False):

        loss_d  = self.loss_data(pos_real, despl_real, save)
        loss_f  = self.loss_PDE(pos_f, save)
        loss_bc = self.loss_BC(pos_bc, save)

        # weights should sum 1
        loss_val = w_loss_d*loss_d + w_loss_f*loss_f + w_loss_bc*loss_bc

        if save:
            self.loss_history["Total"].append(loss_val.to('cpu').detach().numpy())
            self.params_history["E"].append(self.E.to('cpu').data.numpy().copy())
        return loss_val

    'callable for optimizer'
    def closure(self):

        optimizer.zero_grad()

        loss = self.loss(X_real, U_real, X_train_f, X_bc, True)

        loss.backward()

        self.iter += 1

        print(
            'LBFGS iter: %d, Loss total: %.10f, E_PINN/E_real = %.3f / %.3f' %
            (
                self.iter,
                loss.cpu().detach().numpy(),
                self.E.item(),
                E_real
            )
        )

        return loss

    'foward pass'
    def forward(self,pos):
        return self.dnn(pos)

# %% [markdown]
# ## Training

# %%
if Train_with_ADAM:
    ### TRAINING WITH ADAM ###

    print('Training with ADAM')

    'Neural Network Summary'
    pinn = PINN(layers)
    'Neural Network Parameters'
    params = list(pinn.dnn.parameters())

    'ADAM Optimizer'
    optimizer = torch.optim.Adam(params, lr,
                                amsgrad = True,
                                betas=(0.9, 0.999))

    # Measure time
    start_time_ADAM = time.time()
    # Training
    for epoch in range(ADAM_steps+1):

        loss = pinn.loss(X_real, U_real, X_train_f, X_bc, True)

        pinn.iter += 1

        print(
            'ADAM iter: %d, Loss total: %.10f, E_PINN/E_real = %.3f / %.3f ' %
            (
                pinn.iter,
                loss.cpu().detach().numpy(),
                pinn.E.item(),
                E_real
            )
        )

        optimizer.zero_grad()       # Zero Out the gradient
        loss.backward()
        optimizer.step()

    elapsed_time_ADAM = (time.time() - start_time_ADAM)/60
    print('Elapsed time ADAM: %.2f minutes.' % elapsed_time_ADAM)

if Train_with_LBFGS:
    ### TRAINING WITH ADAM ###

    print('Training with L-BFGS')

    'Neural Network Summary'
    pinn = PINN(layers)

    'Neural Network Parameters'
    params = list(pinn.dnn.parameters())

    'Mesure time'
    start_time_LBFGS = time.time()

    'L-BFGS Optimizer'
    optimizer = torch.optim.LBFGS(params, lr,
                                    max_iter = 5000,
                                    max_eval = None,
                                    tolerance_grad = 1e-12,
                                    tolerance_change = 1e-12,
                                    line_search_fn = 'strong_wolfe',
                                    history_size = 100)

    optimizer.step(pinn.closure)

    elapsed_time_LBFGS = (time.time() - start_time_LBFGS)/60

    print('Elapsed time L-BFGS: %.2f minutes' % elapsed_time_LBFGS)
# Out:
# Training with L-BFGS
# LBFGS iter: 1, Loss total: 9.7299251556, E_PINN/E_real = 4.000 / 10.000
# LBFGS iter: 2, Loss total: 7.8092999458, E_PINN/E_real = 4.000 / 10.000
# LBFGS iter: 3, Loss total: 3.1167216301, E_PINN/E_real = 3.999 / 10.000
# LBFGS iter: 4, Loss total: 1.5232684612, E_PINN/E_real = 3.999 / 10.000
# LBFGS iter: 5, Loss total: 0.8202986717, E_PINN/E_real = 3.999 / 10.000
# LBFGS iter: 6, Loss total: 0.4411371946, E_PINN/E_real = 3.999 / 10.000
# LBFGS iter: 7, Loss total: 0.2470728010, E_PINN/E_real = 3.998 / 10.000
# LBFGS iter: 8, Loss total: 0.1628949642, E_PINN/E_real = 3.998 / 10.000
# LBFGS iter: 9, Loss total: 0.1348634213, E_PINN/E_real = 3.998 / 10.000
# LBFGS iter: 10, Loss total: 0.1177517474, E_PINN/E_real = 3.997 / 10.000
# LBFGS iter: 11, Loss total: 0.0987160429, E_PINN/E_real = 3.997 / 10.000
# LBFGS iter: 12, Loss total: 0.0810186341, E_PINN/E_real = 3.997 / 10.000
# LBFGS iter: 13, Loss total: 0.0695418343, E_PINN/E_real = 3.996 / 10.000
# LBFGS iter: 14, Loss total: 0.0619385354, E_PINN/E_real = 3.996 / 10.000
# LBFGS iter: 15, Loss total: 0.0575276911, E_PINN/E_real = 3.996 / 10.000
# LBFGS iter: 16, Loss total: 0.0524096973, E_PINN/E_real = 3.995 / 10.000
# LBFGS iter: 17, Loss total: 0.0461759791, E_PINN/E_real = 3.995 / 10.000
# LBFGS iter: 18, Loss total: 0.0385924689, E_PINN/E_real = 3.994 / 10.000
# LBFGS iter: 19, Loss total: 0.0294137113, E_PINN/E_real = 3.993 / 10.000
# LBFGS iter: 20, Loss total: 0.0230690856, E_PINN/E_real = 3.992 / 10.000
# LBFGS iter: 21, Loss total: 0.0202301256, E_PINN/E_real = 3.992 / 10.000
# LBFGS iter: 22, Loss total: 0.0184766725, E_PINN/E_real = 3.991 / 10.000
# LBFGS iter: 23, Loss total: 0.0167033784, E_PINN/E_real = 3.991 / 10.000
# LBFGS iter: 24, Loss total: 0.0151524497, E_PINN/E_real = 3.990 / 10.000
# LBFGS iter: 25, Loss total: 0.0141923390, E_PINN/E_real = 3.990 / 10.000
# LBFGS iter: 26, Loss total: 0.0128372330, E_PINN/E_real = 3.990 / 10.000
# LBFGS iter: 27, Loss total: 0.0118042585, E_PINN/E_real = 3.989 / 10.000
# LBFGS iter: 28, Loss total: 0.0110002970, E_PINN/E_real = 3.989 / 10.000
# LBFGS iter: 29, Loss total: 0.0104470421, E_PINN/E_real = 3.989 / 10.000
# LBFGS iter: 30, Loss total: 0.0101296809, E_PINN/E_real = 3.989 / 10.000
# LBFGS iter: 31, Loss total: 0.0098534860, E_PINN/E_real = 3.988 / 10.000
# LBFGS iter: 32, Loss total: 0.0095505295, E_PINN/E_real = 3.988 / 10.000
# LBFGS iter: 33, Loss total: 0.0091760941, E_PINN/E_real = 3.988 / 10.000
# LBFGS iter: 34, Loss total: 0.0086776344, E_PINN/E_real = 3.988 / 10.000
# LBFGS iter: 35, Loss total: 0.0080252914, E_PINN/E_real = 3.987 / 10.000
# LBFGS iter: 36, Loss total: 0.0074236207, E_PINN/E_real = 3.986 / 10.000
# LBFGS iter: 37, Loss total: 0.0068912311, E_PINN/E_real = 3.986 / 10.000
# LBFGS iter: 38, Loss total: 0.0063505117, E_PINN/E_real = 3.986 / 10.000
# LBFGS iter: 39, Loss total: 0.0060216947, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 40, Loss total: 0.0057953503, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 41, Loss total: 0.0056338357, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 42, Loss total: 0.0054860786, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 43, Loss total: 0.0053364085, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 44, Loss total: 0.0051566167, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 45, Loss total: 0.0049442751, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 46, Loss total: 0.0047175279, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 47, Loss total: 0.0045261346, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 48, Loss total: 0.0043805409, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 49, Loss total: 0.0042232377, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 50, Loss total: 0.0040395013, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 51, Loss total: 0.0039042060, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 52, Loss total: 0.0038103815, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 53, Loss total: 0.0037275532, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 54, Loss total: 0.0036168634, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 55, Loss total: 0.0035326525, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 56, Loss total: 0.0034519248, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 57, Loss total: 0.0033932622, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 58, Loss total: 0.0033332622, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 59, Loss total: 0.0032682070, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 60, Loss total: 0.0032016742, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 61, Loss total: 0.0031398116, E_PINN/E_real = 3.985 / 10.000
# LBFGS iter: 62, Loss total: 0.0030909055, E_PINN/E_real = 3.986 / 10.000
# LBFGS iter: 63, Loss total: 0.0030500209, E_PINN/E_real = 3.986 / 10.000
# LBFGS iter: 64, Loss total: 0.0029956081, E_PINN/E_real = 3.986 / 10.000
# LBFGS iter: 65, Loss total: 0.0029294365, E_PINN/E_real = 3.986 / 10.000
# LBFGS iter: 66, Loss total: 0.0028593740, E_PINN/E_real = 3.987 / 10.000
# LBFGS iter: 67, Loss total: 0.0028008397, E_PINN/E_real = 3.987 / 10.000
# LBFGS iter: 68, Loss total: 0.0027564042, E_PINN/E_real = 3.988 / 10.000
# LBFGS iter: 69, Loss total: 0.0027190973, E_PINN/E_real = 3.988 / 10.000
# LBFGS iter: 70, Loss total: 0.0026920182, E_PINN/E_real = 3.989 / 10.000
# LBFGS iter: 71, Loss total: 0.0026683174, E_PINN/E_real = 3.989 / 10.000
# LBFGS iter: 72, Loss total: 0.0026398366, E_PINN/E_real = 3.989 / 10.000
# LBFGS iter: 73, Loss total: 0.0026057626, E_PINN/E_real = 3.990 / 10.000
# LBFGS iter: 74, Loss total: 0.0025616395, E_PINN/E_real = 3.991 / 10.000
# LBFGS iter: 75, Loss total: 0.0025142676, E_PINN/E_real = 3.992 / 10.000
# LBFGS iter: 76, Loss total: 0.0024706430, E_PINN/E_real = 3.993 / 10.000
# LBFGS iter: 77, Loss total: 0.0024317794, E_PINN/E_real = 3.993 / 10.000
# LBFGS iter: 78, Loss total: 0.0023989885, E_PINN/E_real = 3.994 / 10.000
# LBFGS iter: 79, Loss total: 0.0023726127, E_PINN/E_real = 3.995 / 10.000
# LBFGS iter: 80, Loss total: 0.0023463534, E_PINN/E_real = 3.996 / 10.000
# LBFGS iter: 81, Loss total: 0.0023220137, E_PINN/E_real = 3.996 / 10.000
# LBFGS iter: 82, Loss total: 0.0022910484, E_PINN/E_real = 3.997 / 10.000
# LBFGS iter: 83, Loss total: 0.0022529007, E_PINN/E_real = 3.998 / 10.000
# LBFGS iter: 84, Loss total: 0.0022050291, E_PINN/E_real = 4.000 / 10.000
# LBFGS iter: 85, Loss total: 0.0021534390, E_PINN/E_real = 4.001 / 10.000
# LBFGS iter: 86, Loss total: 0.0021112862, E_PINN/E_real = 4.003 / 10.000
# LBFGS iter: 87, Loss total: 0.0020692511, E_PINN/E_real = 4.004 / 10.000
# LBFGS iter: 88, Loss total: 0.0020373370, E_PINN/E_real = 4.006 / 10.000
# LBFGS iter: 89, Loss total: 0.0020125855, E_PINN/E_real = 4.006 / 10.000
# LBFGS iter: 90, Loss total: 0.0019894375, E_PINN/E_real = 4.008 / 10.000
# LBFGS iter: 91, Loss total: 0.0019740406, E_PINN/E_real = 4.008 / 10.000
# LBFGS iter: 92, Loss total: 0.0019629369, E_PINN/E_real = 4.008 / 10.000
# LBFGS iter: 93, Loss total: 0.0019541066, E_PINN/E_real = 4.009 / 10.000
# LBFGS iter: 94, Loss total: 0.0019383472, E_PINN/E_real = 4.009 / 10.000
# LBFGS iter: 95, Loss total: 0.0019173948, E_PINN/E_real = 4.011 / 10.000
# LBFGS iter: 96, Loss total: 0.0019010181, E_PINN/E_real = 4.012 / 10.000
# LBFGS iter: 97, Loss total: 0.0018877110, E_PINN/E_real = 4.013 / 10.000
# LBFGS iter: 98, Loss total: 0.0018706324, E_PINN/E_real = 4.014 / 10.000
# LBFGS iter: 99, Loss total: 0.0018467901, E_PINN/E_real = 4.015 / 10.000
# LBFGS iter: 100, Loss total: 0.0018225145, E_PINN/E_real = 4.016 / 10.000
# LBFGS iter: 101, Loss total: 0.0018001474, E_PINN/E_real = 4.017 / 10.000
# LBFGS iter: 102, Loss total: 0.0017777160, E_PINN/E_real = 4.018 / 10.000
# LBFGS iter: 103, Loss total: 0.0017485861, E_PINN/E_real = 4.019 / 10.000
# LBFGS iter: 104, Loss total: 0.0017137122, E_PINN/E_real = 4.020 / 10.000
# LBFGS iter: 105, Loss total: 0.0016808314, E_PINN/E_real = 4.021 / 10.000
# LBFGS iter: 106, Loss total: 0.0016530573, E_PINN/E_real = 4.022 / 10.000
# LBFGS iter: 107, Loss total: 0.0016323114, E_PINN/E_real = 4.023 / 10.000
# LBFGS iter: 108, Loss total: 0.0016182448, E_PINN/E_real = 4.024 / 10.000
# LBFGS iter: 109, Loss total: 0.0016092695, E_PINN/E_real = 4.025 / 10.000
# LBFGS iter: 110, Loss total: 0.0016039150, E_PINN/E_real = 4.025 / 10.000
# LBFGS iter: 111, Loss total: 0.0015995255, E_PINN/E_real = 4.026 / 10.000
# LBFGS iter: 112, Loss total: 0.0015925404, E_PINN/E_real = 4.027 / 10.000
# LBFGS iter: 113, Loss total: 0.0015816984, E_PINN/E_real = 4.028 / 10.000
# LBFGS iter: 114, Loss total: 0.0015686305, E_PINN/E_real = 4.029 / 10.000
# LBFGS iter: 115, Loss total: 0.0015565478, E_PINN/E_real = 4.030 / 10.000
# LBFGS iter: 116, Loss total: 0.0015437494, E_PINN/E_real = 4.031 / 10.000
# LBFGS iter: 117, Loss total: 0.0015284083, E_PINN/E_real = 4.033 / 10.000
# LBFGS iter: 118, Loss total: 0.0015126067, E_PINN/E_real = 4.034 / 10.000
# LBFGS iter: 119, Loss total: 0.0015005381, E_PINN/E_real = 4.035 / 10.000
# LBFGS iter: 120, Loss total: 0.0014915143, E_PINN/E_real = 4.036 / 10.000
# LBFGS iter: 121, Loss total: 0.0014825913, E_PINN/E_real = 4.036 / 10.000
# LBFGS iter: 122, Loss total: 0.0014729290, E_PINN/E_real = 4.037 / 10.000
# LBFGS iter: 123, Loss total: 0.0014631033, E_PINN/E_real = 4.038 / 10.000
# LBFGS iter: 124, Loss total: 0.0014535998, E_PINN/E_real = 4.039 / 10.000
# LBFGS iter: 125, Loss total: 0.0014415660, E_PINN/E_real = 4.040 / 10.000
# LBFGS iter: 126, Loss total: 0.0014297481, E_PINN/E_real = 4.040 / 10.000
# LBFGS iter: 127, Loss total: 0.0014198935, E_PINN/E_real = 4.041 / 10.000
# LBFGS iter: 128, Loss total: 0.0014113527, E_PINN/E_real = 4.042 / 10.000
# LBFGS iter: 129, Loss total: 0.0014022011, E_PINN/E_real = 4.043 / 10.000
# LBFGS iter: 130, Loss total: 0.0013903197, E_PINN/E_real = 4.045 / 10.000
# LBFGS iter: 131, Loss total: 0.0013740691, E_PINN/E_real = 4.047 / 10.000
# LBFGS iter: 132, Loss total: 0.0013573332, E_PINN/E_real = 4.050 / 10.000
# LBFGS iter: 133, Loss total: 0.0013459084, E_PINN/E_real = 4.052 / 10.000
# LBFGS iter: 134, Loss total: 0.0013356326, E_PINN/E_real = 4.053 / 10.000
# LBFGS iter: 135, Loss total: 0.0013252943, E_PINN/E_real = 4.054 / 10.000
# LBFGS iter: 136, Loss total: 0.0013169706, E_PINN/E_real = 4.055 / 10.000
# LBFGS iter: 137, Loss total: 0.0013109117, E_PINN/E_real = 4.056 / 10.000
# LBFGS iter: 138, Loss total: 0.0013049137, E_PINN/E_real = 4.056 / 10.000
# LBFGS iter: 139, Loss total: 0.0012978845, E_PINN/E_real = 4.057 / 10.000
# LBFGS iter: 140, Loss total: 0.0012908409, E_PINN/E_real = 4.058 / 10.000
# LBFGS iter: 141, Loss total: 0.0012849208, E_PINN/E_real = 4.058 / 10.000
# LBFGS iter: 142, Loss total: 0.0012793362, E_PINN/E_real = 4.059 / 10.000
# LBFGS iter: 143, Loss total: 0.0012731787, E_PINN/E_real = 4.059 / 10.000
# LBFGS iter: 144, Loss total: 0.0012671440, E_PINN/E_real = 4.060 / 10.000
# LBFGS iter: 145, Loss total: 0.0012596246, E_PINN/E_real = 4.061 / 10.000
# LBFGS iter: 146, Loss total: 0.0012477911, E_PINN/E_real = 4.063 / 10.000
# LBFGS iter: 147, Loss total: 0.0012366823, E_PINN/E_real = 4.066 / 10.000
# LBFGS iter: 148, Loss total: 0.0012258929, E_PINN/E_real = 4.068 / 10.000
# LBFGS iter: 149, Loss total: 0.0012168565, E_PINN/E_real = 4.071 / 10.000
# LBFGS iter: 150, Loss total: 0.0012088085, E_PINN/E_real = 4.073 / 10.000
# LBFGS iter: 151, Loss total: 0.0011998304, E_PINN/E_real = 4.076 / 10.000
# LBFGS iter: 152, Loss total: 0.0011881932, E_PINN/E_real = 4.079 / 10.000
# LBFGS iter: 153, Loss total: 0.0011804297, E_PINN/E_real = 4.082 / 10.000
# LBFGS iter: 154, Loss total: 0.0011685847, E_PINN/E_real = 4.084 / 10.000
# LBFGS iter: 155, Loss total: 0.0011552424, E_PINN/E_real = 4.087 / 10.000
# LBFGS iter: 156, Loss total: 0.0011442162, E_PINN/E_real = 4.090 / 10.000
# LBFGS iter: 157, Loss total: 0.0011379516, E_PINN/E_real = 4.090 / 10.000
# LBFGS iter: 158, Loss total: 0.0011348258, E_PINN/E_real = 4.092 / 10.000
# LBFGS iter: 159, Loss total: 0.0011335050, E_PINN/E_real = 4.092 / 10.000
# LBFGS iter: 160, Loss total: 0.0011314565, E_PINN/E_real = 4.092 / 10.000
# LBFGS iter: 161, Loss total: 0.0011282638, E_PINN/E_real = 4.093 / 10.000
# LBFGS iter: 162, Loss total: 0.0011248719, E_PINN/E_real = 4.092 / 10.000
# LBFGS iter: 163, Loss total: 0.0011212924, E_PINN/E_real = 4.092 / 10.000
# LBFGS iter: 164, Loss total: 0.0011162098, E_PINN/E_real = 4.092 / 10.000
# LBFGS iter: 165, Loss total: 0.0011095848, E_PINN/E_real = 4.092 / 10.000
# LBFGS iter: 166, Loss total: 0.0011040423, E_PINN/E_real = 4.092 / 10.000
# LBFGS iter: 167, Loss total: 0.0010982952, E_PINN/E_real = 4.092 / 10.000
# LBFGS iter: 168, Loss total: 0.0010930062, E_PINN/E_real = 4.093 / 10.000
# LBFGS iter: 169, Loss total: 0.0010874863, E_PINN/E_real = 4.093 / 10.000
# LBFGS iter: 170, Loss total: 0.0010809046, E_PINN/E_real = 4.094 / 10.000
# LBFGS iter: 171, Loss total: 0.0010743516, E_PINN/E_real = 4.095 / 10.000
# LBFGS iter: 172, Loss total: 0.0010684942, E_PINN/E_real = 4.097 / 10.000
# LBFGS iter: 173, Loss total: 0.0010624634, E_PINN/E_real = 4.098 / 10.000
# LBFGS iter: 174, Loss total: 0.0010555658, E_PINN/E_real = 4.100 / 10.000
# LBFGS iter: 175, Loss total: 0.0010468288, E_PINN/E_real = 4.103 / 10.000
# LBFGS iter: 176, Loss total: 0.0010372710, E_PINN/E_real = 4.105 / 10.000
# LBFGS iter: 177, Loss total: 0.0010289040, E_PINN/E_real = 4.107 / 10.000
# LBFGS iter: 178, Loss total: 0.0010215996, E_PINN/E_real = 4.109 / 10.000
# LBFGS iter: 179, Loss total: 0.0010165806, E_PINN/E_real = 4.111 / 10.000
# LBFGS iter: 180, Loss total: 0.0010133588, E_PINN/E_real = 4.111 / 10.000
# LBFGS iter: 181, Loss total: 0.0010107912, E_PINN/E_real = 4.113 / 10.000
# LBFGS iter: 182, Loss total: 0.0010083310, E_PINN/E_real = 4.113 / 10.000
# LBFGS iter: 183, Loss total: 0.0010066708, E_PINN/E_real = 4.114 / 10.000
# LBFGS iter: 184, Loss total: 0.0010024783, E_PINN/E_real = 4.115 / 10.000
# LBFGS iter: 185, Loss total: 0.0009953706, E_PINN/E_real = 4.117 / 10.000
# LBFGS iter: 186, Loss total: 0.0009872243, E_PINN/E_real = 4.118 / 10.000
# LBFGS iter: 187, Loss total: 0.0009795272, E_PINN/E_real = 4.121 / 10.000
# LBFGS iter: 188, Loss total: 0.0009731936, E_PINN/E_real = 4.122 / 10.000
# LBFGS iter: 189, Loss total: 0.0009687148, E_PINN/E_real = 4.124 / 10.000
# LBFGS iter: 190, Loss total: 0.0009655426, E_PINN/E_real = 4.125 / 10.000
# LBFGS iter: 191, Loss total: 0.0009632874, E_PINN/E_real = 4.126 / 10.000
# LBFGS iter: 192, Loss total: 0.0009615745, E_PINN/E_real = 4.126 / 10.000
# LBFGS iter: 193, Loss total: 0.0009598496, E_PINN/E_real = 4.126 / 10.000
# LBFGS iter: 194, Loss total: 0.0009577860, E_PINN/E_real = 4.126 / 10.000
# LBFGS iter: 195, Loss total: 0.0009560756, E_PINN/E_real = 4.126 / 10.000
# LBFGS iter: 196, Loss total: 0.0009538090, E_PINN/E_real = 4.127 / 10.000
# LBFGS iter: 197, Loss total: 0.0009500264, E_PINN/E_real = 4.127 / 10.000
# LBFGS iter: 198, Loss total: 0.0009453312, E_PINN/E_real = 4.128 / 10.000
# LBFGS iter: 199, Loss total: 0.0009400261, E_PINN/E_real = 4.129 / 10.000
# LBFGS iter: 200, Loss total: 0.0009349985, E_PINN/E_real = 4.130 / 10.000
# LBFGS iter: 201, Loss total: 0.0009318286, E_PINN/E_real = 4.132 / 10.000
# LBFGS iter: 202, Loss total: 0.0009291878, E_PINN/E_real = 4.133 / 10.000
# LBFGS iter: 203, Loss total: 0.0009274307, E_PINN/E_real = 4.134 / 10.000
# LBFGS iter: 204, Loss total: 0.0009262730, E_PINN/E_real = 4.135 / 10.000
# LBFGS iter: 205, Loss total: 0.0009255295, E_PINN/E_real = 4.136 / 10.000
# LBFGS iter: 206, Loss total: 0.0009248527, E_PINN/E_real = 4.136 / 10.000
# LBFGS iter: 207, Loss total: 0.0009237776, E_PINN/E_real = 4.137 / 10.000
# LBFGS iter: 208, Loss total: 0.0009217288, E_PINN/E_real = 4.138 / 10.000
# LBFGS iter: 209, Loss total: 0.0009184171, E_PINN/E_real = 4.140 / 10.000
# LBFGS iter: 210, Loss total: 0.0009138518, E_PINN/E_real = 4.142 / 10.000
# LBFGS iter: 211, Loss total: 0.0009094418, E_PINN/E_real = 4.145 / 10.000
# LBFGS iter: 212, Loss total: 0.0009055992, E_PINN/E_real = 4.147 / 10.000
# LBFGS iter: 213, Loss total: 0.0009032825, E_PINN/E_real = 4.148 / 10.000
# LBFGS iter: 214, Loss total: 0.0009015336, E_PINN/E_real = 4.148 / 10.000
# LBFGS iter: 215, Loss total: 0.0009004396, E_PINN/E_real = 4.148 / 10.000
# LBFGS iter: 216, Loss total: 0.0008994120, E_PINN/E_real = 4.148 / 10.000
# LBFGS iter: 217, Loss total: 0.0008980542, E_PINN/E_real = 4.148 / 10.000
# LBFGS iter: 218, Loss total: 0.0008962920, E_PINN/E_real = 4.148 / 10.000
# LBFGS iter: 219, Loss total: 0.0008943379, E_PINN/E_real = 4.148 / 10.000
# LBFGS iter: 220, Loss total: 0.0008918704, E_PINN/E_real = 4.148 / 10.000
# LBFGS iter: 221, Loss total: 0.0008888122, E_PINN/E_real = 4.148 / 10.000
# LBFGS iter: 222, Loss total: 0.0008852661, E_PINN/E_real = 4.149 / 10.000
# LBFGS iter: 223, Loss total: 0.0008812879, E_PINN/E_real = 4.151 / 10.000
# LBFGS iter: 224, Loss total: 0.0008780463, E_PINN/E_real = 4.153 / 10.000
# LBFGS iter: 225, Loss total: 0.0008754407, E_PINN/E_real = 4.155 / 10.000
# LBFGS iter: 226, Loss total: 0.0008732262, E_PINN/E_real = 4.157 / 10.000
# LBFGS iter: 227, Loss total: 0.0008714821, E_PINN/E_real = 4.158 / 10.000
# LBFGS iter: 228, Loss total: 0.0008702865, E_PINN/E_real = 4.160 / 10.000
# LBFGS iter: 229, Loss total: 0.0008692611, E_PINN/E_real = 4.161 / 10.000
# LBFGS iter: 230, Loss total: 0.0008679884, E_PINN/E_real = 4.162 / 10.000
# LBFGS iter: 231, Loss total: 0.0008660549, E_PINN/E_real = 4.163 / 10.000
# LBFGS iter: 232, Loss total: 0.0008640848, E_PINN/E_real = 4.165 / 10.000
# LBFGS iter: 233, Loss total: 0.0008624444, E_PINN/E_real = 4.166 / 10.000
# LBFGS iter: 234, Loss total: 0.0008611067, E_PINN/E_real = 4.167 / 10.000
# LBFGS iter: 235, Loss total: 0.0008598688, E_PINN/E_real = 4.167 / 10.000
# LBFGS iter: 236, Loss total: 0.0008583212, E_PINN/E_real = 4.168 / 10.000
# LBFGS iter: 237, Loss total: 0.0008562972, E_PINN/E_real = 4.169 / 10.000
# LBFGS iter: 238, Loss total: 0.0008541298, E_PINN/E_real = 4.170 / 10.000
# LBFGS iter: 239, Loss total: 0.0008520318, E_PINN/E_real = 4.171 / 10.000
# LBFGS iter: 240, Loss total: 0.0008498783, E_PINN/E_real = 4.172 / 10.000
# LBFGS iter: 241, Loss total: 0.0008473286, E_PINN/E_real = 4.174 / 10.000
# LBFGS iter: 242, Loss total: 0.0008436232, E_PINN/E_real = 4.176 / 10.000
# LBFGS iter: 243, Loss total: 0.0008406651, E_PINN/E_real = 4.178 / 10.000
# LBFGS iter: 244, Loss total: 0.0008381566, E_PINN/E_real = 4.180 / 10.000
# LBFGS iter: 245, Loss total: 0.0008355506, E_PINN/E_real = 4.182 / 10.000
# LBFGS iter: 246, Loss total: 0.0008327371, E_PINN/E_real = 4.185 / 10.000
# LBFGS iter: 247, Loss total: 0.0008301849, E_PINN/E_real = 4.186 / 10.000
# LBFGS iter: 248, Loss total: 0.0008279918, E_PINN/E_real = 4.189 / 10.000
# LBFGS iter: 249, Loss total: 0.0008258591, E_PINN/E_real = 4.191 / 10.000
# LBFGS iter: 250, Loss total: 0.0008237263, E_PINN/E_real = 4.194 / 10.000
# LBFGS iter: 251, Loss total: 0.0008214681, E_PINN/E_real = 4.197 / 10.000
# LBFGS iter: 252, Loss total: 0.0008197848, E_PINN/E_real = 4.199 / 10.000
# LBFGS iter: 253, Loss total: 0.0008183593, E_PINN/E_real = 4.202 / 10.000
# LBFGS iter: 254, Loss total: 0.0008175716, E_PINN/E_real = 4.204 / 10.000
# LBFGS iter: 255, Loss total: 0.0008168597, E_PINN/E_real = 4.205 / 10.000
# LBFGS iter: 256, Loss total: 0.0008159223, E_PINN/E_real = 4.207 / 10.000
# LBFGS iter: 257, Loss total: 0.0008146595, E_PINN/E_real = 4.208 / 10.000
# LBFGS iter: 258, Loss total: 0.0008128533, E_PINN/E_real = 4.211 / 10.000
# LBFGS iter: 259, Loss total: 0.0008108460, E_PINN/E_real = 4.213 / 10.000
# LBFGS iter: 260, Loss total: 0.0008092855, E_PINN/E_real = 4.214 / 10.000
# LBFGS iter: 261, Loss total: 0.0008070634, E_PINN/E_real = 4.217 / 10.000
# LBFGS iter: 262, Loss total: 0.0008045491, E_PINN/E_real = 4.219 / 10.000
# LBFGS iter: 263, Loss total: 0.0008021477, E_PINN/E_real = 4.224 / 10.000
# LBFGS iter: 264, Loss total: 0.0008007021, E_PINN/E_real = 4.224 / 10.000
# LBFGS iter: 265, Loss total: 0.0007992975, E_PINN/E_real = 4.227 / 10.000
# LBFGS iter: 266, Loss total: 0.0007979157, E_PINN/E_real = 4.227 / 10.000
# LBFGS iter: 267, Loss total: 0.0007968539, E_PINN/E_real = 4.229 / 10.000
# LBFGS iter: 268, Loss total: 0.0007955256, E_PINN/E_real = 4.231 / 10.000
# LBFGS iter: 269, Loss total: 0.0007941962, E_PINN/E_real = 4.234 / 10.000
# LBFGS iter: 270, Loss total: 0.0007927029, E_PINN/E_real = 4.237 / 10.000
# LBFGS iter: 271, Loss total: 0.0007910555, E_PINN/E_real = 4.241 / 10.000
# LBFGS iter: 272, Loss total: 0.0007896217, E_PINN/E_real = 4.244 / 10.000
# LBFGS iter: 273, Loss total: 0.0007880539, E_PINN/E_real = 4.248 / 10.000
# LBFGS iter: 274, Loss total: 0.0007860698, E_PINN/E_real = 4.251 / 10.000
# LBFGS iter: 275, Loss total: 0.0007841819, E_PINN/E_real = 4.258 / 10.000
# LBFGS iter: 276, Loss total: 0.0007823427, E_PINN/E_real = 4.260 / 10.000
# LBFGS iter: 277, Loss total: 0.0007813363, E_PINN/E_real = 4.263 / 10.000
# LBFGS iter: 278, Loss total: 0.0007803506, E_PINN/E_real = 4.265 / 10.000
# LBFGS iter: 279, Loss total: 0.0007798293, E_PINN/E_real = 4.265 / 10.000
# LBFGS iter: 280, Loss total: 0.0007791893, E_PINN/E_real = 4.266 / 10.000
# LBFGS iter: 281, Loss total: 0.0007784362, E_PINN/E_real = 4.265 / 10.000
# LBFGS iter: 282, Loss total: 0.0007778116, E_PINN/E_real = 4.264 / 10.000
# LBFGS iter: 283, Loss total: 0.0007773340, E_PINN/E_real = 4.263 / 10.000
# LBFGS iter: 284, Loss total: 0.0007768173, E_PINN/E_real = 4.262 / 10.000
# LBFGS iter: 285, Loss total: 0.0007763255, E_PINN/E_real = 4.261 / 10.000
# LBFGS iter: 286, Loss total: 0.0007756230, E_PINN/E_real = 4.260 / 10.000
# LBFGS iter: 287, Loss total: 0.0007745731, E_PINN/E_real = 4.259 / 10.000
# LBFGS iter: 288, Loss total: 0.0007733835, E_PINN/E_real = 4.258 / 10.000
# LBFGS iter: 289, Loss total: 0.0007720308, E_PINN/E_real = 4.256 / 10.000
# LBFGS iter: 290, Loss total: 0.0007705570, E_PINN/E_real = 4.255 / 10.000
# LBFGS iter: 291, Loss total: 0.0007688660, E_PINN/E_real = 4.254 / 10.000
# LBFGS iter: 292, Loss total: 0.0007671873, E_PINN/E_real = 4.253 / 10.000
# LBFGS iter: 293, Loss total: 0.0007656734, E_PINN/E_real = 4.254 / 10.000
# LBFGS iter: 294, Loss total: 0.0007646360, E_PINN/E_real = 4.253 / 10.000
# LBFGS iter: 295, Loss total: 0.0007640088, E_PINN/E_real = 4.253 / 10.000
# LBFGS iter: 296, Loss total: 0.0007632915, E_PINN/E_real = 4.253 / 10.000
# LBFGS iter: 297, Loss total: 0.0007623530, E_PINN/E_real = 4.254 / 10.000
# LBFGS iter: 298, Loss total: 0.0007615656, E_PINN/E_real = 4.254 / 10.000
# LBFGS iter: 299, Loss total: 0.0007609769, E_PINN/E_real = 4.255 / 10.000
# LBFGS iter: 300, Loss total: 0.0007603651, E_PINN/E_real = 4.255 / 10.000
# LBFGS iter: 301, Loss total: 0.0007597168, E_PINN/E_real = 4.255 / 10.000
# LBFGS iter: 302, Loss total: 0.0007589945, E_PINN/E_real = 4.256 / 10.000
# LBFGS iter: 303, Loss total: 0.0007582923, E_PINN/E_real = 4.256 / 10.000
# LBFGS iter: 304, Loss total: 0.0007576919, E_PINN/E_real = 4.258 / 10.000
# LBFGS iter: 305, Loss total: 0.0007571096, E_PINN/E_real = 4.258 / 10.000
# LBFGS iter: 306, Loss total: 0.0007565028, E_PINN/E_real = 4.260 / 10.000
# LBFGS iter: 307, Loss total: 0.0007556904, E_PINN/E_real = 4.262 / 10.000
# LBFGS iter: 308, Loss total: 0.0007545530, E_PINN/E_real = 4.267 / 10.000
# LBFGS iter: 309, Loss total: 0.0007530386, E_PINN/E_real = 4.273 / 10.000
# LBFGS iter: 310, Loss total: 0.0007517423, E_PINN/E_real = 4.277 / 10.000
# LBFGS iter: 311, Loss total: 0.0007500160, E_PINN/E_real = 4.283 / 10.000
# LBFGS iter: 312, Loss total: 0.0007475658, E_PINN/E_real = 4.288 / 10.000
# LBFGS iter: 313, Loss total: 0.0007460571, E_PINN/E_real = 4.292 / 10.000
# LBFGS iter: 314, Loss total: 0.0007439367, E_PINN/E_real = 4.294 / 10.000
# LBFGS iter: 315, Loss total: 0.0007426220, E_PINN/E_real = 4.298 / 10.000
# LBFGS iter: 316, Loss total: 0.0007414759, E_PINN/E_real = 4.299 / 10.000
# LBFGS iter: 317, Loss total: 0.0007406361, E_PINN/E_real = 4.300 / 10.000
# LBFGS iter: 318, Loss total: 0.0007398631, E_PINN/E_real = 4.301 / 10.000
# LBFGS iter: 319, Loss total: 0.0007389220, E_PINN/E_real = 4.302 / 10.000
# LBFGS iter: 320, Loss total: 0.0007382531, E_PINN/E_real = 4.302 / 10.000
# LBFGS iter: 321, Loss total: 0.0007379415, E_PINN/E_real = 4.302 / 10.000
# LBFGS iter: 322, Loss total: 0.0007376912, E_PINN/E_real = 4.303 / 10.000
# LBFGS iter: 323, Loss total: 0.0007374945, E_PINN/E_real = 4.303 / 10.000
# LBFGS iter: 324, Loss total: 0.0007372862, E_PINN/E_real = 4.303 / 10.000
# LBFGS iter: 325, Loss total: 0.0007368629, E_PINN/E_real = 4.303 / 10.000
# LBFGS iter: 326, Loss total: 0.0007360481, E_PINN/E_real = 4.304 / 10.000
# LBFGS iter: 327, Loss total: 0.0007349260, E_PINN/E_real = 4.306 / 10.000
# LBFGS iter: 328, Loss total: 0.0007333671, E_PINN/E_real = 4.307 / 10.000
# LBFGS iter: 329, Loss total: 0.0007315179, E_PINN/E_real = 4.309 / 10.000
# LBFGS iter: 330, Loss total: 0.0007308760, E_PINN/E_real = 4.311 / 10.000
# LBFGS iter: 331, Loss total: 0.0007292407, E_PINN/E_real = 4.312 / 10.000
# LBFGS iter: 332, Loss total: 0.0007278885, E_PINN/E_real = 4.312 / 10.000
# LBFGS iter: 333, Loss total: 0.0007268767, E_PINN/E_real = 4.313 / 10.000
# LBFGS iter: 334, Loss total: 0.0007261793, E_PINN/E_real = 4.312 / 10.000
# LBFGS iter: 335, Loss total: 0.0007257556, E_PINN/E_real = 4.312 / 10.000
# LBFGS iter: 336, Loss total: 0.0007253937, E_PINN/E_real = 4.312 / 10.000
# LBFGS iter: 337, Loss total: 0.0007249838, E_PINN/E_real = 4.312 / 10.000
# LBFGS iter: 338, Loss total: 0.0007244536, E_PINN/E_real = 4.312 / 10.000
# LBFGS iter: 339, Loss total: 0.0007238225, E_PINN/E_real = 4.312 / 10.000
# LBFGS iter: 340, Loss total: 0.0007230785, E_PINN/E_real = 4.312 / 10.000
# LBFGS iter: 341, Loss total: 0.0007224580, E_PINN/E_real = 4.312 / 10.000
# LBFGS iter: 342, Loss total: 0.0007219384, E_PINN/E_real = 4.313 / 10.000
# LBFGS iter: 343, Loss total: 0.0007213775, E_PINN/E_real = 4.313 / 10.000
# LBFGS iter: 344, Loss total: 0.0007206351, E_PINN/E_real = 4.314 / 10.000
# LBFGS iter: 345, Loss total: 0.0007197706, E_PINN/E_real = 4.316 / 10.000
# LBFGS iter: 346, Loss total: 0.0007188696, E_PINN/E_real = 4.317 / 10.000
# LBFGS iter: 347, Loss total: 0.0007182050, E_PINN/E_real = 4.319 / 10.000
# LBFGS iter: 348, Loss total: 0.0007172119, E_PINN/E_real = 4.320 / 10.000
# LBFGS iter: 349, Loss total: 0.0007163669, E_PINN/E_real = 4.322 / 10.000
# LBFGS iter: 350, Loss total: 0.0007157375, E_PINN/E_real = 4.323 / 10.000
# LBFGS iter: 351, Loss total: 0.0007153326, E_PINN/E_real = 4.324 / 10.000
# LBFGS iter: 352, Loss total: 0.0007148821, E_PINN/E_real = 4.324 / 10.000
# LBFGS iter: 353, Loss total: 0.0007145361, E_PINN/E_real = 4.325 / 10.000
# LBFGS iter: 354, Loss total: 0.0007142117, E_PINN/E_real = 4.326 / 10.000
# LBFGS iter: 355, Loss total: 0.0007139479, E_PINN/E_real = 4.326 / 10.000
# LBFGS iter: 356, Loss total: 0.0007136465, E_PINN/E_real = 4.327 / 10.000
# LBFGS iter: 357, Loss total: 0.0007132076, E_PINN/E_real = 4.328 / 10.000
# LBFGS iter: 358, Loss total: 0.0007127112, E_PINN/E_real = 4.329 / 10.000
# LBFGS iter: 359, Loss total: 0.0007122080, E_PINN/E_real = 4.330 / 10.000
# LBFGS iter: 360, Loss total: 0.0007117421, E_PINN/E_real = 4.332 / 10.000
# LBFGS iter: 361, Loss total: 0.0007113228, E_PINN/E_real = 4.333 / 10.000
# LBFGS iter: 362, Loss total: 0.0007109348, E_PINN/E_real = 4.334 / 10.000
# LBFGS iter: 363, Loss total: 0.0007106824, E_PINN/E_real = 4.335 / 10.000
# LBFGS iter: 364, Loss total: 0.0007104693, E_PINN/E_real = 4.335 / 10.000
# LBFGS iter: 365, Loss total: 0.0007101567, E_PINN/E_real = 4.335 / 10.000
# LBFGS iter: 366, Loss total: 0.0007099384, E_PINN/E_real = 4.335 / 10.000
# LBFGS iter: 367, Loss total: 0.0007097954, E_PINN/E_real = 4.334 / 10.000
# LBFGS iter: 368, Loss total: 0.0007096869, E_PINN/E_real = 4.334 / 10.000
# LBFGS iter: 369, Loss total: 0.0007095317, E_PINN/E_real = 4.334 / 10.000
# LBFGS iter: 370, Loss total: 0.0007092820, E_PINN/E_real = 4.334 / 10.000
# LBFGS iter: 371, Loss total: 0.0007090127, E_PINN/E_real = 4.334 / 10.000
# LBFGS iter: 372, Loss total: 0.0007086523, E_PINN/E_real = 4.334 / 10.000
# LBFGS iter: 373, Loss total: 0.0007082921, E_PINN/E_real = 4.334 / 10.000
# LBFGS iter: 374, Loss total: 0.0007075522, E_PINN/E_real = 4.335 / 10.000
# LBFGS iter: 375, Loss total: 0.0007066979, E_PINN/E_real = 4.336 / 10.000
# LBFGS iter: 376, Loss total: 0.0007058964, E_PINN/E_real = 4.338 / 10.000
# LBFGS iter: 377, Loss total: 0.0007051547, E_PINN/E_real = 4.338 / 10.000
# LBFGS iter: 378, Loss total: 0.0007044264, E_PINN/E_real = 4.339 / 10.000
# LBFGS iter: 379, Loss total: 0.0007053440, E_PINN/E_real = 4.340 / 10.000
# LBFGS iter: 380, Loss total: 0.0007041396, E_PINN/E_real = 4.339 / 10.000
# LBFGS iter: 381, Loss total: 0.0007035118, E_PINN/E_real = 4.340 / 10.000
# LBFGS iter: 382, Loss total: 0.0007028922, E_PINN/E_real = 4.340 / 10.000
# LBFGS iter: 383, Loss total: 0.0007023779, E_PINN/E_real = 4.340 / 10.000
# LBFGS iter: 384, Loss total: 0.0007019582, E_PINN/E_real = 4.340 / 10.000
# LBFGS iter: 385, Loss total: 0.0007016617, E_PINN/E_real = 4.340 / 10.000
# LBFGS iter: 386, Loss total: 0.0007012214, E_PINN/E_real = 4.339 / 10.000
# LBFGS iter: 387, Loss total: 0.0007003773, E_PINN/E_real = 4.339 / 10.000
# LBFGS iter: 388, Loss total: 0.0006994717, E_PINN/E_real = 4.339 / 10.000
# LBFGS iter: 389, Loss total: 0.0006987088, E_PINN/E_real = 4.339 / 10.000
# LBFGS iter: 390, Loss total: 0.0006981639, E_PINN/E_real = 4.340 / 10.000
# LBFGS iter: 391, Loss total: 0.0006977827, E_PINN/E_real = 4.340 / 10.000
# LBFGS iter: 392, Loss total: 0.0006975265, E_PINN/E_real = 4.341 / 10.000
# LBFGS iter: 393, Loss total: 0.0006973518, E_PINN/E_real = 4.341 / 10.000
# LBFGS iter: 394, Loss total: 0.0006972127, E_PINN/E_real = 4.342 / 10.000
# LBFGS iter: 395, Loss total: 0.0006970657, E_PINN/E_real = 4.342 / 10.000
# LBFGS iter: 396, Loss total: 0.0006968696, E_PINN/E_real = 4.343 / 10.000
# LBFGS iter: 397, Loss total: 0.0006965542, E_PINN/E_real = 4.344 / 10.000
# LBFGS iter: 398, Loss total: 0.0006961714, E_PINN/E_real = 4.345 / 10.000
# LBFGS iter: 399, Loss total: 0.0006956671, E_PINN/E_real = 4.345 / 10.000
# LBFGS iter: 400, Loss total: 0.0006949875, E_PINN/E_real = 4.346 / 10.000
# LBFGS iter: 401, Loss total: 0.0006942771, E_PINN/E_real = 4.347 / 10.000
# LBFGS iter: 402, Loss total: 0.0006936872, E_PINN/E_real = 4.347 / 10.000
# LBFGS iter: 403, Loss total: 0.0006932135, E_PINN/E_real = 4.348 / 10.000
# LBFGS iter: 404, Loss total: 0.0006929088, E_PINN/E_real = 4.347 / 10.000
# LBFGS iter: 405, Loss total: 0.0006927080, E_PINN/E_real = 4.347 / 10.000
# LBFGS iter: 406, Loss total: 0.0006924051, E_PINN/E_real = 4.346 / 10.000
# LBFGS iter: 407, Loss total: 0.0006920827, E_PINN/E_real = 4.345 / 10.000
# LBFGS iter: 408, Loss total: 0.0006918681, E_PINN/E_real = 4.345 / 10.000
# LBFGS iter: 409, Loss total: 0.0006917030, E_PINN/E_real = 4.345 / 10.000
# LBFGS iter: 410, Loss total: 0.0006915517, E_PINN/E_real = 4.345 / 10.000
# LBFGS iter: 411, Loss total: 0.0006913051, E_PINN/E_real = 4.345 / 10.000
# LBFGS iter: 412, Loss total: 0.0006909766, E_PINN/E_real = 4.346 / 10.000
# LBFGS iter: 413, Loss total: 0.0006904540, E_PINN/E_real = 4.346 / 10.000
# LBFGS iter: 414, Loss total: 0.0006896661, E_PINN/E_real = 4.347 / 10.000
# LBFGS iter: 415, Loss total: 0.0006886593, E_PINN/E_real = 4.347 / 10.000
# LBFGS iter: 416, Loss total: 0.0006874896, E_PINN/E_real = 4.348 / 10.000
# LBFGS iter: 417, Loss total: 0.0006865287, E_PINN/E_real = 4.348 / 10.000
# LBFGS iter: 418, Loss total: 0.0006852989, E_PINN/E_real = 4.349 / 10.000
# LBFGS iter: 419, Loss total: 0.0006842294, E_PINN/E_real = 4.349 / 10.000
# LBFGS iter: 420, Loss total: 0.0006833434, E_PINN/E_real = 4.349 / 10.000
# LBFGS iter: 421, Loss total: 0.0006825482, E_PINN/E_real = 4.349 / 10.000
# LBFGS iter: 422, Loss total: 0.0006812497, E_PINN/E_real = 4.351 / 10.000
# LBFGS iter: 423, Loss total: 0.0006800604, E_PINN/E_real = 4.352 / 10.000
# LBFGS iter: 424, Loss total: 0.0006792255, E_PINN/E_real = 4.352 / 10.000
# LBFGS iter: 425, Loss total: 0.0006781690, E_PINN/E_real = 4.355 / 10.000
# LBFGS iter: 426, Loss total: 0.0006770573, E_PINN/E_real = 4.357 / 10.000
# LBFGS iter: 427, Loss total: 0.0006762372, E_PINN/E_real = 4.359 / 10.000
# LBFGS iter: 428, Loss total: 0.0006752242, E_PINN/E_real = 4.361 / 10.000
# LBFGS iter: 429, Loss total: 0.0006742040, E_PINN/E_real = 4.363 / 10.000
# LBFGS iter: 430, Loss total: 0.0006734005, E_PINN/E_real = 4.366 / 10.000
# LBFGS iter: 431, Loss total: 0.0006725736, E_PINN/E_real = 4.368 / 10.000
# LBFGS iter: 432, Loss total: 0.0006720317, E_PINN/E_real = 4.370 / 10.000
# LBFGS iter: 433, Loss total: 0.0006713496, E_PINN/E_real = 4.372 / 10.000
# LBFGS iter: 434, Loss total: 0.0006707376, E_PINN/E_real = 4.373 / 10.000
# LBFGS iter: 435, Loss total: 0.0006702242, E_PINN/E_real = 4.374 / 10.000
# LBFGS iter: 436, Loss total: 0.0006695465, E_PINN/E_real = 4.375 / 10.000
# LBFGS iter: 437, Loss total: 0.0006689820, E_PINN/E_real = 4.376 / 10.000
# LBFGS iter: 438, Loss total: 0.0006684648, E_PINN/E_real = 4.377 / 10.000
# LBFGS iter: 439, Loss total: 0.0006679036, E_PINN/E_real = 4.379 / 10.000
# LBFGS iter: 440, Loss total: 0.0006674258, E_PINN/E_real = 4.379 / 10.000
# LBFGS iter: 441, Loss total: 0.0006670172, E_PINN/E_real = 4.380 / 10.000
# LBFGS iter: 442, Loss total: 0.0006661291, E_PINN/E_real = 4.382 / 10.000
# LBFGS iter: 443, Loss total: 0.0006652782, E_PINN/E_real = 4.386 / 10.000
# LBFGS iter: 444, Loss total: 0.0006645473, E_PINN/E_real = 4.388 / 10.000
# LBFGS iter: 445, Loss total: 0.0006640036, E_PINN/E_real = 4.390 / 10.000
# LBFGS iter: 446, Loss total: 0.0006633459, E_PINN/E_real = 4.391 / 10.000
# LBFGS iter: 447, Loss total: 0.0006623867, E_PINN/E_real = 4.393 / 10.000
# LBFGS iter: 448, Loss total: 0.0006616740, E_PINN/E_real = 4.395 / 10.000
# LBFGS iter: 449, Loss total: 0.0006610844, E_PINN/E_real = 4.398 / 10.000
# LBFGS iter: 450, Loss total: 0.0006605772, E_PINN/E_real = 4.399 / 10.000
# LBFGS iter: 451, Loss total: 0.0006601191, E_PINN/E_real = 4.400 / 10.000
# LBFGS iter: 452, Loss total: 0.0006595998, E_PINN/E_real = 4.403 / 10.000
# LBFGS iter: 453, Loss total: 0.0006592236, E_PINN/E_real = 4.404 / 10.000
# LBFGS iter: 454, Loss total: 0.0006588770, E_PINN/E_real = 4.406 / 10.000
# LBFGS iter: 455, Loss total: 0.0006586048, E_PINN/E_real = 4.408 / 10.000
# LBFGS iter: 456, Loss total: 0.0006583586, E_PINN/E_real = 4.409 / 10.000
# LBFGS iter: 457, Loss total: 0.0006580294, E_PINN/E_real = 4.411 / 10.000
# LBFGS iter: 458, Loss total: 0.0006577093, E_PINN/E_real = 4.412 / 10.000
# LBFGS iter: 459, Loss total: 0.0006574822, E_PINN/E_real = 4.412 / 10.000
# LBFGS iter: 460, Loss total: 0.0006572569, E_PINN/E_real = 4.413 / 10.000
# LBFGS iter: 461, Loss total: 0.0006571116, E_PINN/E_real = 4.414 / 10.000
# LBFGS iter: 462, Loss total: 0.0006570046, E_PINN/E_real = 4.414 / 10.000
# LBFGS iter: 463, Loss total: 0.0006568855, E_PINN/E_real = 4.414 / 10.000
# LBFGS iter: 464, Loss total: 0.0006570957, E_PINN/E_real = 4.414 / 10.000
# LBFGS iter: 465, Loss total: 0.0006568152, E_PINN/E_real = 4.414 / 10.000
# LBFGS iter: 466, Loss total: 0.0006566034, E_PINN/E_real = 4.414 / 10.000
# LBFGS iter: 467, Loss total: 0.0006563505, E_PINN/E_real = 4.414 / 10.000
# LBFGS iter: 468, Loss total: 0.0006559921, E_PINN/E_real = 4.414 / 10.000
# LBFGS iter: 469, Loss total: 0.0006556422, E_PINN/E_real = 4.414 / 10.000
# LBFGS iter: 470, Loss total: 0.0006553179, E_PINN/E_real = 4.413 / 10.000
# LBFGS iter: 471, Loss total: 0.0006549903, E_PINN/E_real = 4.414 / 10.000
# LBFGS iter: 472, Loss total: 0.0006546759, E_PINN/E_real = 4.414 / 10.000
# LBFGS iter: 473, Loss total: 0.0006544216, E_PINN/E_real = 4.415 / 10.000
# LBFGS iter: 474, Loss total: 0.0006541544, E_PINN/E_real = 4.415 / 10.000
# LBFGS iter: 475, Loss total: 0.0006539769, E_PINN/E_real = 4.416 / 10.000
# LBFGS iter: 476, Loss total: 0.0006538238, E_PINN/E_real = 4.417 / 10.000
# LBFGS iter: 477, Loss total: 0.0006535903, E_PINN/E_real = 4.418 / 10.000
# LBFGS iter: 478, Loss total: 0.0006533542, E_PINN/E_real = 4.418 / 10.000
# LBFGS iter: 479, Loss total: 0.0006531535, E_PINN/E_real = 4.419 / 10.000
# LBFGS iter: 480, Loss total: 0.0006529336, E_PINN/E_real = 4.419 / 10.000
# LBFGS iter: 481, Loss total: 0.0006526182, E_PINN/E_real = 4.420 / 10.000
# LBFGS iter: 482, Loss total: 0.0006523518, E_PINN/E_real = 4.421 / 10.000
# LBFGS iter: 483, Loss total: 0.0006521396, E_PINN/E_real = 4.421 / 10.000
# LBFGS iter: 484, Loss total: 0.0006519310, E_PINN/E_real = 4.422 / 10.000
# LBFGS iter: 485, Loss total: 0.0006517509, E_PINN/E_real = 4.423 / 10.000
# LBFGS iter: 486, Loss total: 0.0006516048, E_PINN/E_real = 4.424 / 10.000
# LBFGS iter: 487, Loss total: 0.0006514502, E_PINN/E_real = 4.425 / 10.000
# LBFGS iter: 488, Loss total: 0.0006512473, E_PINN/E_real = 4.426 / 10.000
# LBFGS iter: 489, Loss total: 0.0006510151, E_PINN/E_real = 4.428 / 10.000
# LBFGS iter: 490, Loss total: 0.0006507387, E_PINN/E_real = 4.430 / 10.000
# LBFGS iter: 491, Loss total: 0.0006505778, E_PINN/E_real = 4.435 / 10.000
# LBFGS iter: 492, Loss total: 0.0006502676, E_PINN/E_real = 4.435 / 10.000
# LBFGS iter: 493, Loss total: 0.0006499816, E_PINN/E_real = 4.436 / 10.000
# LBFGS iter: 494, Loss total: 0.0006497117, E_PINN/E_real = 4.438 / 10.000
# LBFGS iter: 495, Loss total: 0.0006494281, E_PINN/E_real = 4.438 / 10.000
# LBFGS iter: 496, Loss total: 0.0006491849, E_PINN/E_real = 4.439 / 10.000
# LBFGS iter: 497, Loss total: 0.0006488235, E_PINN/E_real = 4.441 / 10.000
# LBFGS iter: 498, Loss total: 0.0006483349, E_PINN/E_real = 4.443 / 10.000
# LBFGS iter: 499, Loss total: 0.0006479150, E_PINN/E_real = 4.446 / 10.000
# LBFGS iter: 500, Loss total: 0.0006475932, E_PINN/E_real = 4.448 / 10.000
# LBFGS iter: 501, Loss total: 0.0006473802, E_PINN/E_real = 4.448 / 10.000
# LBFGS iter: 502, Loss total: 0.0006471683, E_PINN/E_real = 4.451 / 10.000
# LBFGS iter: 503, Loss total: 0.0006470096, E_PINN/E_real = 4.452 / 10.000
# LBFGS iter: 504, Loss total: 0.0006468507, E_PINN/E_real = 4.453 / 10.000
# LBFGS iter: 505, Loss total: 0.0006466893, E_PINN/E_real = 4.454 / 10.000
# LBFGS iter: 506, Loss total: 0.0006465212, E_PINN/E_real = 4.455 / 10.000
# LBFGS iter: 507, Loss total: 0.0006463796, E_PINN/E_real = 4.457 / 10.000
# LBFGS iter: 508, Loss total: 0.0006462271, E_PINN/E_real = 4.458 / 10.000
# LBFGS iter: 509, Loss total: 0.0006459969, E_PINN/E_real = 4.459 / 10.000
# LBFGS iter: 510, Loss total: 0.0006456428, E_PINN/E_real = 4.460 / 10.000
# LBFGS iter: 511, Loss total: 0.0006452363, E_PINN/E_real = 4.462 / 10.000
# LBFGS iter: 512, Loss total: 0.0006448920, E_PINN/E_real = 4.463 / 10.000
# LBFGS iter: 513, Loss total: 0.0006446118, E_PINN/E_real = 4.462 / 10.000
# LBFGS iter: 514, Loss total: 0.0006443123, E_PINN/E_real = 4.463 / 10.000
# LBFGS iter: 515, Loss total: 0.0006439649, E_PINN/E_real = 4.462 / 10.000
# LBFGS iter: 516, Loss total: 0.0006437066, E_PINN/E_real = 4.462 / 10.000
# LBFGS iter: 517, Loss total: 0.0006434651, E_PINN/E_real = 4.462 / 10.000
# LBFGS iter: 518, Loss total: 0.0006432438, E_PINN/E_real = 4.461 / 10.000
# LBFGS iter: 519, Loss total: 0.0006429829, E_PINN/E_real = 4.461 / 10.000
# LBFGS iter: 520, Loss total: 0.0006425857, E_PINN/E_real = 4.460 / 10.000
# LBFGS iter: 521, Loss total: 0.0006422134, E_PINN/E_real = 4.458 / 10.000
# LBFGS iter: 522, Loss total: 0.0006415668, E_PINN/E_real = 4.457 / 10.000
# LBFGS iter: 523, Loss total: 0.0006411288, E_PINN/E_real = 4.457 / 10.000
# LBFGS iter: 524, Loss total: 0.0006403722, E_PINN/E_real = 4.455 / 10.000
# LBFGS iter: 525, Loss total: 0.0006397827, E_PINN/E_real = 4.453 / 10.000
# LBFGS iter: 526, Loss total: 0.0006394930, E_PINN/E_real = 4.453 / 10.000
# LBFGS iter: 527, Loss total: 0.0006391504, E_PINN/E_real = 4.452 / 10.000
# LBFGS iter: 528, Loss total: 0.0006386832, E_PINN/E_real = 4.452 / 10.000
# LBFGS iter: 529, Loss total: 0.0006381285, E_PINN/E_real = 4.451 / 10.000
# LBFGS iter: 530, Loss total: 0.0006377047, E_PINN/E_real = 4.450 / 10.000
# LBFGS iter: 531, Loss total: 0.0006372434, E_PINN/E_real = 4.452 / 10.000
# LBFGS iter: 532, Loss total: 0.0006368894, E_PINN/E_real = 4.452 / 10.000
# LBFGS iter: 533, Loss total: 0.0006362704, E_PINN/E_real = 4.453 / 10.000
# LBFGS iter: 534, Loss total: 0.0006355103, E_PINN/E_real = 4.454 / 10.000
# LBFGS iter: 535, Loss total: 0.0006347847, E_PINN/E_real = 4.456 / 10.000
# LBFGS iter: 536, Loss total: 0.0006341717, E_PINN/E_real = 4.457 / 10.000
# LBFGS iter: 537, Loss total: 0.0006336098, E_PINN/E_real = 4.458 / 10.000
# LBFGS iter: 538, Loss total: 0.0006331489, E_PINN/E_real = 4.459 / 10.000
# LBFGS iter: 539, Loss total: 0.0006327555, E_PINN/E_real = 4.459 / 10.000
# LBFGS iter: 540, Loss total: 0.0006323132, E_PINN/E_real = 4.459 / 10.000
# LBFGS iter: 541, Loss total: 0.0006319563, E_PINN/E_real = 4.460 / 10.000
# LBFGS iter: 542, Loss total: 0.0006311759, E_PINN/E_real = 4.459 / 10.000
# LBFGS iter: 543, Loss total: 0.0006306535, E_PINN/E_real = 4.459 / 10.000
# LBFGS iter: 544, Loss total: 0.0006302875, E_PINN/E_real = 4.459 / 10.000
# LBFGS iter: 545, Loss total: 0.0006299673, E_PINN/E_real = 4.459 / 10.000
# LBFGS iter: 546, Loss total: 0.0006297008, E_PINN/E_real = 4.459 / 10.000
# LBFGS iter: 547, Loss total: 0.0006293856, E_PINN/E_real = 4.459 / 10.000
# LBFGS iter: 548, Loss total: 0.0006290954, E_PINN/E_real = 4.460 / 10.000
# LBFGS iter: 549, Loss total: 0.0006288954, E_PINN/E_real = 4.460 / 10.000
# LBFGS iter: 550, Loss total: 0.0006287374, E_PINN/E_real = 4.461 / 10.000
# LBFGS iter: 551, Loss total: 0.0006286370, E_PINN/E_real = 4.461 / 10.000
# LBFGS iter: 552, Loss total: 0.0006285124, E_PINN/E_real = 4.461 / 10.000
# LBFGS iter: 553, Loss total: 0.0006284588, E_PINN/E_real = 4.461 / 10.000
# LBFGS iter: 554, Loss total: 0.0006284050, E_PINN/E_real = 4.461 / 10.000
# LBFGS iter: 555, Loss total: 0.0006283256, E_PINN/E_real = 4.461 / 10.000
# LBFGS iter: 556, Loss total: 0.0006282282, E_PINN/E_real = 4.461 / 10.000
# LBFGS iter: 557, Loss total: 0.0006280920, E_PINN/E_real = 4.462 / 10.000
# LBFGS iter: 558, Loss total: 0.0006279008, E_PINN/E_real = 4.462 / 10.000
# LBFGS iter: 559, Loss total: 0.0006277184, E_PINN/E_real = 4.462 / 10.000
# LBFGS iter: 560, Loss total: 0.0006272964, E_PINN/E_real = 4.463 / 10.000
# LBFGS iter: 561, Loss total: 0.0006268111, E_PINN/E_real = 4.464 / 10.000
# LBFGS iter: 562, Loss total: 0.0006263595, E_PINN/E_real = 4.465 / 10.000
# LBFGS iter: 563, Loss total: 0.0006260441, E_PINN/E_real = 4.466 / 10.000
# LBFGS iter: 564, Loss total: 0.0006257177, E_PINN/E_real = 4.466 / 10.000
# LBFGS iter: 565, Loss total: 0.0006254273, E_PINN/E_real = 4.466 / 10.000
# LBFGS iter: 566, Loss total: 0.0006251650, E_PINN/E_real = 4.466 / 10.000
# LBFGS iter: 567, Loss total: 0.0006249128, E_PINN/E_real = 4.466 / 10.000
# LBFGS iter: 568, Loss total: 0.0006246340, E_PINN/E_real = 4.466 / 10.000
# LBFGS iter: 569, Loss total: 0.0006241297, E_PINN/E_real = 4.466 / 10.000
# LBFGS iter: 570, Loss total: 0.0006235986, E_PINN/E_real = 4.467 / 10.000
# LBFGS iter: 571, Loss total: 0.0006231213, E_PINN/E_real = 4.467 / 10.000
# LBFGS iter: 572, Loss total: 0.0006225239, E_PINN/E_real = 4.468 / 10.000
# LBFGS iter: 573, Loss total: 0.0006217881, E_PINN/E_real = 4.469 / 10.000
# LBFGS iter: 574, Loss total: 0.0006200524, E_PINN/E_real = 4.471 / 10.000
# LBFGS iter: 575, Loss total: 0.0006178307, E_PINN/E_real = 4.474 / 10.000
# LBFGS iter: 576, Loss total: 0.0006153696, E_PINN/E_real = 4.479 / 10.000
# LBFGS iter: 577, Loss total: 0.0006132268, E_PINN/E_real = 4.482 / 10.000
# LBFGS iter: 578, Loss total: 0.0006115010, E_PINN/E_real = 4.486 / 10.000
# LBFGS iter: 579, Loss total: 0.0006101574, E_PINN/E_real = 4.487 / 10.000
# LBFGS iter: 580, Loss total: 0.0006091589, E_PINN/E_real = 4.489 / 10.000
# LBFGS iter: 581, Loss total: 0.0006080496, E_PINN/E_real = 4.491 / 10.000
# LBFGS iter: 582, Loss total: 0.0006068557, E_PINN/E_real = 4.491 / 10.000
# LBFGS iter: 583, Loss total: 0.0006062121, E_PINN/E_real = 4.491 / 10.000
# LBFGS iter: 584, Loss total: 0.0006055056, E_PINN/E_real = 4.492 / 10.000
# LBFGS iter: 585, Loss total: 0.0006048825, E_PINN/E_real = 4.493 / 10.000
# LBFGS iter: 586, Loss total: 0.0006044940, E_PINN/E_real = 4.493 / 10.000
# LBFGS iter: 587, Loss total: 0.0006041639, E_PINN/E_real = 4.494 / 10.000
# LBFGS iter: 588, Loss total: 0.0006039570, E_PINN/E_real = 4.495 / 10.000
# LBFGS iter: 589, Loss total: 0.0006038369, E_PINN/E_real = 4.495 / 10.000
# LBFGS iter: 590, Loss total: 0.0006037536, E_PINN/E_real = 4.495 / 10.000
# LBFGS iter: 591, Loss total: 0.0006036771, E_PINN/E_real = 4.495 / 10.000
# LBFGS iter: 592, Loss total: 0.0006035733, E_PINN/E_real = 4.496 / 10.000
# LBFGS iter: 593, Loss total: 0.0006034594, E_PINN/E_real = 4.496 / 10.000
# LBFGS iter: 594, Loss total: 0.0006032753, E_PINN/E_real = 4.497 / 10.000
# LBFGS iter: 595, Loss total: 0.0006030737, E_PINN/E_real = 4.498 / 10.000
# LBFGS iter: 596, Loss total: 0.0006028331, E_PINN/E_real = 4.498 / 10.000
# LBFGS iter: 597, Loss total: 0.0006025373, E_PINN/E_real = 4.499 / 10.000
# LBFGS iter: 598, Loss total: 0.0006022851, E_PINN/E_real = 4.499 / 10.000
# LBFGS iter: 599, Loss total: 0.0006020913, E_PINN/E_real = 4.500 / 10.000
# LBFGS iter: 600, Loss total: 0.0006018407, E_PINN/E_real = 4.501 / 10.000
# LBFGS iter: 601, Loss total: 0.0006015503, E_PINN/E_real = 4.502 / 10.000
# LBFGS iter: 602, Loss total: 0.0006012905, E_PINN/E_real = 4.504 / 10.000
# LBFGS iter: 603, Loss total: 0.0006009270, E_PINN/E_real = 4.505 / 10.000
# LBFGS iter: 604, Loss total: 0.0006005665, E_PINN/E_real = 4.508 / 10.000
# LBFGS iter: 605, Loss total: 0.0006001373, E_PINN/E_real = 4.509 / 10.000
# LBFGS iter: 606, Loss total: 0.0005997742, E_PINN/E_real = 4.511 / 10.000
# LBFGS iter: 607, Loss total: 0.0005993646, E_PINN/E_real = 4.513 / 10.000
# LBFGS iter: 608, Loss total: 0.0005990865, E_PINN/E_real = 4.514 / 10.000
# LBFGS iter: 609, Loss total: 0.0005987778, E_PINN/E_real = 4.516 / 10.000
# LBFGS iter: 610, Loss total: 0.0005985177, E_PINN/E_real = 4.518 / 10.000
# LBFGS iter: 611, Loss total: 0.0005984176, E_PINN/E_real = 4.521 / 10.000
# LBFGS iter: 612, Loss total: 0.0005982502, E_PINN/E_real = 4.521 / 10.000
# LBFGS iter: 613, Loss total: 0.0005981016, E_PINN/E_real = 4.521 / 10.000
# LBFGS iter: 614, Loss total: 0.0005979479, E_PINN/E_real = 4.522 / 10.000
# LBFGS iter: 615, Loss total: 0.0005978593, E_PINN/E_real = 4.523 / 10.000
# LBFGS iter: 616, Loss total: 0.0005977457, E_PINN/E_real = 4.524 / 10.000
# LBFGS iter: 617, Loss total: 0.0005976592, E_PINN/E_real = 4.525 / 10.000
# LBFGS iter: 618, Loss total: 0.0005975660, E_PINN/E_real = 4.526 / 10.000
# LBFGS iter: 619, Loss total: 0.0005974913, E_PINN/E_real = 4.526 / 10.000
# LBFGS iter: 620, Loss total: 0.0005974160, E_PINN/E_real = 4.527 / 10.000
# LBFGS iter: 621, Loss total: 0.0005973375, E_PINN/E_real = 4.528 / 10.000
# LBFGS iter: 622, Loss total: 0.0005972480, E_PINN/E_real = 4.528 / 10.000
# LBFGS iter: 623, Loss total: 0.0005971594, E_PINN/E_real = 4.529 / 10.000
# LBFGS iter: 624, Loss total: 0.0005970448, E_PINN/E_real = 4.530 / 10.000
# LBFGS iter: 625, Loss total: 0.0005968695, E_PINN/E_real = 4.532 / 10.000
# LBFGS iter: 626, Loss total: 0.0005965941, E_PINN/E_real = 4.534 / 10.000
# LBFGS iter: 627, Loss total: 0.0005963263, E_PINN/E_real = 4.536 / 10.000
# LBFGS iter: 628, Loss total: 0.0005959335, E_PINN/E_real = 4.538 / 10.000
# LBFGS iter: 629, Loss total: 0.0005956609, E_PINN/E_real = 4.539 / 10.000
# LBFGS iter: 630, Loss total: 0.0005962900, E_PINN/E_real = 4.543 / 10.000
# LBFGS iter: 631, Loss total: 0.0005954963, E_PINN/E_real = 4.540 / 10.000
# LBFGS iter: 632, Loss total: 0.0005949595, E_PINN/E_real = 4.542 / 10.000
# LBFGS iter: 633, Loss total: 0.0005946853, E_PINN/E_real = 4.543 / 10.000
# LBFGS iter: 634, Loss total: 0.0005945109, E_PINN/E_real = 4.543 / 10.000
# LBFGS iter: 635, Loss total: 0.0005943780, E_PINN/E_real = 4.544 / 10.000
# LBFGS iter: 636, Loss total: 0.0005942467, E_PINN/E_real = 4.544 / 10.000
# LBFGS iter: 637, Loss total: 0.0005941013, E_PINN/E_real = 4.545 / 10.000
# LBFGS iter: 638, Loss total: 0.0005939444, E_PINN/E_real = 4.545 / 10.000
# LBFGS iter: 639, Loss total: 0.0005937485, E_PINN/E_real = 4.545 / 10.000
# LBFGS iter: 640, Loss total: 0.0005935479, E_PINN/E_real = 4.546 / 10.000
# LBFGS iter: 641, Loss total: 0.0005932861, E_PINN/E_real = 4.546 / 10.000
# LBFGS iter: 642, Loss total: 0.0005930543, E_PINN/E_real = 4.546 / 10.000
# LBFGS iter: 643, Loss total: 0.0005928685, E_PINN/E_real = 4.547 / 10.000
# LBFGS iter: 644, Loss total: 0.0005927066, E_PINN/E_real = 4.547 / 10.000
# LBFGS iter: 645, Loss total: 0.0005925315, E_PINN/E_real = 4.548 / 10.000
# LBFGS iter: 646, Loss total: 0.0005923167, E_PINN/E_real = 4.549 / 10.000
# LBFGS iter: 647, Loss total: 0.0005921746, E_PINN/E_real = 4.552 / 10.000
# LBFGS iter: 648, Loss total: 0.0005920787, E_PINN/E_real = 4.551 / 10.000
# LBFGS iter: 649, Loss total: 0.0005918921, E_PINN/E_real = 4.551 / 10.000
# ...
# LBFGS iter: 932, Loss total: 0.0005009728, E_PINN/E_real = 4.877 / 10.000
# LBFGS iter: 933, Loss total: 0.0005007994, E_PINN/E_real = 4.877 / 10.000
# LBFGS iter: 934, Loss total: 0.0005006733, E_PINN/E_real = 4.877 / 10.000
# LBFGS iter: 935, Loss total: 0.0005005907, E_PINN/E_real = 4.878 / 10.000
# LBFGS iter: 936, Loss total: 0.0005004680, E_PINN/E_real = 4.878 / 10.000
# LBFGS iter: 937, Loss total: 0.0005002366, E_PINN/E_real = 4.878 / 10.000
# LBFGS iter: 938, Loss total: 0.0004999222, E_PINN/E_real = 4.878 / 10.000
# LBFGS iter: 939, Loss total: 0.0004995578, E_PINN/E_real = 4.879 / 10.000
# LBFGS iter: 940, Loss total: 0.0004991522, E_PINN/E_real = 4.879 / 10.000
# LBFGS iter: 941, Loss total: 0.0004986409, E_PINN/E_real = 4.880 / 10.000
# LBFGS iter: 942, Loss total: 0.0004981530, E_PINN/E_real = 4.881 / 10.000
# LBFGS iter: 943, Loss total: 0.0004975857, E_PINN/E_real = 4.883 / 10.000
# LBFGS iter: 944, Loss total: 0.0004972023, E_PINN/E_real = 4.886 / 10.000
# LBFGS iter: 945, Loss total: 0.0004969530, E_PINN/E_real = 4.887 / 10.000
# LBFGS iter: 946, Loss total: 0.0004966172, E_PINN/E_real = 4.889 / 10.000
# LBFGS iter: 947, Loss total: 0.0004962598, E_PINN/E_real = 4.891 / 10.000
# LBFGS iter: 948, Loss total: 0.0004959178, E_PINN/E_real = 4.893 / 10.000
# LBFGS iter: 949, Loss total: 0.0004955692, E_PINN/E_real = 4.896 / 10.000
# LBFGS iter: 950, Loss total: 0.0004952329, E_PINN/E_real = 4.899 / 10.000
# LBFGS iter: 951, Loss total: 0.0004948560, E_PINN/E_real = 4.900 / 10.000
# LBFGS iter: 952, Loss total: 0.0004945527, E_PINN/E_real = 4.901 / 10.000
# LBFGS iter: 953, Loss total: 0.0004942833, E_PINN/E_real = 4.902 / 10.000
# LBFGS iter: 954, Loss total: 0.0004941326, E_PINN/E_real = 4.902 / 10.000
# LBFGS iter: 955, Loss total: 0.0004939709, E_PINN/E_real = 4.904 / 10.000
# LBFGS iter: 956, Loss total: 0.0004939019, E_PINN/E_real = 4.904 / 10.000
# LBFGS iter: 957, Loss total: 0.0004937534, E_PINN/E_real = 4.905 / 10.000
# LBFGS iter: 958, Loss total: 0.0004935889, E_PINN/E_real = 4.906 / 10.000
# LBFGS iter: 959, Loss total: 0.0004934381, E_PINN/E_real = 4.907 / 10.000
# LBFGS iter: 960, Loss total: 0.0004932929, E_PINN/E_real = 4.908 / 10.000
# LBFGS iter: 961, Loss total: 0.0004931523, E_PINN/E_real = 4.909 / 10.000
# LBFGS iter: 962, Loss total: 0.0004929866, E_PINN/E_real = 4.910 / 10.000
# LBFGS iter: 963, Loss total: 0.0004928008, E_PINN/E_real = 4.912 / 10.000
# LBFGS iter: 964, Loss total: 0.0004925354, E_PINN/E_real = 4.913 / 10.000
# LBFGS iter: 965, Loss total: 0.0004923278, E_PINN/E_real = 4.915 / 10.000
# LBFGS iter: 966, Loss total: 0.0004921014, E_PINN/E_real = 4.916 / 10.000
# LBFGS iter: 967, Loss total: 0.0004917270, E_PINN/E_real = 4.918 / 10.000
# LBFGS iter: 968, Loss total: 0.0004914153, E_PINN/E_real = 4.919 / 10.000
# LBFGS iter: 969, Loss total: 0.0004912293, E_PINN/E_real = 4.919 / 10.000
# LBFGS iter: 970, Loss total: 0.0004911144, E_PINN/E_real = 4.919 / 10.000
# LBFGS iter: 971, Loss total: 0.0004908668, E_PINN/E_real = 4.919 / 10.000
# LBFGS iter: 972, Loss total: 0.0004906421, E_PINN/E_real = 4.918 / 10.000
# LBFGS iter: 973, Loss total: 0.0004904100, E_PINN/E_real = 4.918 / 10.000
# LBFGS iter: 974, Loss total: 0.0004902216, E_PINN/E_real = 4.917 / 10.000
# LBFGS iter: 975, Loss total: 0.0004900161, E_PINN/E_real = 4.917 / 10.000
# LBFGS iter: 976, Loss total: 0.0004897758, E_PINN/E_real = 4.917 / 10.000
# LBFGS iter: 977, Loss total: 0.0004894577, E_PINN/E_real = 4.916 / 10.000
# LBFGS iter: 978, Loss total: 0.0004891724, E_PINN/E_real = 4.916 / 10.000
# LBFGS iter: 979, Loss total: 0.0004888957, E_PINN/E_real = 4.915 / 10.000
# LBFGS iter: 980, Loss total: 0.0004885703, E_PINN/E_real = 4.914 / 10.000
# LBFGS iter: 981, Loss total: 0.0004882439, E_PINN/E_real = 4.913 / 10.000
# LBFGS iter: 982, Loss total: 0.0004880055, E_PINN/E_real = 4.910 / 10.000
# LBFGS iter: 983, Loss total: 0.0004877762, E_PINN/E_real = 4.910 / 10.000
# LBFGS iter: 984, Loss total: 0.0004874580, E_PINN/E_real = 4.908 / 10.000
# LBFGS iter: 985, Loss total: 0.0004870798, E_PINN/E_real = 4.907 / 10.000
# LBFGS iter: 986, Loss total: 0.0004869010, E_PINN/E_real = 4.907 / 10.000
# LBFGS iter: 987, Loss total: 0.0004863959, E_PINN/E_real = 4.905 / 10.000
# LBFGS iter: 988, Loss total: 0.0004860266, E_PINN/E_real = 4.903 / 10.000
# LBFGS iter: 989, Loss total: 0.0004856976, E_PINN/E_real = 4.902 / 10.000
# LBFGS iter: 990, Loss total: 0.0004853091, E_PINN/E_real = 4.901 / 10.000
# LBFGS iter: 991, Loss total: 0.0004849819, E_PINN/E_real = 4.900 / 10.000
# LBFGS iter: 992, Loss total: 0.0004847369, E_PINN/E_real = 4.899 / 10.000
# LBFGS iter: 993, Loss total: 0.0004845044, E_PINN/E_real = 4.900 / 10.000
# LBFGS iter: 994, Loss total: 0.0004843166, E_PINN/E_real = 4.901 / 10.000
# LBFGS iter: 995, Loss total: 0.0004840409, E_PINN/E_real = 4.903 / 10.000
# LBFGS iter: 996, Loss total: 0.0004837394, E_PINN/E_real = 4.905 / 10.000
# LBFGS iter: 997, Loss total: 0.0004834129, E_PINN/E_real = 4.908 / 10.000
# LBFGS iter: 998, Loss total: 0.0004831341, E_PINN/E_real = 4.910 / 10.000
# LBFGS iter: 999, Loss total: 0.0004828744, E_PINN/E_real = 4.912 / 10.000
# LBFGS iter: 1000, Loss total: 0.0004826700, E_PINN/E_real = 4.914 / 10.000
# LBFGS iter: 1001, Loss total: 0.0004825242, E_PINN/E_real = 4.915 / 10.000
# LBFGS iter: 1002, Loss total: 0.0004823793, E_PINN/E_real = 4.916 / 10.000
# LBFGS iter: 1003, Loss total: 0.0004834426, E_PINN/E_real = 4.921 / 10.000
# LBFGS iter: 1004, Loss total: 0.0004823277, E_PINN/E_real = 4.917 / 10.000
# LBFGS iter: 1005, Loss total: 0.0004822444, E_PINN/E_real = 4.919 / 10.000
# LBFGS iter: 1006, Loss total: 0.0004820198, E_PINN/E_real = 4.919 / 10.000
# LBFGS iter: 1007, Loss total: 0.0004817618, E_PINN/E_real = 4.920 / 10.000
# LBFGS iter: 1008, Loss total: 0.0004814110, E_PINN/E_real = 4.921 / 10.000
# LBFGS iter: 1009, Loss total: 0.0004810979, E_PINN/E_real = 4.922 / 10.000
# LBFGS iter: 1010, Loss total: 0.0004806918, E_PINN/E_real = 4.923 / 10.000
# LBFGS iter: 1011, Loss total: 0.0004802182, E_PINN/E_real = 4.924 / 10.000
# LBFGS iter: 1012, Loss total: 0.0004798102, E_PINN/E_real = 4.925 / 10.000
# LBFGS iter: 1013, Loss total: 0.0004793960, E_PINN/E_real = 4.927 / 10.000
# LBFGS iter: 1014, Loss total: 0.0004789462, E_PINN/E_real = 4.928 / 10.000
# LBFGS iter: 1015, Loss total: 0.0004783242, E_PINN/E_real = 4.930 / 10.000
# LBFGS iter: 1016, Loss total: 0.0004776814, E_PINN/E_real = 4.932 / 10.000
# LBFGS iter: 1017, Loss total: 0.0004771983, E_PINN/E_real = 4.933 / 10.000
# LBFGS iter: 1018, Loss total: 0.0004768356, E_PINN/E_real = 4.936 / 10.000
# LBFGS iter: 1019, Loss total: 0.0004766547, E_PINN/E_real = 4.937 / 10.000
# LBFGS iter: 1020, Loss total: 0.0004764929, E_PINN/E_real = 4.938 / 10.000
# LBFGS iter: 1021, Loss total: 0.0004762914, E_PINN/E_real = 4.940 / 10.000
# LBFGS iter: 1022, Loss total: 0.0004760818, E_PINN/E_real = 4.942 / 10.000
# LBFGS iter: 1023, Loss total: 0.0004758978, E_PINN/E_real = 4.944 / 10.000
# LBFGS iter: 1024, Loss total: 0.0004757443, E_PINN/E_real = 4.946 / 10.000
# LBFGS iter: 1025, Loss total: 0.0004756542, E_PINN/E_real = 4.947 / 10.000
# LBFGS iter: 1026, Loss total: 0.0004755837, E_PINN/E_real = 4.948 / 10.000
# LBFGS iter: 1027, Loss total: 0.0004755183, E_PINN/E_real = 4.948 / 10.000
# LBFGS iter: 1028, Loss total: 0.0004754714, E_PINN/E_real = 4.948 / 10.000
# LBFGS iter: 1029, Loss total: 0.0004754304, E_PINN/E_real = 4.948 / 10.000
# LBFGS iter: 1030, Loss total: 0.0004753770, E_PINN/E_real = 4.948 / 10.000
# LBFGS iter: 1031, Loss total: 0.0004753396, E_PINN/E_real = 4.948 / 10.000
# LBFGS iter: 1032, Loss total: 0.0004752901, E_PINN/E_real = 4.948 / 10.000
# LBFGS iter: 1033, Loss total: 0.0004752194, E_PINN/E_real = 4.947 / 10.000
# LBFGS iter: 1034, Loss total: 0.0004751489, E_PINN/E_real = 4.947 / 10.000
# LBFGS iter: 1035, Loss total: 0.0004750873, E_PINN/E_real = 4.947 / 10.000
# LBFGS iter: 1036, Loss total: 0.0004750351, E_PINN/E_real = 4.948 / 10.000
# LBFGS iter: 1037, Loss total: 0.0004748846, E_PINN/E_real = 4.948 / 10.000
# LBFGS iter: 1038, Loss total: 0.0004746932, E_PINN/E_real = 4.950 / 10.000
# LBFGS iter: 1039, Loss total: 0.0004744300, E_PINN/E_real = 4.952 / 10.000
# LBFGS iter: 1040, Loss total: 0.0004740398, E_PINN/E_real = 4.956 / 10.000
# LBFGS iter: 1041, Loss total: 0.0004736019, E_PINN/E_real = 4.960 / 10.000
# LBFGS iter: 1042, Loss total: 0.0004731688, E_PINN/E_real = 4.964 / 10.000
# LBFGS iter: 1043, Loss total: 0.0004726161, E_PINN/E_real = 4.968 / 10.000
# LBFGS iter: 1044, Loss total: 0.0004720844, E_PINN/E_real = 4.976 / 10.000
# LBFGS iter: 1045, Loss total: 0.0004713931, E_PINN/E_real = 4.978 / 10.000
# LBFGS iter: 1046, Loss total: 0.0004711426, E_PINN/E_real = 4.981 / 10.000
# LBFGS iter: 1047, Loss total: 0.0004708173, E_PINN/E_real = 4.984 / 10.000
# LBFGS iter: 1048, Loss total: 0.0004703049, E_PINN/E_real = 4.991 / 10.000
# LBFGS iter: 1049, Loss total: 0.0004699061, E_PINN/E_real = 4.992 / 10.000
# LBFGS iter: 1050, Loss total: 0.0004689877, E_PINN/E_real = 4.998 / 10.000
# LBFGS iter: 1051, Loss total: 0.0004680170, E_PINN/E_real = 5.003 / 10.000
# LBFGS iter: 1052, Loss total: 0.0004674482, E_PINN/E_real = 5.008 / 10.000
# LBFGS iter: 1053, Loss total: 0.0004668598, E_PINN/E_real = 5.015 / 10.000
# LBFGS iter: 1054, Loss total: 0.0004662455, E_PINN/E_real = 5.019 / 10.000
# LBFGS iter: 1055, Loss total: 0.0004658527, E_PINN/E_real = 5.020 / 10.000
# LBFGS iter: 1056, Loss total: 0.0004669882, E_PINN/E_real = 5.034 / 10.000
# LBFGS iter: 1057, Loss total: 0.0004655491, E_PINN/E_real = 5.025 / 10.000
# LBFGS iter: 1058, Loss total: 0.0004651236, E_PINN/E_real = 5.029 / 10.000
# LBFGS iter: 1059, Loss total: 0.0004647953, E_PINN/E_real = 5.031 / 10.000
# LBFGS iter: 1060, Loss total: 0.0004643788, E_PINN/E_real = 5.035 / 10.000
# LBFGS iter: 1061, Loss total: 0.0004640633, E_PINN/E_real = 5.041 / 10.000
# LBFGS iter: 1062, Loss total: 0.0004637143, E_PINN/E_real = 5.044 / 10.000
# LBFGS iter: 1063, Loss total: 0.0004635264, E_PINN/E_real = 5.045 / 10.000
# LBFGS iter: 1064, Loss total: 0.0004633659, E_PINN/E_real = 5.048 / 10.000
# LBFGS iter: 1065, Loss total: 0.0004632119, E_PINN/E_real = 5.049 / 10.000
# LBFGS iter: 1066, Loss total: 0.0004630986, E_PINN/E_real = 5.051 / 10.000
# LBFGS iter: 1067, Loss total: 0.0004629258, E_PINN/E_real = 5.052 / 10.000
# LBFGS iter: 1068, Loss total: 0.0004627828, E_PINN/E_real = 5.053 / 10.000
# LBFGS iter: 1069, Loss total: 0.0004625437, E_PINN/E_real = 5.055 / 10.000
# LBFGS iter: 1070, Loss total: 0.0004623526, E_PINN/E_real = 5.057 / 10.000
# LBFGS iter: 1071, Loss total: 0.0005051126, E_PINN/E_real = 5.083 / 10.000
# LBFGS iter: 1072, Loss total: 0.0004621619, E_PINN/E_real = 5.059 / 10.000
# LBFGS iter: 1073, Loss total: 0.0004620048, E_PINN/E_real = 5.060 / 10.000
# LBFGS iter: 1074, Loss total: 0.0004617390, E_PINN/E_real = 5.059 / 10.000
# LBFGS iter: 1075, Loss total: 0.0004614711, E_PINN/E_real = 5.059 / 10.000
# LBFGS iter: 1076, Loss total: 0.0004612059, E_PINN/E_real = 5.058 / 10.000
# LBFGS iter: 1077, Loss total: 0.0004609222, E_PINN/E_real = 5.058 / 10.000
# LBFGS iter: 1078, Loss total: 0.0004609732, E_PINN/E_real = 5.056 / 10.000
# LBFGS iter: 1079, Loss total: 0.0004607130, E_PINN/E_real = 5.057 / 10.000
# LBFGS iter: 1080, Loss total: 0.0004602195, E_PINN/E_real = 5.056 / 10.000
# LBFGS iter: 1081, Loss total: 0.0004598239, E_PINN/E_real = 5.056 / 10.000
# LBFGS iter: 1082, Loss total: 0.0004589401, E_PINN/E_real = 5.057 / 10.000
# LBFGS iter: 1083, Loss total: 0.0004581895, E_PINN/E_real = 5.059 / 10.000
# LBFGS iter: 1084, Loss total: 0.0004574913, E_PINN/E_real = 5.060 / 10.000
# LBFGS iter: 1085, Loss total: 0.0004567413, E_PINN/E_real = 5.066 / 10.000
# LBFGS iter: 1086, Loss total: 0.0004557869, E_PINN/E_real = 5.069 / 10.000
# LBFGS iter: 1087, Loss total: 0.0004544900, E_PINN/E_real = 5.071 / 10.000
# LBFGS iter: 1088, Loss total: 0.0004529066, E_PINN/E_real = 5.077 / 10.000
# LBFGS iter: 1089, Loss total: 0.0004520024, E_PINN/E_real = 5.080 / 10.000
# LBFGS iter: 1090, Loss total: 0.0004515160, E_PINN/E_real = 5.080 / 10.000
# LBFGS iter: 1091, Loss total: 0.0004509900, E_PINN/E_real = 5.083 / 10.000
# LBFGS iter: 1092, Loss total: 0.0004506795, E_PINN/E_real = 5.082 / 10.000
# LBFGS iter: 1093, Loss total: 0.0004503412, E_PINN/E_real = 5.082 / 10.000
# LBFGS iter: 1094, Loss total: 0.0004499421, E_PINN/E_real = 5.081 / 10.000
# LBFGS iter: 1095, Loss total: 0.0004496272, E_PINN/E_real = 5.082 / 10.000
# LBFGS iter: 1096, Loss total: 0.0004493615, E_PINN/E_real = 5.082 / 10.000
# LBFGS iter: 1097, Loss total: 0.0004490719, E_PINN/E_real = 5.082 / 10.000
# LBFGS iter: 1098, Loss total: 0.0004487824, E_PINN/E_real = 5.082 / 10.000
# LBFGS iter: 1099, Loss total: 0.0004486046, E_PINN/E_real = 5.081 / 10.000
# LBFGS iter: 1100, Loss total: 0.0004484321, E_PINN/E_real = 5.081 / 10.000
# LBFGS iter: 1101, Loss total: 0.0004483358, E_PINN/E_real = 5.081 / 10.000
# LBFGS iter: 1102, Loss total: 0.0004482009, E_PINN/E_real = 5.080 / 10.000
# LBFGS iter: 1103, Loss total: 0.0004479016, E_PINN/E_real = 5.079 / 10.000
# LBFGS iter: 1104, Loss total: 0.0004474014, E_PINN/E_real = 5.078 / 10.000
# LBFGS iter: 1105, Loss total: 0.0004468111, E_PINN/E_real = 5.076 / 10.000
# LBFGS iter: 1106, Loss total: 0.0004461452, E_PINN/E_real = 5.074 / 10.000
# LBFGS iter: 1107, Loss total: 0.0004454242, E_PINN/E_real = 5.072 / 10.000
# LBFGS iter: 1108, Loss total: 0.0004450807, E_PINN/E_real = 5.071 / 10.000
# LBFGS iter: 1109, Loss total: 0.0004445465, E_PINN/E_real = 5.070 / 10.000
# LBFGS iter: 1110, Loss total: 0.0004443442, E_PINN/E_real = 5.070 / 10.000
# LBFGS iter: 1111, Loss total: 0.0004441578, E_PINN/E_real = 5.071 / 10.000
# LBFGS iter: 1112, Loss total: 0.0004440046, E_PINN/E_real = 5.071 / 10.000
# LBFGS iter: 1113, Loss total: 0.0004438588, E_PINN/E_real = 5.072 / 10.000
# LBFGS iter: 1114, Loss total: 0.0004436956, E_PINN/E_real = 5.073 / 10.000
# LBFGS iter: 1115, Loss total: 0.0004435364, E_PINN/E_real = 5.073 / 10.000
# LBFGS iter: 1116, Loss total: 0.0004433927, E_PINN/E_real = 5.074 / 10.000
# LBFGS iter: 1117, Loss total: 0.0004432335, E_PINN/E_real = 5.074 / 10.000
# LBFGS iter: 1118, Loss total: 0.0004430892, E_PINN/E_real = 5.074 / 10.000
# LBFGS iter: 1119, Loss total: 0.0004428720, E_PINN/E_real = 5.074 / 10.000
# LBFGS iter: 1120, Loss total: 0.0004425576, E_PINN/E_real = 5.073 / 10.000
# LBFGS iter: 1121, Loss total: 0.0004422545, E_PINN/E_real = 5.073 / 10.000
# LBFGS iter: 1122, Loss total: 0.0004416797, E_PINN/E_real = 5.073 / 10.000
# LBFGS iter: 1123, Loss total: 0.0004411348, E_PINN/E_real = 5.074 / 10.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-2cbd1dbc71da> in <cell line: 0>()
#      66                                     history_size = 100)
#      67
# ---> 68     optimizer.step(pinn.closure)
#      69
#      70     elapsed_time_LBFGS = (time.time() - start_time_LBFGS)/60
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     491                             )
#     492
# --> 493                 out = func(*args, **kwargs)
#     494                 self._optimizer_step_code()
#     495
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/lbfgs.py in step(self, closure)
#     442                         return self._directional_evaluate(closure, x, t, d)
#     443
# --> 444                     loss, flat_grad, t, ls_func_evals = _strong_wolfe(
#     445                         obj_func, x_init, t, d, loss, flat_grad, gtd
#     446                     )
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/lbfgs.py in _strong_wolfe(obj_func, x, t, d, f, g, gtd, c1, c2, tolerance_change, max_ls)
#      63             break
#      64
# ---> 65         if abs(gtd_new) <= -c2 * gtd:
#      66             bracket = [t]
#      67             bracket_f = [f_new]
#
# KeyboardInterrupt:

# %% [markdown]
# ## Loss evolution

# %%
# print los history with log scale
plt.plot(w_loss_d*pinn.loss_history["Data"], label='Data')
plt.plot(w_loss_f*pinn.loss_history["PDE"], label='PDE')
plt.plot(w_loss_bc*pinn.loss_history["BC"], label='BC')
plt.plot(pinn.loss_history["Total"], label='Total')
plt.yscale('log')
plt.xlabel('# Iterations')
plt.ylabel(r'$\log_{10}$ Loss')
# grid
plt.grid(True, which="both", ls="-")
plt.legend()
plt.show()

# %% [markdown]
# # Verification

# %% [markdown]
# ## Parameter Evolution

# %%
# Plot mesh of displacements and original position in red and blue respectively

################################################ COMPLETAR
# Compute X_real, Xfinal_real y X_finalpred

plt.scatter(X_real[:,0], X_real[:,1], c='k', label='Inicial', s=30, alpha=0.5)
plt.scatter(X_final_real[:,0], X_final_real[:,1], c="blue", label='Real', s=30)
plt.scatter(X_final_pred[:,0], X_final_pred[:,1], c='r', label='Predicted', s=5)
plt.xlim(-16, 16)
plt.ylim(-6, 10)
plt.legend(loc='best')
# define size of figure
fig = plt.gcf()
fig.set_size_inches(20, 10)

plt.show()

# %%
# plor G_real and G_PINN evolution
plt.plot(pinn.params_history["E"], label='E_PINN')
plt.plot(np.ones(len(pinn.params_history["E"]))*E_real, label='E_real')
plt.legend()
# add axe legend
plt.xlabel('# Iterations')
plt.ylabel('E')
plt.grid(True, which="both", ls="-")

plt.show()
