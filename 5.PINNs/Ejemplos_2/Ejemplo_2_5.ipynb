# %% [markdown]
# # Problema: Masa Resorte Amortiguador

# %%
# Librerias utiles
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import imageio.v2 as imageio
from google.colab import drive
from google.colab import files
from os import TMP_MAX

# %% [markdown]
# # Modelo Físico

# %%
# Parámetros físicos
l0 = 0.25 # m
g = 9.81  # m/s^2
m = 1     # kg
b = 0.5     # Ns/m
k = 2    # N/m
tiempo_total = 20 # s
delta_T = 0.01 # s
t_datos = 0.5*tiempo_total

# %%
# Calculo de parámetros útiles
omega = np.sqrt(k/m)
seda  = b/(2*np.sqrt(m*k))
phi = np.arctan(-seda)
# Definir el vector de tiempo
t = np.arange(0, tiempo_total, delta_T)

print(f"omega = {omega}")
print(f"seda = {seda}")
print(f"phi = {phi}")
# Out:
# omega = 1.4142135623730951
# seda = 0.17677669529663687
# phi = -0.17496904566568885

# %%
# Calcular desplazamiento y posición
def desplazamiento(tiempo):
  despl = (g / omega**2) * (1 - np.exp(-seda * omega * tiempo)* np.cos(omega * tiempo + phi)/np.cos(phi))
  return despl

u = desplazamiento(t)
x = u + l0

# %%
# Graficar
plt.figure(figsize=(8, 5))
plt.plot(t, x, linewidth=2)
plt.xlabel('Time (s)')
plt.ylabel('Displacement (m)')
plt.grid(True)
plt.title('Displacement vs Time')
plt.show()

# %% [markdown]
# # Parámetros para Modelos Predictivos

# %%
# Crear datos de entrada para la red neuronal
# X es un vector de n valores seleccionados entre 0 y 10
n = 25 # Numero de muestras
t_max = t_datos # Tiempo maximo
t_min = 0 # Tiempo minimo
X = np.arange(t_min, t_max, (t_max-t_min)/n)
y = desplazamiento(X)
X_collocation = np.arange(0.0, tiempo_total, tiempo_total/100)
X_i = np.array([[0.0]])
b_init = np.array([[0.0]])

# %%
# Convertir a tensores de PyTorch
X_train = torch.tensor(X, dtype=torch.float32).reshape(-1, 1)
X_test  = torch.tensor(t, dtype=torch.float32).reshape(-1, 1)
y_train = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)
y_test  = torch.tensor(u, dtype=torch.float32).reshape(-1, 1)
X_train_phy = torch.tensor(X_collocation, dtype=torch.float32).reshape(-1, 1)
X_init = torch.tensor(X_i, dtype=torch.float32).reshape(-1, 1)

# %%
# Parametros de la Red Neuronal
epochs_FFNN = 10000
epochs_PINN = 50000
epochs_PINN_id = 100000
epochs_PINN_adm_id = 500000
learning_rate = 2e-4
nneurons = 64
nhiden_layers = 4
activation_fn = nn.Tanh()
make_video = False

input_dim = X_train.shape[1]
output_dim = y_train.shape[1]
layers = np.array([input_dim] + [ nneurons for i in range(nhiden_layers)] + [output_dim])

# %% [markdown]
# # Modelo adimensionalizado

# %% [markdown]
# ## Adimensionalizando... 📏

# %%
# Variables de adimensionalizacion
U_ref = m*g/k
T_ref = 1/omega

# Admiensionalizacion
X_train_adm = X_train/T_ref
y_train_adm = y_train/U_ref
X_test_adm  = X_test/T_ref
y_test_adm  = y_test/U_ref
X_train_phy_adm = X_train_phy/T_ref
X_init_adm = X_init/T_ref
#Y_init = torch.tensor([0.0, 0.0, 0.0])
#y_init_adm = torch.tensor([0.0])/U_ref
#dy_init_adm = torch.tensor([0.0])*T_ref/U_ref
#ddy_init_adm = torch.tensor([g*(1-seda**2)])*T_ref**2/U_ref
#Y_init_adm = torch.cat((y_init_adm, dy_init_adm, ddy_init_adm), dim=0)


t_min = X_test_adm.min()
t_max = X_test_adm.max()
Delta_t_adm = (t_max - t_min)
Delta_t_adm.retain_grad = False
u_min = y_test_adm.min()
u_min.retain_grad = False
u_max = y_test_adm.max()
Delta_u_adm = (u_max - u_min)
Delta_u_adm.retain_grad = False

# %% [markdown]
# # Modelo Predictivo ADIMENSIONALIZADO - FFNN

# %% [markdown]
# ## Clase Deep Neural Network 🧠

# %%
class DNN(nn.Module):

  # Inicialización de la RED
  def __init__(self, layers):
    super(DNN, self).__init__() # Llama __init__ de la clase padre

    # Funcion de activacion
    self.activation_fn = activation_fn

    # Historial de loss
    self.loss_history = []

    # Definir capas (crea una lista de capas Fully connected)
    self.layers = nn.ModuleList([nn.Linear(layers[i], layers[i+1]) for i in range(len(layers)-1)])

    # Inicializacion de pesos Xavier Glorot y bias como ceros
    for i in range(len(layers)-1):
      # Pesos
      nn.init.xavier_normal_(self.layers[i].weight.data, gain=1.0)
      # Bias
      nn.init.zeros_(self.layers[i].bias.data)

  # Propagación hacia adelante
  def forward(self, x):
    for i in range(len(layers)-2):
      x = self.activation_fn(self.layers[i](x))

    x = self.layers[-1](x)
    return x

# %% [markdown]
# ## Instanciar el modelo ⛏

# %%
# Instanciar modelo, definir función de pérdida y optimizador
model_ffnn_adm = DNN(layers)
loss_fn = nn.MSELoss(reduction = "mean")
optimizer = optim.Adam(model_ffnn_adm.parameters(), lr=learning_rate)

# %% [markdown]
# ## Entrenar 🦾

# %%
# Entrenar el modelo

frames = [] # Lista para guardar imágenes

for epoch in range(epochs_FFNN):
  # Forward
  y_pred_adm = model_ffnn_adm(X_train_adm)
  loss = loss_fn(y_pred_adm, y_train_adm)
  model_ffnn_adm.loss_history.append(loss.item())

  # Backward
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
  if (epoch) % 10 == 0:
    print(f'Epoch [{epoch}/{epochs_FFNN}], Loss: {loss.item():.6f}')

    if make_video:
      # Haciendo plots para video
      y_pred_adm = model_ffnn_adm(X_test_adm).detach().numpy()
      plt.figure(figsize=(8, 5))
      plt.plot(X_test, y_test_adm, label='Real', linewidth=1.5)
      plt.plot(X_test, y_pred_adm, label='Predicho', linewidth=1.5, linestyle='dashed')
      # plot los puntos de evaluacion con X
      plt.scatter(X_train[:, 0], y_train, color='red', label='Puntos de evaluación', marker= 'x')
      plt.xlabel('Time (seda)')
      plt.ylabel('Displacement (m)')
      plt.legend()
      plt.title(f"Epoch {epoch}")
      plt.savefig(f"frame_{epoch}.png")
      plt.close()
      frames.append(imageio.imread(f"frame_{epoch}.png"))

if make_video:
  # Guardar el GIF
  gif_path = "/content/training_animation.gif"
  imageio.mimsave(gif_path, frames, duration=0.5)
  files.download(gif_path)
# Out:
# Epoch [0/10000], Loss: 1.219524
# Epoch [10/10000], Loss: 0.176316
# Epoch [20/10000], Loss: 0.162450
# Epoch [30/10000], Loss: 0.107258
# Epoch [40/10000], Loss: 0.081031
# Epoch [50/10000], Loss: 0.071196
# Epoch [9900/10000], Loss: 0.000005
# Epoch [9910/10000], Loss: 0.000005
# Epoch [9920/10000], Loss: 0.000004
# Epoch [9930/10000], Loss: 0.000004
# Epoch [9940/10000], Loss: 0.000004
# Epoch [9950/10000], Loss: 0.000004
# Epoch [9960/10000], Loss: 0.000004
# Epoch [9970/10000], Loss: 0.000004
# Epoch [9980/10000], Loss: 0.000004
# Epoch [9990/10000], Loss: 0.000004

# %% [markdown]
# ## Evaluar resultados 📈

# %%
# Hacer predicciones
model_ffnn_adm.eval()
y_pred_adm = model_ffnn_adm(X_test_adm).detach().numpy()

# Crear una figura con 2 subgráficos (1 fila, 2 columnas)
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# --- Gráfico 1: Predicción vs Real ---
axs[0].plot(X_test_adm, y_test_adm, label='Real', linewidth=1.5, color = 'grey')
axs[0].plot(X_test_adm, y_pred_adm, label='Predicho', linewidth=1.5, color = 'blue')
axs[0].scatter(X_train_adm[:, 0], y_train_adm, color='orange', label='Puntos de evaluación', marker='o')
axs[0].set_xlabel('Time (s)')
axs[0].set_ylabel('Displacement (m)')
axs[0].grid(True)
axs[0].set_title('Predicción de Desplazamiento')
axs[0].legend()

# --- Gráfico 2: Historial de pérdida ---
axs[1].semilogy(model_ffnn_adm.loss_history, label='Loss', color='blue', linewidth=1.5)
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Loss')
axs[1].grid(True)
axs[1].set_title('Historial de Pérdida')
axs[1].legend()

# Ajustar diseño para evitar superposiciones
plt.tight_layout()

# Mostrar los gráficos
plt.show()

# %% [markdown]
# # Modelo de Identificación ADIMENSIONALIZADO - PINN_id_𝒜

# %% [markdown]
# ## Clase PINN_adm ⚛

# %%
class PINN_adm():
  def __init__(self,layers):

    # funcion de perdida
    self.loss_fn = nn.MSELoss(reduction = "mean")

    # Inicializando iterador
    self.iter = 0

    # Inicializando la DNN
    self.dnn = DNN(layers)
    self.b = torch.tensor(b_init, dtype=torch.float32, requires_grad=True).reshape(-1, 1)
    self.b = nn.Parameter(self.b)
    self.dnn.register_parameter('b', self.b)
    self.parameter_history = {"b":[]}

    # Inicializando el historial de losses
    self.loss_history = {"Data":[],
                         "Physics":[],
                         "IC":[],
                         "Total":[],
                        }
  def loss_data(self, X, y):
    y_pred = self.dnn(X).reshape(-1,1)
    loss_data = self.loss_fn(y_pred, y)
    self.loss_history["Data"].append(loss_data.item())
    return loss_data

  def loss_physics(self, X_phy, X_init):
    # Cálculo en el dominio de la física
    X_physics = X_phy.clone().requires_grad_(True)
    y_pred = self.dnn(X_physics).reshape(-1, 1)
    u_adm = y_pred
    b_pred = self.b
    self.parameter_history["b"].append(b_pred.item())
    seda_pred = b_pred/(2*np.sqrt(m*k))

    # Primer orden: dû*/dt^*
    du_dt_adm = torch.autograd.grad(u_adm, X_physics,
                                            torch.ones_like(u_adm),
                                            retain_graph=True, create_graph=True)[0]
    # Segundo orden: ddû*/dt^2*
    ddu_ddt_adm = torch.autograd.grad(du_dt_adm, X_physics,
                                            torch.ones_like(du_dt_adm),
                                            retain_graph=True, create_graph=True)[0]

    #loss_term_1 = 2 * Delta_u_adm * ddu_ddt_adm_norm / (Delta_t_adm ** 2)
    #loss_term_2 = 2 * seda * Delta_u_adm * du_dt_adm_norm / Delta_t_adm
    #loss_term_3 = (u_adm_norm + 1) * Delta_u_adm / 2 + u_min
    #loss_term_4 = g / (omega ** 2 * U_ref)

    loss_physics = torch.norm(ddu_ddt_adm + 2*seda_pred*du_dt_adm + u_adm - g/(U_ref*omega**2))
    self.loss_history["Physics"].append(loss_physics.item())

    # En el instante inicial:
    # u(0) = 0
    # du/dt(0) = 0
    # ddu/ddt(0) = g(1-seda**2)
    X_initial = X_init.clone().requires_grad_(True)
    y_pred_init = self.dnn(X_initial).reshape(-1,1)
    u_init_adm = y_pred_init
    du_dt_init_adm = torch.autograd.grad(u_init_adm, X_initial,
                                              torch.ones_like(u_init_adm),
                                              retain_graph=True, create_graph=True)[0]
    ddu_ddt_init_adm = torch.autograd.grad(du_dt_init_adm, X_initial,
                                                torch.ones_like(du_dt_init_adm),
                                                retain_graph=True, create_graph=True)[0]

    aceleracion_norm = torch.tensor([g*(1-seda_pred**2)])*T_ref**2/U_ref
    loss_IC_term_1 = torch.norm(u_init_adm)
    loss_IC_term_2 = torch.norm(du_dt_init_adm)
    loss_IC_term_3 = torch.norm(ddu_ddt_init_adm - aceleracion_norm)

    loss_IC = loss_IC_term_1 + loss_IC_term_2 + loss_IC_term_3
    self.loss_history["IC"].append(loss_IC.item())

    return loss_physics, loss_IC


  def loss_total(self, X, y, X_phy, X_init):
    loss_data = self.loss_data(X, y)
    loss_physics, loss_IC = self.loss_physics(X_phy, X_init)
    loss_total = loss_data + loss_physics + loss_IC
    self.loss_history["Total"].append(loss_total.item())
    return loss_total, loss_data, loss_physics, loss_IC

# %% [markdown]
# ## Instanciar el modelo ⛏

# %%
# Instanciar modelo, definir función de pérdida y optimizador
model_pinn_adm = PINN_adm(layers)
loss_fn = nn.MSELoss(reduction = "mean")
optimizer = optim.Adam(model_pinn_adm.dnn.parameters(), lr=learning_rate)

# %% [markdown]
# ## Entrenar 🦾

# %%
for epoch in range(epochs_PINN_adm_id):
  # Forward
  loss, loss_data, loss_physics, loss_IC = model_pinn_adm.loss_total(X_train_adm,
                                                                          y_train_adm,
                                                                          X_train_phy_adm,
                                                                          X_init_adm)

  # Backward
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
  if (epoch) % 100 == 0:
    print(f'Epoch [{epoch}/{epochs_PINN_adm_id}], Loss_T: {loss.item():.6f}, Loss_data: {loss_data.item():.6f}, Loss_physics: {loss_physics.item():.6f}, Loss_IC: {loss_IC.item():.6f}, b_pred (real): {model_pinn_adm.b.item():.3f}({b})')

    if make_video:
      # Haciendo plots para video
      y_pred_adm = model_pinn_adm(X_test).detach().numpy()
      plt.figure(figsize=(8, 5))
      plt.plot(X_test_adm, y_test_adm, label='Real', linewidth=1.5)
      plt.plot(X_test_adm, y_pred_adm, label='Predicho', linewidth=1.5, linestyle='dashed')
      # plot los puntos de evaluacion con X
      plt.scatter(X_train_adm, y_train_adm, color='red', label='Puntos de evaluación', marker= 'x')
      plt.xlabel('Time (seda)')
      plt.ylabel('Displacement (m)')
      plt.legend()
      plt.title(f"Epoch {epoch}")
      plt.savefig(f"frame_{epoch}.png")
      plt.close()
      frames.append(imageio.imread(f"frame_{epoch}.png"))

if make_video:
  # Guardar el GIF
  gif_path = "/content/training_animation.gif"
  imageio.mimsave(gif_path, frames, duration=0.5)
  files.download(gif_path)
# Out:
# Epoch [0/500000], Loss_T: 13.288888, Loss_data: 1.072960, Loss_physics: 11.152896, Loss_IC: 1.063032, b_pred (real): -0.000(0.5)
# Epoch [100/500000], Loss_T: 3.329375, Loss_data: 0.074696, Loss_physics: 1.588811, Loss_IC: 1.665868, b_pred (real): 0.020(0.5)
# Epoch [200/500000], Loss_T: 2.597937, Loss_data: 0.100515, Loss_physics: 0.528727, Loss_IC: 1.968695, b_pred (real): 0.036(0.5)
# Epoch [300/500000], Loss_T: 2.360669, Loss_data: 0.129482, Loss_physics: 0.196084, Loss_IC: 2.035104, b_pred (real): 0.038(0.5)
# Epoch [400/500000], Loss_T: 2.349713, Loss_data: 0.128752, Loss_physics: 0.215288, Loss_IC: 2.005673, b_pred (real): 0.039(0.5)
# Epoch [500/500000], Loss_T: 2.200942, Loss_data: 0.128935, Loss_physics: 0.061795, Loss_IC: 2.010211, b_pred (real): 0.039(0.5)
# Epoch [600/500000], Loss_T: 2.179680, Loss_data: 0.128815, Loss_physics: 0.047992, Loss_IC: 2.002872, b_pred (real): 0.039(0.5)
# Epoch [700/500000], Loss_T: 2.164386, Loss_data: 0.127285, Loss_physics: 0.051600, Loss_IC: 1.985500, b_pred (real): 0.039(0.5)
# Epoch [800/500000], Loss_T: 2.153808, Loss_data: 0.125796, Loss_physics: 0.060307, Loss_IC: 1.967705, b_pred (real): 0.041(0.5)
# Epoch [900/500000], Loss_T: 2.115365, Loss_data: 0.123602, Loss_physics: 0.049697, Loss_IC: 1.942065, b_pred (real): 0.043(0.5)
# Epoch [1000/500000], Loss_T: 2.091370, Loss_data: 0.121089, Loss_physics: 0.057751, Loss_IC: 1.912529, b_pred (real): 0.047(0.5)
# Epoch [1100/500000], Loss_T: 2.065145, Loss_data: 0.117357, Loss_physics: 0.077773, Loss_IC: 1.870016, b_pred (real): 0.053(0.5)
# Epoch [1200/500000], Loss_T: 2.029385, Loss_data: 0.112021, Loss_physics: 0.110934, Loss_IC: 1.806429, b_pred (real): 0.063(0.5)
# Epoch [1300/500000], Loss_T: 1.972070, Loss_data: 0.103873, Loss_physics: 0.163042, Loss_IC: 1.705155, b_pred (real): 0.078(0.5)
# Epoch [1400/500000], Loss_T: 1.877185, Loss_data: 0.091404, Loss_physics: 0.247182, Loss_IC: 1.538599, b_pred (real): 0.101(0.5)
# Epoch [1500/500000], Loss_T: 1.713316, Loss_data: 0.072689, Loss_physics: 0.393033, Loss_IC: 1.247594, b_pred (real): 0.133(0.5)
# Epoch [1600/500000], Loss_T: 1.406849, Loss_data: 0.047248, Loss_physics: 0.667207, Loss_IC: 0.692393, b_pred (real): 0.176(0.5)
# Epoch [1700/500000], Loss_T: 1.038524, Loss_data: 0.032785, Loss_physics: 0.941535, Loss_IC: 0.064204, b_pred (real): 0.228(0.5)
# Epoch [1800/500000], Loss_T: 0.961591, Loss_data: 0.030597, Loss_physics: 0.898623, Loss_IC: 0.032371, b_pred (real): 0.272(0.5)
# Epoch [1900/500000], Loss_T: 0.892747, Loss_data: 0.028302, Loss_physics: 0.830352, Loss_IC: 0.034093, b_pred (real): 0.310(0.5)
# Epoch [2000/500000], Loss_T: 0.836258, Loss_data: 0.026804, Loss_physics: 0.787132, Loss_IC: 0.022322, b_pred (real): 0.343(0.5)
# Epoch [2100/500000], Loss_T: 0.785626, Loss_data: 0.025565, Loss_physics: 0.754364, Loss_IC: 0.005697, b_pred (real): 0.373(0.5)
# Epoch [2200/500000], Loss_T: 0.729333, Loss_data: 0.024415, Loss_physics: 0.700290, Loss_IC: 0.004627, b_pred (real): 0.401(0.5)
# Epoch [2300/500000], Loss_T: 0.699154, Loss_data: 0.023245, Loss_physics: 0.653430, Loss_IC: 0.022478, b_pred (real): 0.427(0.5)
# Epoch [2400/500000], Loss_T: 0.637788, Loss_data: 0.022269, Loss_physics: 0.609122, Loss_IC: 0.006397, b_pred (real): 0.452(0.5)
# Epoch [2500/500000], Loss_T: 0.596024, Loss_data: 0.021023, Loss_physics: 0.556992, Loss_IC: 0.018010, b_pred (real): 0.476(0.5)
# Epoch [2600/500000], Loss_T: 0.541395, Loss_data: 0.020284, Loss_physics: 0.516722, Loss_IC: 0.004389, b_pred (real): 0.500(0.5)
# Epoch [2700/500000], Loss_T: 0.507084, Loss_data: 0.019179, Loss_physics: 0.473229, Loss_IC: 0.014676, b_pred (real): 0.522(0.5)
# Epoch [2800/500000], Loss_T: 0.489464, Loss_data: 0.018514, Loss_physics: 0.456579, Loss_IC: 0.014371, b_pred (real): 0.544(0.5)
# Epoch [2900/500000], Loss_T: 0.443381, Loss_data: 0.018038, Loss_physics: 0.413340, Loss_IC: 0.012003, b_pred (real): 0.565(0.5)
# Epoch [3000/500000], Loss_T: 0.418417, Loss_data: 0.017837, Loss_physics: 0.395874, Loss_IC: 0.004707, b_pred (real): 0.585(0.5)
# Epoch [3100/500000], Loss_T: 0.387124, Loss_data: 0.017219, Loss_physics: 0.360173, Loss_IC: 0.009732, b_pred (real): 0.604(0.5)
# Epoch [3200/500000], Loss_T: 0.388881, Loss_data: 0.017239, Loss_physics: 0.366409, Loss_IC: 0.005233, b_pred (real): 0.623(0.5)
# Epoch [3300/500000], Loss_T: 0.341920, Loss_data: 0.016763, Loss_physics: 0.319318, Loss_IC: 0.005840, b_pred (real): 0.641(0.5)
# Epoch [3400/500000], Loss_T: 0.330220, Loss_data: 0.016422, Loss_physics: 0.301921, Loss_IC: 0.011877, b_pred (real): 0.658(0.5)
# Epoch [3500/500000], Loss_T: 0.310996, Loss_data: 0.016642, Loss_physics: 0.288991, Loss_IC: 0.005363, b_pred (real): 0.675(0.5)
# Epoch [3600/500000], Loss_T: 0.305058, Loss_data: 0.016558, Loss_physics: 0.280647, Loss_IC: 0.007853, b_pred (real): 0.691(0.5)
# Epoch [3700/500000], Loss_T: 0.278612, Loss_data: 0.016652, Loss_physics: 0.254421, Loss_IC: 0.007539, b_pred (real): 0.706(0.5)
# Epoch [3800/500000], Loss_T: 0.270110, Loss_data: 0.016722, Loss_physics: 0.248871, Loss_IC: 0.004516, b_pred (real): 0.721(0.5)
# Epoch [3900/500000], Loss_T: 0.252081, Loss_data: 0.016918, Loss_physics: 0.231634, Loss_IC: 0.003529, b_pred (real): 0.735(0.5)
# Epoch [4000/500000], Loss_T: 0.240376, Loss_data: 0.016643, Loss_physics: 0.220182, Loss_IC: 0.003551, b_pred (real): 0.749(0.5)
# Epoch [4100/500000], Loss_T: 0.238126, Loss_data: 0.016576, Loss_physics: 0.213656, Loss_IC: 0.007894, b_pred (real): 0.762(0.5)
# Epoch [4200/500000], Loss_T: 0.229570, Loss_data: 0.016612, Loss_physics: 0.197577, Loss_IC: 0.015381, b_pred (real): 0.775(0.5)
# Epoch [4300/500000], Loss_T: 0.230546, Loss_data: 0.017610, Loss_physics: 0.208006, Loss_IC: 0.004929, b_pred (real): 0.787(0.5)
# Epoch [4400/500000], Loss_T: 0.219728, Loss_data: 0.016904, Loss_physics: 0.186714, Loss_IC: 0.016109, b_pred (real): 0.799(0.5)
# Epoch [4500/500000], Loss_T: 0.201726, Loss_data: 0.017681, Loss_physics: 0.182756, Loss_IC: 0.001289, b_pred (real): 0.810(0.5)
# Epoch [4600/500000], Loss_T: 0.212309, Loss_data: 0.018107, Loss_physics: 0.191368, Loss_IC: 0.002833, b_pred (real): 0.821(0.5)
# Epoch [4700/500000], Loss_T: 0.206448, Loss_data: 0.017802, Loss_physics: 0.173902, Loss_IC: 0.014744, b_pred (real): 0.832(0.5)
# Epoch [4800/500000], Loss_T: 0.191186, Loss_data: 0.018669, Loss_physics: 0.169965, Loss_IC: 0.002552, b_pred (real): 0.842(0.5)
# Epoch [4900/500000], Loss_T: 0.203078, Loss_data: 0.018689, Loss_physics: 0.178962, Loss_IC: 0.005426, b_pred (real): 0.852(0.5)
# Epoch [5000/500000], Loss_T: 0.178922, Loss_data: 0.019032, Loss_physics: 0.157024, Loss_IC: 0.002865, b_pred (real): 0.862(0.5)
# Epoch [5100/500000], Loss_T: 0.183394, Loss_data: 0.019551, Loss_physics: 0.159096, Loss_IC: 0.004747, b_pred (real): 0.872(0.5)
# Epoch [5200/500000], Loss_T: 0.175704, Loss_data: 0.019670, Loss_physics: 0.147031, Loss_IC: 0.009004, b_pred (real): 0.881(0.5)
# Epoch [5300/500000], Loss_T: 0.180061, Loss_data: 0.020361, Loss_physics: 0.152107, Loss_IC: 0.007593, b_pred (real): 0.890(0.5)
# Epoch [5400/500000], Loss_T: 0.171366, Loss_data: 0.020316, Loss_physics: 0.145939, Loss_IC: 0.005111, b_pred (real): 0.899(0.5)
# Epoch [5500/500000], Loss_T: 0.177847, Loss_data: 0.020197, Loss_physics: 0.141596, Loss_IC: 0.016054, b_pred (real): 0.907(0.5)
# Epoch [5600/500000], Loss_T: 0.172288, Loss_data: 0.021255, Loss_physics: 0.146095, Loss_IC: 0.004938, b_pred (real): 0.916(0.5)
# Epoch [5700/500000], Loss_T: 0.171042, Loss_data: 0.021212, Loss_physics: 0.143729, Loss_IC: 0.006101, b_pred (real): 0.924(0.5)
# Epoch [5800/500000], Loss_T: 0.168251, Loss_data: 0.021538, Loss_physics: 0.139469, Loss_IC: 0.007244, b_pred (real): 0.931(0.5)
# Epoch [5900/500000], Loss_T: 0.167164, Loss_data: 0.021685, Loss_physics: 0.136266, Loss_IC: 0.009213, b_pred (real): 0.939(0.5)
# Epoch [6000/500000], Loss_T: 0.168446, Loss_data: 0.022399, Loss_physics: 0.142257, Loss_IC: 0.003789, b_pred (real): 0.946(0.5)
# Epoch [6100/500000], Loss_T: 0.166647, Loss_data: 0.022130, Loss_physics: 0.134905, Loss_IC: 0.009612, b_pred (real): 0.953(0.5)
# Epoch [6200/500000], Loss_T: 0.171366, Loss_data: 0.022346, Loss_physics: 0.138130, Loss_IC: 0.010890, b_pred (real): 0.960(0.5)
# Epoch [6300/500000], Loss_T: 0.169514, Loss_data: 0.022704, Loss_physics: 0.137940, Loss_IC: 0.008870, b_pred (real): 0.966(0.5)
# Epoch [6400/500000], Loss_T: 0.169286, Loss_data: 0.023143, Loss_physics: 0.135653, Loss_IC: 0.010490, b_pred (real): 0.972(0.5)
# Epoch [6500/500000], Loss_T: 0.172118, Loss_data: 0.023085, Loss_physics: 0.134792, Loss_IC: 0.014241, b_pred (real): 0.978(0.5)
# Epoch [6600/500000], Loss_T: 0.170477, Loss_data: 0.023790, Loss_physics: 0.140579, Loss_IC: 0.006108, b_pred (real): 0.984(0.5)
# Epoch [6700/500000], Loss_T: 0.171123, Loss_data: 0.024031, Loss_physics: 0.142565, Loss_IC: 0.004527, b_pred (real): 0.990(0.5)
# Epoch [6800/500000], Loss_T: 0.168549, Loss_data: 0.023879, Loss_physics: 0.134632, Loss_IC: 0.010038, b_pred (real): 0.995(0.5)
# Epoch [6900/500000], Loss_T: 0.169404, Loss_data: 0.024467, Loss_physics: 0.132935, Loss_IC: 0.012002, b_pred (real): 1.000(0.5)
# Epoch [7000/500000], Loss_T: 0.189278, Loss_data: 0.024205, Loss_physics: 0.148034, Loss_IC: 0.017039, b_pred (real): 1.005(0.5)
# Epoch [7100/500000], Loss_T: 0.172272, Loss_data: 0.024030, Loss_physics: 0.131247, Loss_IC: 0.016995, b_pred (real): 1.010(0.5)
# Epoch [7200/500000], Loss_T: 0.172044, Loss_data: 0.025082, Loss_physics: 0.139673, Loss_IC: 0.007289, b_pred (real): 1.014(0.5)
# Epoch [7300/500000], Loss_T: 0.174296, Loss_data: 0.024942, Loss_physics: 0.142372, Loss_IC: 0.006983, b_pred (real): 1.019(0.5)
# Epoch [7400/500000], Loss_T: 0.175107, Loss_data: 0.025071, Loss_physics: 0.141041, Loss_IC: 0.008995, b_pred (real): 1.023(0.5)
# Epoch [7500/500000], Loss_T: 0.173573, Loss_data: 0.025345, Loss_physics: 0.141616, Loss_IC: 0.006611, b_pred (real): 1.027(0.5)
# Epoch [7600/500000], Loss_T: 0.184490, Loss_data: 0.025851, Loss_physics: 0.144685, Loss_IC: 0.013954, b_pred (real): 1.029(0.5)
# Epoch [7700/500000], Loss_T: 0.174387, Loss_data: 0.025339, Loss_physics: 0.136179, Loss_IC: 0.012869, b_pred (real): 1.033(0.5)
# Epoch [7800/500000], Loss_T: 0.176727, Loss_data: 0.025614, Loss_physics: 0.136266, Loss_IC: 0.014847, b_pred (real): 1.036(0.5)
# Epoch [7900/500000], Loss_T: 0.174188, Loss_data: 0.025699, Loss_physics: 0.134505, Loss_IC: 0.013984, b_pred (real): 1.039(0.5)
# Epoch [8000/500000], Loss_T: 0.176444, Loss_data: 0.025928, Loss_physics: 0.138477, Loss_IC: 0.012039, b_pred (real): 1.042(0.5)
# Epoch [8100/500000], Loss_T: 0.186363, Loss_data: 0.025794, Loss_physics: 0.141876, Loss_IC: 0.018694, b_pred (real): 1.044(0.5)
# Epoch [8200/500000], Loss_T: 0.182741, Loss_data: 0.026100, Loss_physics: 0.144300, Loss_IC: 0.012340, b_pred (real): 1.047(0.5)
# Epoch [8300/500000], Loss_T: 0.193045, Loss_data: 0.025993, Loss_physics: 0.150742, Loss_IC: 0.016310, b_pred (real): 1.050(0.5)
# Epoch [8400/500000], Loss_T: 0.175912, Loss_data: 0.026227, Loss_physics: 0.135807, Loss_IC: 0.013878, b_pred (real): 1.052(0.5)
# Epoch [8500/500000], Loss_T: 0.178004, Loss_data: 0.026389, Loss_physics: 0.137573, Loss_IC: 0.014043, b_pred (real): 1.053(0.5)
# Epoch [8600/500000], Loss_T: 0.180675, Loss_data: 0.026289, Loss_physics: 0.139722, Loss_IC: 0.014663, b_pred (real): 1.055(0.5)
# Epoch [8700/500000], Loss_T: 0.175653, Loss_data: 0.026332, Loss_physics: 0.130455, Loss_IC: 0.018866, b_pred (real): 1.056(0.5)
# Epoch [8800/500000], Loss_T: 0.183345, Loss_data: 0.026315, Loss_physics: 0.141256, Loss_IC: 0.015774, b_pred (real): 1.058(0.5)
# Epoch [8900/500000], Loss_T: 0.177928, Loss_data: 0.026319, Loss_physics: 0.132973, Loss_IC: 0.018636, b_pred (real): 1.058(0.5)
# Epoch [9000/500000], Loss_T: 0.186725, Loss_data: 0.025817, Loss_physics: 0.138071, Loss_IC: 0.022837, b_pred (real): 1.059(0.5)
# Epoch [9100/500000], Loss_T: 0.179056, Loss_data: 0.025995, Loss_physics: 0.126179, Loss_IC: 0.026883, b_pred (real): 1.059(0.5)
# Epoch [9200/500000], Loss_T: 0.185606, Loss_data: 0.026547, Loss_physics: 0.136707, Loss_IC: 0.022352, b_pred (real): 1.059(0.5)
# Epoch [9300/500000], Loss_T: 0.180710, Loss_data: 0.026486, Loss_physics: 0.133467, Loss_IC: 0.020757, b_pred (real): 1.060(0.5)
# Epoch [9400/500000], Loss_T: 0.187936, Loss_data: 0.026672, Loss_physics: 0.137580, Loss_IC: 0.023683, b_pred (real): 1.060(0.5)
# Epoch [9500/500000], Loss_T: 0.176566, Loss_data: 0.026773, Loss_physics: 0.130223, Loss_IC: 0.019570, b_pred (real): 1.061(0.5)
# Epoch [9600/500000], Loss_T: 0.176374, Loss_data: 0.026343, Loss_physics: 0.129591, Loss_IC: 0.020441, b_pred (real): 1.061(0.5)
# Epoch [9700/500000], Loss_T: 0.175816, Loss_data: 0.026551, Loss_physics: 0.130871, Loss_IC: 0.018394, b_pred (real): 1.061(0.5)
# Epoch [9800/500000], Loss_T: 0.176761, Loss_data: 0.026916, Loss_physics: 0.132544, Loss_IC: 0.017301, b_pred (real): 1.060(0.5)
# Epoch [9900/500000], Loss_T: 0.184101, Loss_data: 0.026219, Loss_physics: 0.134479, Loss_IC: 0.023404, b_pred (real): 1.061(0.5)
# Epoch [10000/500000], Loss_T: 0.178617, Loss_data: 0.026271, Loss_physics: 0.134157, Loss_IC: 0.018189, b_pred (real): 1.059(0.5)
# Epoch [10100/500000], Loss_T: 0.174965, Loss_data: 0.026516, Loss_physics: 0.127695, Loss_IC: 0.020755, b_pred (real): 1.058(0.5)
# Epoch [10200/500000], Loss_T: 0.174191, Loss_data: 0.026411, Loss_physics: 0.127465, Loss_IC: 0.020315, b_pred (real): 1.058(0.5)
# Epoch [10300/500000], Loss_T: 0.174739, Loss_data: 0.026124, Loss_physics: 0.128935, Loss_IC: 0.019680, b_pred (real): 1.058(0.5)
# Epoch [10400/500000], Loss_T: 0.177295, Loss_data: 0.026294, Loss_physics: 0.131575, Loss_IC: 0.019426, b_pred (real): 1.058(0.5)
# Epoch [10500/500000], Loss_T: 0.174512, Loss_data: 0.026022, Loss_physics: 0.128486, Loss_IC: 0.020004, b_pred (real): 1.056(0.5)
# Epoch [10600/500000], Loss_T: 0.173340, Loss_data: 0.026075, Loss_physics: 0.129602, Loss_IC: 0.017663, b_pred (real): 1.055(0.5)
# Epoch [10700/500000], Loss_T: 0.172356, Loss_data: 0.026129, Loss_physics: 0.122614, Loss_IC: 0.023613, b_pred (real): 1.053(0.5)
# Epoch [10800/500000], Loss_T: 0.177226, Loss_data: 0.025947, Loss_physics: 0.127844, Loss_IC: 0.023435, b_pred (real): 1.053(0.5)
# Epoch [10900/500000], Loss_T: 0.175030, Loss_data: 0.025770, Loss_physics: 0.129814, Loss_IC: 0.019446, b_pred (real): 1.052(0.5)
# Epoch [11000/500000], Loss_T: 0.188096, Loss_data: 0.024927, Loss_physics: 0.135778, Loss_IC: 0.027390, b_pred (real): 1.052(0.5)
# Epoch [11100/500000], Loss_T: 0.179046, Loss_data: 0.025683, Loss_physics: 0.129792, Loss_IC: 0.023571, b_pred (real): 1.049(0.5)
# Epoch [11200/500000], Loss_T: 0.171507, Loss_data: 0.025724, Loss_physics: 0.124290, Loss_IC: 0.021493, b_pred (real): 1.048(0.5)
# Epoch [11300/500000], Loss_T: 0.169637, Loss_data: 0.025564, Loss_physics: 0.120046, Loss_IC: 0.024027, b_pred (real): 1.046(0.5)
# Epoch [11400/500000], Loss_T: 0.182686, Loss_data: 0.025486, Loss_physics: 0.135210, Loss_IC: 0.021991, b_pred (real): 1.046(0.5)
# Epoch [11500/500000], Loss_T: 0.172178, Loss_data: 0.025470, Loss_physics: 0.131644, Loss_IC: 0.015064, b_pred (real): 1.045(0.5)
# Epoch [11600/500000], Loss_T: 0.169303, Loss_data: 0.025528, Loss_physics: 0.129718, Loss_IC: 0.014057, b_pred (real): 1.044(0.5)
# Epoch [11700/500000], Loss_T: 0.169939, Loss_data: 0.025314, Loss_physics: 0.130848, Loss_IC: 0.013777, b_pred (real): 1.043(0.5)
# Epoch [11800/500000], Loss_T: 0.177263, Loss_data: 0.025388, Loss_physics: 0.132717, Loss_IC: 0.019158, b_pred (real): 1.040(0.5)
# Epoch [11900/500000], Loss_T: 0.169252, Loss_data: 0.024922, Loss_physics: 0.124673, Loss_IC: 0.019657, b_pred (real): 1.039(0.5)
# Epoch [12000/500000], Loss_T: 0.173619, Loss_data: 0.025116, Loss_physics: 0.126245, Loss_IC: 0.022259, b_pred (real): 1.037(0.5)
# Epoch [12100/500000], Loss_T: 0.167239, Loss_data: 0.025034, Loss_physics: 0.122976, Loss_IC: 0.019229, b_pred (real): 1.036(0.5)
# Epoch [12200/500000], Loss_T: 0.165990, Loss_data: 0.025178, Loss_physics: 0.124566, Loss_IC: 0.016246, b_pred (real): 1.035(0.5)
# Epoch [12300/500000], Loss_T: 0.167031, Loss_data: 0.024777, Loss_physics: 0.128176, Loss_IC: 0.014077, b_pred (real): 1.035(0.5)
# Epoch [12400/500000], Loss_T: 0.173097, Loss_data: 0.025056, Loss_physics: 0.130306, Loss_IC: 0.017735, b_pred (real): 1.033(0.5)
# Epoch [12500/500000], Loss_T: 0.173840, Loss_data: 0.024309, Loss_physics: 0.125407, Loss_IC: 0.024124, b_pred (real): 1.031(0.5)
# Epoch [12600/500000], Loss_T: 0.165090, Loss_data: 0.024829, Loss_physics: 0.122051, Loss_IC: 0.018211, b_pred (real): 1.030(0.5)
# Epoch [12700/500000], Loss_T: 0.173983, Loss_data: 0.023665, Loss_physics: 0.121964, Loss_IC: 0.028353, b_pred (real): 1.029(0.5)
# Epoch [12800/500000], Loss_T: 0.167576, Loss_data: 0.024462, Loss_physics: 0.120564, Loss_IC: 0.022551, b_pred (real): 1.027(0.5)
# Epoch [12900/500000], Loss_T: 0.165574, Loss_data: 0.024645, Loss_physics: 0.126644, Loss_IC: 0.014285, b_pred (real): 1.027(0.5)
# Epoch [13000/500000], Loss_T: 0.164118, Loss_data: 0.024148, Loss_physics: 0.124584, Loss_IC: 0.015387, b_pred (real): 1.027(0.5)
# Epoch [13100/500000], Loss_T: 0.165858, Loss_data: 0.024481, Loss_physics: 0.121035, Loss_IC: 0.020342, b_pred (real): 1.024(0.5)
# Epoch [13200/500000], Loss_T: 0.165975, Loss_data: 0.024357, Loss_physics: 0.123599, Loss_IC: 0.018019, b_pred (real): 1.023(0.5)
# Epoch [13300/500000], Loss_T: 0.161723, Loss_data: 0.024171, Loss_physics: 0.119316, Loss_IC: 0.018236, b_pred (real): 1.022(0.5)
# Epoch [13400/500000], Loss_T: 0.162301, Loss_data: 0.024457, Loss_physics: 0.121025, Loss_IC: 0.016819, b_pred (real): 1.020(0.5)
# Epoch [13500/500000], Loss_T: 0.162492, Loss_data: 0.024114, Loss_physics: 0.119808, Loss_IC: 0.018570, b_pred (real): 1.019(0.5)
# Epoch [13600/500000], Loss_T: 0.160820, Loss_data: 0.024085, Loss_physics: 0.120775, Loss_IC: 0.015960, b_pred (real): 1.018(0.5)
# Epoch [13700/500000], Loss_T: 0.163519, Loss_data: 0.024344, Loss_physics: 0.124759, Loss_IC: 0.014416, b_pred (real): 1.017(0.5)
# Epoch [13800/500000], Loss_T: 0.159391, Loss_data: 0.023775, Loss_physics: 0.119101, Loss_IC: 0.016515, b_pred (real): 1.016(0.5)
# Epoch [13900/500000], Loss_T: 0.167958, Loss_data: 0.024052, Loss_physics: 0.121735, Loss_IC: 0.022170, b_pred (real): 1.014(0.5)
# Epoch [14000/500000], Loss_T: 0.169534, Loss_data: 0.023843, Loss_physics: 0.123603, Loss_IC: 0.022087, b_pred (real): 1.013(0.5)
# Epoch [14100/500000], Loss_T: 0.166737, Loss_data: 0.023165, Loss_physics: 0.122074, Loss_IC: 0.021498, b_pred (real): 1.012(0.5)
# Epoch [14200/500000], Loss_T: 0.158811, Loss_data: 0.023520, Loss_physics: 0.115329, Loss_IC: 0.019962, b_pred (real): 1.011(0.5)
# Epoch [14300/500000], Loss_T: 0.159202, Loss_data: 0.023557, Loss_physics: 0.114963, Loss_IC: 0.020683, b_pred (real): 1.009(0.5)
# Epoch [14400/500000], Loss_T: 0.160914, Loss_data: 0.023539, Loss_physics: 0.122083, Loss_IC: 0.015291, b_pred (real): 1.009(0.5)
# Epoch [14500/500000], Loss_T: 0.163093, Loss_data: 0.022875, Loss_physics: 0.115083, Loss_IC: 0.025135, b_pred (real): 1.008(0.5)
# Epoch [14600/500000], Loss_T: 0.157125, Loss_data: 0.023246, Loss_physics: 0.117525, Loss_IC: 0.016354, b_pred (real): 1.007(0.5)
# Epoch [14700/500000], Loss_T: 0.158115, Loss_data: 0.023623, Loss_physics: 0.119222, Loss_IC: 0.015270, b_pred (real): 1.005(0.5)
# Epoch [14800/500000], Loss_T: 0.157258, Loss_data: 0.023141, Loss_physics: 0.110947, Loss_IC: 0.023171, b_pred (real): 1.004(0.5)
# Epoch [14900/500000], Loss_T: 0.156228, Loss_data: 0.023159, Loss_physics: 0.114969, Loss_IC: 0.018101, b_pred (real): 1.002(0.5)
# Epoch [15000/500000], Loss_T: 0.158226, Loss_data: 0.023134, Loss_physics: 0.121590, Loss_IC: 0.013503, b_pred (real): 1.002(0.5)
# Epoch [15100/500000], Loss_T: 0.154407, Loss_data: 0.023038, Loss_physics: 0.111067, Loss_IC: 0.020302, b_pred (real): 1.000(0.5)
# Epoch [15200/500000], Loss_T: 0.155676, Loss_data: 0.023281, Loss_physics: 0.115733, Loss_IC: 0.016662, b_pred (real): 0.999(0.5)
# Epoch [15300/500000], Loss_T: 0.158425, Loss_data: 0.022647, Loss_physics: 0.116732, Loss_IC: 0.019046, b_pred (real): 0.998(0.5)
# Epoch [15400/500000], Loss_T: 0.162106, Loss_data: 0.022757, Loss_physics: 0.120515, Loss_IC: 0.018833, b_pred (real): 0.996(0.5)
# Epoch [15500/500000], Loss_T: 0.159979, Loss_data: 0.022537, Loss_physics: 0.115517, Loss_IC: 0.021925, b_pred (real): 0.995(0.5)
# Epoch [15600/500000], Loss_T: 0.153838, Loss_data: 0.022498, Loss_physics: 0.115869, Loss_IC: 0.015471, b_pred (real): 0.994(0.5)
# Epoch [15700/500000], Loss_T: 0.153836, Loss_data: 0.022811, Loss_physics: 0.117138, Loss_IC: 0.013887, b_pred (real): 0.992(0.5)
# Epoch [15800/500000], Loss_T: 0.154240, Loss_data: 0.022629, Loss_physics: 0.117547, Loss_IC: 0.014064, b_pred (real): 0.992(0.5)
# Epoch [15900/500000], Loss_T: 0.155904, Loss_data: 0.022196, Loss_physics: 0.117428, Loss_IC: 0.016281, b_pred (real): 0.990(0.5)
# Epoch [16000/500000], Loss_T: 0.151750, Loss_data: 0.021870, Loss_physics: 0.107318, Loss_IC: 0.022563, b_pred (real): 0.988(0.5)
# Epoch [16100/500000], Loss_T: 0.165996, Loss_data: 0.021526, Loss_physics: 0.121084, Loss_IC: 0.023386, b_pred (real): 0.987(0.5)
# Epoch [16200/500000], Loss_T: 0.151890, Loss_data: 0.022161, Loss_physics: 0.116144, Loss_IC: 0.013585, b_pred (real): 0.985(0.5)
# Epoch [16300/500000], Loss_T: 0.149535, Loss_data: 0.022022, Loss_physics: 0.118480, Loss_IC: 0.009033, b_pred (real): 0.985(0.5)
# Epoch [16400/500000], Loss_T: 0.155448, Loss_data: 0.022394, Loss_physics: 0.120578, Loss_IC: 0.012476, b_pred (real): 0.983(0.5)
# Epoch [16500/500000], Loss_T: 0.151758, Loss_data: 0.022249, Loss_physics: 0.119252, Loss_IC: 0.010257, b_pred (real): 0.981(0.5)
# Epoch [16600/500000], Loss_T: 0.147652, Loss_data: 0.021711, Loss_physics: 0.109183, Loss_IC: 0.016758, b_pred (real): 0.980(0.5)
# Epoch [16700/500000], Loss_T: 0.149392, Loss_data: 0.021882, Loss_physics: 0.108563, Loss_IC: 0.018947, b_pred (real): 0.978(0.5)
# Epoch [16800/500000], Loss_T: 0.147836, Loss_data: 0.021507, Loss_physics: 0.108348, Loss_IC: 0.017981, b_pred (real): 0.977(0.5)
# Epoch [16900/500000], Loss_T: 0.149724, Loss_data: 0.021854, Loss_physics: 0.119048, Loss_IC: 0.008822, b_pred (real): 0.977(0.5)
# Epoch [17000/500000], Loss_T: 0.160586, Loss_data: 0.021015, Loss_physics: 0.123159, Loss_IC: 0.016412, b_pred (real): 0.975(0.5)
# Epoch [17100/500000], Loss_T: 0.152141, Loss_data: 0.021414, Loss_physics: 0.116031, Loss_IC: 0.014696, b_pred (real): 0.973(0.5)
# Epoch [17200/500000], Loss_T: 0.153261, Loss_data: 0.021739, Loss_physics: 0.120381, Loss_IC: 0.011141, b_pred (real): 0.972(0.5)
# Epoch [17300/500000], Loss_T: 0.145906, Loss_data: 0.020936, Loss_physics: 0.103136, Loss_IC: 0.021835, b_pred (real): 0.970(0.5)
# Epoch [17400/500000], Loss_T: 0.151030, Loss_data: 0.020746, Loss_physics: 0.108770, Loss_IC: 0.021515, b_pred (real): 0.969(0.5)
# Epoch [17500/500000], Loss_T: 0.149572, Loss_data: 0.021081, Loss_physics: 0.121603, Loss_IC: 0.006888, b_pred (real): 0.969(0.5)
# Epoch [17600/500000], Loss_T: 0.144876, Loss_data: 0.021149, Loss_physics: 0.110866, Loss_IC: 0.012861, b_pred (real): 0.967(0.5)
# Epoch [17700/500000], Loss_T: 0.152308, Loss_data: 0.020807, Loss_physics: 0.114533, Loss_IC: 0.016968, b_pred (real): 0.965(0.5)
# Epoch [17800/500000], Loss_T: 0.144195, Loss_data: 0.020898, Loss_physics: 0.106236, Loss_IC: 0.017061, b_pred (real): 0.963(0.5)
# Epoch [17900/500000], Loss_T: 0.150184, Loss_data: 0.020695, Loss_physics: 0.111301, Loss_IC: 0.018188, b_pred (real): 0.963(0.5)
# Epoch [18000/500000], Loss_T: 0.142754, Loss_data: 0.020701, Loss_physics: 0.107189, Loss_IC: 0.014865, b_pred (real): 0.961(0.5)
# Epoch [18100/500000], Loss_T: 0.142845, Loss_data: 0.020430, Loss_physics: 0.114360, Loss_IC: 0.008054, b_pred (real): 0.960(0.5)
# Epoch [18200/500000], Loss_T: 0.151562, Loss_data: 0.020446, Loss_physics: 0.117469, Loss_IC: 0.013647, b_pred (real): 0.958(0.5)
# Epoch [18300/500000], Loss_T: 0.146054, Loss_data: 0.020529, Loss_physics: 0.113325, Loss_IC: 0.012200, b_pred (real): 0.957(0.5)
# Epoch [18400/500000], Loss_T: 0.159327, Loss_data: 0.020651, Loss_physics: 0.119568, Loss_IC: 0.019108, b_pred (real): 0.955(0.5)
# Epoch [18500/500000], Loss_T: 0.143276, Loss_data: 0.020549, Loss_physics: 0.110119, Loss_IC: 0.012608, b_pred (real): 0.953(0.5)
# Epoch [18600/500000], Loss_T: 0.139752, Loss_data: 0.020415, Loss_physics: 0.105140, Loss_IC: 0.014198, b_pred (real): 0.952(0.5)
# Epoch [18700/500000], Loss_T: 0.139874, Loss_data: 0.020112, Loss_physics: 0.106378, Loss_IC: 0.013384, b_pred (real): 0.951(0.5)
# Epoch [18800/500000], Loss_T: 0.139526, Loss_data: 0.019942, Loss_physics: 0.104958, Loss_IC: 0.014626, b_pred (real): 0.950(0.5)
# Epoch [18900/500000], Loss_T: 0.143368, Loss_data: 0.019731, Loss_physics: 0.101022, Loss_IC: 0.022615, b_pred (real): 0.948(0.5)
# Epoch [19000/500000], Loss_T: 0.145893, Loss_data: 0.019719, Loss_physics: 0.101828, Loss_IC: 0.024346, b_pred (real): 0.947(0.5)
# Epoch [19100/500000], Loss_T: 0.141048, Loss_data: 0.019522, Loss_physics: 0.103676, Loss_IC: 0.017851, b_pred (real): 0.945(0.5)
# Epoch [19200/500000], Loss_T: 0.143161, Loss_data: 0.019427, Loss_physics: 0.109008, Loss_IC: 0.014727, b_pred (real): 0.944(0.5)
# Epoch [19300/500000], Loss_T: 0.137127, Loss_data: 0.019656, Loss_physics: 0.107276, Loss_IC: 0.010196, b_pred (real): 0.943(0.5)
# Epoch [19400/500000], Loss_T: 0.138527, Loss_data: 0.019394, Loss_physics: 0.106117, Loss_IC: 0.013016, b_pred (real): 0.942(0.5)
# Epoch [19500/500000], Loss_T: 0.137843, Loss_data: 0.019148, Loss_physics: 0.101042, Loss_IC: 0.017653, b_pred (real): 0.939(0.5)
# Epoch [19600/500000], Loss_T: 0.138395, Loss_data: 0.018989, Loss_physics: 0.100635, Loss_IC: 0.018771, b_pred (real): 0.938(0.5)
# Epoch [19700/500000], Loss_T: 0.136550, Loss_data: 0.019239, Loss_physics: 0.104732, Loss_IC: 0.012578, b_pred (real): 0.937(0.5)
# Epoch [19800/500000], Loss_T: 0.135414, Loss_data: 0.019192, Loss_physics: 0.105693, Loss_IC: 0.010529, b_pred (real): 0.936(0.5)
# Epoch [19900/500000], Loss_T: 0.135705, Loss_data: 0.019528, Loss_physics: 0.104507, Loss_IC: 0.011670, b_pred (real): 0.934(0.5)
# Epoch [20000/500000], Loss_T: 0.135289, Loss_data: 0.019113, Loss_physics: 0.100750, Loss_IC: 0.015425, b_pred (real): 0.932(0.5)
# Epoch [20100/500000], Loss_T: 0.141562, Loss_data: 0.018938, Loss_physics: 0.103720, Loss_IC: 0.018904, b_pred (real): 0.931(0.5)
# Epoch [20200/500000], Loss_T: 0.140407, Loss_data: 0.018400, Loss_physics: 0.101094, Loss_IC: 0.020912, b_pred (real): 0.930(0.5)
# Epoch [20300/500000], Loss_T: 0.138487, Loss_data: 0.018785, Loss_physics: 0.100804, Loss_IC: 0.018897, b_pred (real): 0.927(0.5)
# Epoch [20400/500000], Loss_T: 0.135072, Loss_data: 0.018703, Loss_physics: 0.107457, Loss_IC: 0.008913, b_pred (real): 0.927(0.5)
# Epoch [20500/500000], Loss_T: 0.134988, Loss_data: 0.018739, Loss_physics: 0.106687, Loss_IC: 0.009561, b_pred (real): 0.925(0.5)
# Epoch [20600/500000], Loss_T: 0.140514, Loss_data: 0.018353, Loss_physics: 0.105804, Loss_IC: 0.016357, b_pred (real): 0.923(0.5)
# Epoch [20700/500000], Loss_T: 0.130636, Loss_data: 0.018539, Loss_physics: 0.098581, Loss_IC: 0.013516, b_pred (real): 0.922(0.5)
# Epoch [20800/500000], Loss_T: 0.133142, Loss_data: 0.018615, Loss_physics: 0.106751, Loss_IC: 0.007776, b_pred (real): 0.921(0.5)
# Epoch [20900/500000], Loss_T: 0.130589, Loss_data: 0.018299, Loss_physics: 0.101756, Loss_IC: 0.010534, b_pred (real): 0.919(0.5)
# Epoch [21000/500000], Loss_T: 0.142732, Loss_data: 0.017754, Loss_physics: 0.109439, Loss_IC: 0.015539, b_pred (real): 0.918(0.5)
# Epoch [21100/500000], Loss_T: 0.132488, Loss_data: 0.018178, Loss_physics: 0.101107, Loss_IC: 0.013203, b_pred (real): 0.916(0.5)
# Epoch [21200/500000], Loss_T: 0.139750, Loss_data: 0.017798, Loss_physics: 0.106049, Loss_IC: 0.015903, b_pred (real): 0.915(0.5)
# Epoch [21300/500000], Loss_T: 0.128787, Loss_data: 0.018057, Loss_physics: 0.101598, Loss_IC: 0.009132, b_pred (real): 0.913(0.5)
# Epoch [21400/500000], Loss_T: 0.130266, Loss_data: 0.017495, Loss_physics: 0.094699, Loss_IC: 0.018072, b_pred (real): 0.912(0.5)
# Epoch [21500/500000], Loss_T: 0.127686, Loss_data: 0.017822, Loss_physics: 0.095123, Loss_IC: 0.014742, b_pred (real): 0.910(0.5)
# Epoch [21600/500000], Loss_T: 0.133731, Loss_data: 0.017694, Loss_physics: 0.100407, Loss_IC: 0.015629, b_pred (real): 0.909(0.5)
# Epoch [21700/500000], Loss_T: 0.135782, Loss_data: 0.017322, Loss_physics: 0.097890, Loss_IC: 0.020569, b_pred (real): 0.907(0.5)
# Epoch [21800/500000], Loss_T: 0.131934, Loss_data: 0.017310, Loss_physics: 0.104923, Loss_IC: 0.009702, b_pred (real): 0.906(0.5)
# Epoch [21900/500000], Loss_T: 0.125457, Loss_data: 0.017651, Loss_physics: 0.097056, Loss_IC: 0.010750, b_pred (real): 0.904(0.5)
# Epoch [22000/500000], Loss_T: 0.127298, Loss_data: 0.017378, Loss_physics: 0.097422, Loss_IC: 0.012498, b_pred (real): 0.902(0.5)
# Epoch [22100/500000], Loss_T: 0.126366, Loss_data: 0.017364, Loss_physics: 0.095017, Loss_IC: 0.013984, b_pred (real): 0.901(0.5)
# Epoch [22200/500000], Loss_T: 0.125999, Loss_data: 0.017187, Loss_physics: 0.103101, Loss_IC: 0.005710, b_pred (real): 0.900(0.5)
# Epoch [22300/500000], Loss_T: 0.128980, Loss_data: 0.016908, Loss_physics: 0.096308, Loss_IC: 0.015764, b_pred (real): 0.898(0.5)
# Epoch [22400/500000], Loss_T: 0.125056, Loss_data: 0.016724, Loss_physics: 0.092221, Loss_IC: 0.016112, b_pred (real): 0.896(0.5)
# Epoch [22500/500000], Loss_T: 0.124845, Loss_data: 0.016759, Loss_physics: 0.091925, Loss_IC: 0.016162, b_pred (real): 0.895(0.5)
# Epoch [22600/500000], Loss_T: 0.133349, Loss_data: 0.016542, Loss_physics: 0.102233, Loss_IC: 0.014575, b_pred (real): 0.894(0.5)
# Epoch [22700/500000], Loss_T: 0.124993, Loss_data: 0.016530, Loss_physics: 0.100683, Loss_IC: 0.007780, b_pred (real): 0.893(0.5)
# Epoch [22800/500000], Loss_T: 0.124708, Loss_data: 0.016893, Loss_physics: 0.098281, Loss_IC: 0.009534, b_pred (real): 0.890(0.5)
# Epoch [22900/500000], Loss_T: 0.124578, Loss_data: 0.016722, Loss_physics: 0.096037, Loss_IC: 0.011820, b_pred (real): 0.888(0.5)
# Epoch [23000/500000], Loss_T: 0.129181, Loss_data: 0.016756, Loss_physics: 0.100596, Loss_IC: 0.011829, b_pred (real): 0.887(0.5)
# Epoch [23100/500000], Loss_T: 0.127711, Loss_data: 0.016673, Loss_physics: 0.106529, Loss_IC: 0.004509, b_pred (real): 0.887(0.5)
# Epoch [23200/500000], Loss_T: 0.123318, Loss_data: 0.016597, Loss_physics: 0.093947, Loss_IC: 0.012775, b_pred (real): 0.884(0.5)
# Epoch [23300/500000], Loss_T: 0.121351, Loss_data: 0.016063, Loss_physics: 0.087407, Loss_IC: 0.017881, b_pred (real): 0.883(0.5)
# Epoch [23400/500000], Loss_T: 0.128532, Loss_data: 0.016321, Loss_physics: 0.098316, Loss_IC: 0.013894, b_pred (real): 0.882(0.5)
# Epoch [23500/500000], Loss_T: 0.119100, Loss_data: 0.016195, Loss_physics: 0.090346, Loss_IC: 0.012559, b_pred (real): 0.880(0.5)
# Epoch [23600/500000], Loss_T: 0.122924, Loss_data: 0.015661, Loss_physics: 0.087069, Loss_IC: 0.020194, b_pred (real): 0.879(0.5)
# Epoch [23700/500000], Loss_T: 0.124164, Loss_data: 0.015781, Loss_physics: 0.091546, Loss_IC: 0.016837, b_pred (real): 0.878(0.5)
# Epoch [23800/500000], Loss_T: 0.133389, Loss_data: 0.015448, Loss_physics: 0.090695, Loss_IC: 0.027246, b_pred (real): 0.876(0.5)
# Epoch [23900/500000], Loss_T: 0.117311, Loss_data: 0.015853, Loss_physics: 0.095064, Loss_IC: 0.006394, b_pred (real): 0.876(0.5)
# Epoch [24000/500000], Loss_T: 0.118859, Loss_data: 0.015823, Loss_physics: 0.091248, Loss_IC: 0.011788, b_pred (real): 0.874(0.5)
# Epoch [24100/500000], Loss_T: 0.121470, Loss_data: 0.015790, Loss_physics: 0.091256, Loss_IC: 0.014423, b_pred (real): 0.872(0.5)
# Epoch [24200/500000], Loss_T: 0.119830, Loss_data: 0.015748, Loss_physics: 0.089895, Loss_IC: 0.014187, b_pred (real): 0.871(0.5)
# Epoch [24300/500000], Loss_T: 0.121131, Loss_data: 0.015458, Loss_physics: 0.093462, Loss_IC: 0.012212, b_pred (real): 0.871(0.5)
# Epoch [24400/500000], Loss_T: 0.116414, Loss_data: 0.015580, Loss_physics: 0.089362, Loss_IC: 0.011473, b_pred (real): 0.870(0.5)
# Epoch [24500/500000], Loss_T: 0.123790, Loss_data: 0.015572, Loss_physics: 0.093510, Loss_IC: 0.014708, b_pred (real): 0.868(0.5)
# Epoch [24600/500000], Loss_T: 0.117927, Loss_data: 0.015335, Loss_physics: 0.090533, Loss_IC: 0.012059, b_pred (real): 0.867(0.5)
# Epoch [24700/500000], Loss_T: 0.116914, Loss_data: 0.015161, Loss_physics: 0.092250, Loss_IC: 0.009503, b_pred (real): 0.867(0.5)
# Epoch [24800/500000], Loss_T: 0.115507, Loss_data: 0.015203, Loss_physics: 0.087448, Loss_IC: 0.012856, b_pred (real): 0.865(0.5)
# Epoch [24900/500000], Loss_T: 0.130650, Loss_data: 0.015433, Loss_physics: 0.106098, Loss_IC: 0.009119, b_pred (real): 0.864(0.5)
# Epoch [25000/500000], Loss_T: 0.116994, Loss_data: 0.015347, Loss_physics: 0.086664, Loss_IC: 0.014982, b_pred (real): 0.862(0.5)
# Epoch [25100/500000], Loss_T: 0.117488, Loss_data: 0.015052, Loss_physics: 0.086508, Loss_IC: 0.015929, b_pred (real): 0.862(0.5)
# Epoch [25200/500000], Loss_T: 0.115635, Loss_data: 0.014889, Loss_physics: 0.080766, Loss_IC: 0.019980, b_pred (real): 0.860(0.5)
# Epoch [25300/500000], Loss_T: 0.114934, Loss_data: 0.015156, Loss_physics: 0.091970, Loss_IC: 0.007809, b_pred (real): 0.860(0.5)
# Epoch [25400/500000], Loss_T: 0.121365, Loss_data: 0.014848, Loss_physics: 0.090339, Loss_IC: 0.016178, b_pred (real): 0.859(0.5)
# Epoch [25500/500000], Loss_T: 0.114448, Loss_data: 0.014976, Loss_physics: 0.087565, Loss_IC: 0.011907, b_pred (real): 0.858(0.5)
# Epoch [25600/500000], Loss_T: 0.117728, Loss_data: 0.014837, Loss_physics: 0.088754, Loss_IC: 0.014137, b_pred (real): 0.858(0.5)
# Epoch [25700/500000], Loss_T: 0.119491, Loss_data: 0.015077, Loss_physics: 0.096160, Loss_IC: 0.008254, b_pred (real): 0.857(0.5)
# Epoch [25800/500000], Loss_T: 0.118578, Loss_data: 0.015080, Loss_physics: 0.097189, Loss_IC: 0.006309, b_pred (real): 0.856(0.5)
# Epoch [25900/500000], Loss_T: 0.113679, Loss_data: 0.014989, Loss_physics: 0.090587, Loss_IC: 0.008103, b_pred (real): 0.855(0.5)
# Epoch [26000/500000], Loss_T: 0.118799, Loss_data: 0.014650, Loss_physics: 0.092627, Loss_IC: 0.011523, b_pred (real): 0.855(0.5)
# Epoch [26100/500000], Loss_T: 0.112352, Loss_data: 0.014809, Loss_physics: 0.090273, Loss_IC: 0.007270, b_pred (real): 0.854(0.5)
# Epoch [26200/500000], Loss_T: 0.112866, Loss_data: 0.014621, Loss_physics: 0.084103, Loss_IC: 0.014142, b_pred (real): 0.853(0.5)
# Epoch [26300/500000], Loss_T: 0.117310, Loss_data: 0.014831, Loss_physics: 0.094993, Loss_IC: 0.007486, b_pred (real): 0.853(0.5)
# Epoch [26400/500000], Loss_T: 0.116247, Loss_data: 0.014269, Loss_physics: 0.085842, Loss_IC: 0.016136, b_pred (real): 0.852(0.5)
# Epoch [26500/500000], Loss_T: 0.121058, Loss_data: 0.014543, Loss_physics: 0.090625, Loss_IC: 0.015889, b_pred (real): 0.851(0.5)
# Epoch [26600/500000], Loss_T: 0.112875, Loss_data: 0.014622, Loss_physics: 0.086839, Loss_IC: 0.011413, b_pred (real): 0.850(0.5)
# Epoch [26700/500000], Loss_T: 0.112489, Loss_data: 0.014392, Loss_physics: 0.084287, Loss_IC: 0.013811, b_pred (real): 0.850(0.5)
# Epoch [26800/500000], Loss_T: 0.114949, Loss_data: 0.014026, Loss_physics: 0.080716, Loss_IC: 0.020206, b_pred (real): 0.849(0.5)
# Epoch [26900/500000], Loss_T: 0.112778, Loss_data: 0.014454, Loss_physics: 0.083760, Loss_IC: 0.014564, b_pred (real): 0.849(0.5)
# Epoch [27000/500000], Loss_T: 0.112025, Loss_data: 0.014017, Loss_physics: 0.081401, Loss_IC: 0.016608, b_pred (real): 0.849(0.5)
# Epoch [27100/500000], Loss_T: 0.127177, Loss_data: 0.013901, Loss_physics: 0.098559, Loss_IC: 0.014717, b_pred (real): 0.848(0.5)
# Epoch [27200/500000], Loss_T: 0.115347, Loss_data: 0.014091, Loss_physics: 0.087374, Loss_IC: 0.013882, b_pred (real): 0.848(0.5)
# Epoch [27300/500000], Loss_T: 0.116407, Loss_data: 0.013970, Loss_physics: 0.086471, Loss_IC: 0.015966, b_pred (real): 0.847(0.5)
# Epoch [27400/500000], Loss_T: 0.110759, Loss_data: 0.014101, Loss_physics: 0.083074, Loss_IC: 0.013584, b_pred (real): 0.846(0.5)
# Epoch [27500/500000], Loss_T: 0.113934, Loss_data: 0.013875, Loss_physics: 0.081190, Loss_IC: 0.018869, b_pred (real): 0.846(0.5)
# Epoch [27600/500000], Loss_T: 0.113975, Loss_data: 0.014331, Loss_physics: 0.085920, Loss_IC: 0.013723, b_pred (real): 0.845(0.5)
# Epoch [27700/500000], Loss_T: 0.116147, Loss_data: 0.014296, Loss_physics: 0.091618, Loss_IC: 0.010232, b_pred (real): 0.845(0.5)
# Epoch [27800/500000], Loss_T: 0.113309, Loss_data: 0.014169, Loss_physics: 0.086842, Loss_IC: 0.012298, b_pred (real): 0.845(0.5)
# Epoch [27900/500000], Loss_T: 0.111388, Loss_data: 0.014142, Loss_physics: 0.086237, Loss_IC: 0.011009, b_pred (real): 0.844(0.5)
# Epoch [28000/500000], Loss_T: 0.110581, Loss_data: 0.014413, Loss_physics: 0.083310, Loss_IC: 0.012857, b_pred (real): 0.844(0.5)
# Epoch [28100/500000], Loss_T: 0.112209, Loss_data: 0.014503, Loss_physics: 0.088796, Loss_IC: 0.008910, b_pred (real): 0.844(0.5)
# Epoch [28200/500000], Loss_T: 0.110388, Loss_data: 0.014007, Loss_physics: 0.082352, Loss_IC: 0.014029, b_pred (real): 0.843(0.5)
# Epoch [28300/500000], Loss_T: 0.117215, Loss_data: 0.014145, Loss_physics: 0.083878, Loss_IC: 0.019192, b_pred (real): 0.843(0.5)
# Epoch [28400/500000], Loss_T: 0.114258, Loss_data: 0.014216, Loss_physics: 0.091455, Loss_IC: 0.008588, b_pred (real): 0.843(0.5)
# Epoch [28500/500000], Loss_T: 0.110582, Loss_data: 0.014158, Loss_physics: 0.085721, Loss_IC: 0.010703, b_pred (real): 0.842(0.5)
# Epoch [28600/500000], Loss_T: 0.113909, Loss_data: 0.013534, Loss_physics: 0.085095, Loss_IC: 0.015281, b_pred (real): 0.843(0.5)
# Epoch [28700/500000], Loss_T: 0.111181, Loss_data: 0.014100, Loss_physics: 0.089239, Loss_IC: 0.007842, b_pred (real): 0.842(0.5)
# Epoch [28800/500000], Loss_T: 0.109691, Loss_data: 0.013911, Loss_physics: 0.084919, Loss_IC: 0.010861, b_pred (real): 0.841(0.5)
# Epoch [28900/500000], Loss_T: 0.112296, Loss_data: 0.014056, Loss_physics: 0.089975, Loss_IC: 0.008265, b_pred (real): 0.841(0.5)
# Epoch [29000/500000], Loss_T: 0.113384, Loss_data: 0.013644, Loss_physics: 0.083534, Loss_IC: 0.016206, b_pred (real): 0.841(0.5)
# Epoch [29100/500000], Loss_T: 0.130062, Loss_data: 0.013942, Loss_physics: 0.090296, Loss_IC: 0.025824, b_pred (real): 0.840(0.5)
# Epoch [29200/500000], Loss_T: 0.110247, Loss_data: 0.013952, Loss_physics: 0.083152, Loss_IC: 0.013143, b_pred (real): 0.840(0.5)
# Epoch [29300/500000], Loss_T: 0.117476, Loss_data: 0.013720, Loss_physics: 0.087176, Loss_IC: 0.016580, b_pred (real): 0.840(0.5)
# Epoch [29400/500000], Loss_T: 0.109483, Loss_data: 0.013755, Loss_physics: 0.088873, Loss_IC: 0.006856, b_pred (real): 0.840(0.5)
# Epoch [29500/500000], Loss_T: 0.114451, Loss_data: 0.014012, Loss_physics: 0.088010, Loss_IC: 0.012428, b_pred (real): 0.839(0.5)
# Epoch [29600/500000], Loss_T: 0.111038, Loss_data: 0.013784, Loss_physics: 0.080761, Loss_IC: 0.016493, b_pred (real): 0.839(0.5)
# Epoch [29700/500000], Loss_T: 0.111998, Loss_data: 0.013903, Loss_physics: 0.087904, Loss_IC: 0.010192, b_pred (real): 0.839(0.5)
# Epoch [29800/500000], Loss_T: 0.109650, Loss_data: 0.013787, Loss_physics: 0.083975, Loss_IC: 0.011888, b_pred (real): 0.839(0.5)
# Epoch [29900/500000], Loss_T: 0.110915, Loss_data: 0.013607, Loss_physics: 0.083454, Loss_IC: 0.013853, b_pred (real): 0.839(0.5)
# Epoch [30000/500000], Loss_T: 0.114071, Loss_data: 0.013649, Loss_physics: 0.085141, Loss_IC: 0.015281, b_pred (real): 0.838(0.5)
# Epoch [30100/500000], Loss_T: 0.113661, Loss_data: 0.013767, Loss_physics: 0.087996, Loss_IC: 0.011898, b_pred (real): 0.838(0.5)
# Epoch [30200/500000], Loss_T: 0.108083, Loss_data: 0.013929, Loss_physics: 0.083223, Loss_IC: 0.010931, b_pred (real): 0.838(0.5)
# Epoch [30300/500000], Loss_T: 0.108882, Loss_data: 0.013580, Loss_physics: 0.082672, Loss_IC: 0.012630, b_pred (real): 0.838(0.5)
# Epoch [30400/500000], Loss_T: 0.111299, Loss_data: 0.013847, Loss_physics: 0.090120, Loss_IC: 0.007333, b_pred (real): 0.838(0.5)
# Epoch [30500/500000], Loss_T: 0.107386, Loss_data: 0.013763, Loss_physics: 0.086333, Loss_IC: 0.007289, b_pred (real): 0.837(0.5)
# Epoch [30600/500000], Loss_T: 0.114634, Loss_data: 0.013818, Loss_physics: 0.092834, Loss_IC: 0.007981, b_pred (real): 0.837(0.5)
# Epoch [30700/500000], Loss_T: 0.107912, Loss_data: 0.013540, Loss_physics: 0.081003, Loss_IC: 0.013369, b_pred (real): 0.836(0.5)
# Epoch [30800/500000], Loss_T: 0.115691, Loss_data: 0.013490, Loss_physics: 0.080119, Loss_IC: 0.022082, b_pred (real): 0.836(0.5)
# Epoch [30900/500000], Loss_T: 0.110571, Loss_data: 0.013507, Loss_physics: 0.076023, Loss_IC: 0.021040, b_pred (real): 0.835(0.5)
# Epoch [31000/500000], Loss_T: 0.115476, Loss_data: 0.013246, Loss_physics: 0.082175, Loss_IC: 0.020055, b_pred (real): 0.835(0.5)
# Epoch [31100/500000], Loss_T: 0.115947, Loss_data: 0.013708, Loss_physics: 0.089477, Loss_IC: 0.012761, b_pred (real): 0.835(0.5)
# Epoch [31200/500000], Loss_T: 0.108749, Loss_data: 0.013697, Loss_physics: 0.086752, Loss_IC: 0.008299, b_pred (real): 0.835(0.5)
# Epoch [31300/500000], Loss_T: 0.110806, Loss_data: 0.013822, Loss_physics: 0.083993, Loss_IC: 0.012992, b_pred (real): 0.835(0.5)
# Epoch [31400/500000], Loss_T: 0.107533, Loss_data: 0.013735, Loss_physics: 0.080148, Loss_IC: 0.013650, b_pred (real): 0.835(0.5)
# Epoch [31500/500000], Loss_T: 0.112726, Loss_data: 0.013580, Loss_physics: 0.088003, Loss_IC: 0.011144, b_pred (real): 0.835(0.5)
# Epoch [31600/500000], Loss_T: 0.109374, Loss_data: 0.013918, Loss_physics: 0.081410, Loss_IC: 0.014046, b_pred (real): 0.834(0.5)
# Epoch [31700/500000], Loss_T: 0.113087, Loss_data: 0.013430, Loss_physics: 0.084421, Loss_IC: 0.015236, b_pred (real): 0.834(0.5)
# Epoch [31800/500000], Loss_T: 0.112372, Loss_data: 0.013612, Loss_physics: 0.088258, Loss_IC: 0.010501, b_pred (real): 0.834(0.5)
# Epoch [31900/500000], Loss_T: 0.108858, Loss_data: 0.013791, Loss_physics: 0.085260, Loss_IC: 0.009808, b_pred (real): 0.834(0.5)
# Epoch [32000/500000], Loss_T: 0.108036, Loss_data: 0.013789, Loss_physics: 0.085509, Loss_IC: 0.008738, b_pred (real): 0.833(0.5)
# Epoch [32100/500000], Loss_T: 0.108841, Loss_data: 0.013273, Loss_physics: 0.070430, Loss_IC: 0.025138, b_pred (real): 0.833(0.5)
# Epoch [32200/500000], Loss_T: 0.109012, Loss_data: 0.013521, Loss_physics: 0.084464, Loss_IC: 0.011027, b_pred (real): 0.833(0.5)
# Epoch [32300/500000], Loss_T: 0.110812, Loss_data: 0.013470, Loss_physics: 0.089299, Loss_IC: 0.008043, b_pred (real): 0.833(0.5)
# Epoch [32400/500000], Loss_T: 0.108766, Loss_data: 0.013480, Loss_physics: 0.083789, Loss_IC: 0.011497, b_pred (real): 0.833(0.5)
# Epoch [32500/500000], Loss_T: 0.108177, Loss_data: 0.013573, Loss_physics: 0.081952, Loss_IC: 0.012652, b_pred (real): 0.832(0.5)
# Epoch [32600/500000], Loss_T: 0.108903, Loss_data: 0.013260, Loss_physics: 0.086601, Loss_IC: 0.009042, b_pred (real): 0.832(0.5)
# Epoch [32700/500000], Loss_T: 0.115620, Loss_data: 0.013347, Loss_physics: 0.091925, Loss_IC: 0.010348, b_pred (real): 0.832(0.5)
# Epoch [32800/500000], Loss_T: 0.108099, Loss_data: 0.013533, Loss_physics: 0.083214, Loss_IC: 0.011353, b_pred (real): 0.832(0.5)
# Epoch [32900/500000], Loss_T: 0.107016, Loss_data: 0.013479, Loss_physics: 0.083227, Loss_IC: 0.010310, b_pred (real): 0.831(0.5)
# Epoch [33000/500000], Loss_T: 0.115808, Loss_data: 0.013367, Loss_physics: 0.089712, Loss_IC: 0.012729, b_pred (real): 0.831(0.5)
# Epoch [33100/500000], Loss_T: 0.109270, Loss_data: 0.013403, Loss_physics: 0.082492, Loss_IC: 0.013375, b_pred (real): 0.831(0.5)
# Epoch [33200/500000], Loss_T: 0.113628, Loss_data: 0.013221, Loss_physics: 0.084639, Loss_IC: 0.015768, b_pred (real): 0.831(0.5)
# Epoch [33300/500000], Loss_T: 0.115627, Loss_data: 0.013509, Loss_physics: 0.083738, Loss_IC: 0.018380, b_pred (real): 0.830(0.5)
# Epoch [33400/500000], Loss_T: 0.108336, Loss_data: 0.013156, Loss_physics: 0.081583, Loss_IC: 0.013598, b_pred (real): 0.831(0.5)
# Epoch [33500/500000], Loss_T: 0.108759, Loss_data: 0.013331, Loss_physics: 0.074936, Loss_IC: 0.020492, b_pred (real): 0.830(0.5)
# Epoch [33600/500000], Loss_T: 0.111332, Loss_data: 0.013062, Loss_physics: 0.081722, Loss_IC: 0.016548, b_pred (real): 0.830(0.5)
# Epoch [33700/500000], Loss_T: 0.106172, Loss_data: 0.013421, Loss_physics: 0.084033, Loss_IC: 0.008719, b_pred (real): 0.831(0.5)
# Epoch [33800/500000], Loss_T: 0.106987, Loss_data: 0.013497, Loss_physics: 0.082274, Loss_IC: 0.011216, b_pred (real): 0.830(0.5)
# Epoch [33900/500000], Loss_T: 0.106976, Loss_data: 0.013229, Loss_physics: 0.078294, Loss_IC: 0.015453, b_pred (real): 0.830(0.5)
# Epoch [34000/500000], Loss_T: 0.107396, Loss_data: 0.013487, Loss_physics: 0.082763, Loss_IC: 0.011146, b_pred (real): 0.829(0.5)
# Epoch [34100/500000], Loss_T: 0.110805, Loss_data: 0.013157, Loss_physics: 0.082069, Loss_IC: 0.015579, b_pred (real): 0.828(0.5)
# Epoch [34200/500000], Loss_T: 0.110437, Loss_data: 0.013022, Loss_physics: 0.080849, Loss_IC: 0.016566, b_pred (real): 0.829(0.5)
# Epoch [34300/500000], Loss_T: 0.110874, Loss_data: 0.013517, Loss_physics: 0.085914, Loss_IC: 0.011444, b_pred (real): 0.829(0.5)
# Epoch [34400/500000], Loss_T: 0.106387, Loss_data: 0.013052, Loss_physics: 0.078367, Loss_IC: 0.014968, b_pred (real): 0.829(0.5)
# Epoch [34500/500000], Loss_T: 0.109200, Loss_data: 0.013105, Loss_physics: 0.085342, Loss_IC: 0.010752, b_pred (real): 0.829(0.5)
# Epoch [34600/500000], Loss_T: 0.104931, Loss_data: 0.013387, Loss_physics: 0.077458, Loss_IC: 0.014087, b_pred (real): 0.828(0.5)
# Epoch [34700/500000], Loss_T: 0.112840, Loss_data: 0.013191, Loss_physics: 0.082979, Loss_IC: 0.016670, b_pred (real): 0.827(0.5)
# Epoch [34800/500000], Loss_T: 0.106531, Loss_data: 0.013288, Loss_physics: 0.085949, Loss_IC: 0.007294, b_pred (real): 0.828(0.5)
# Epoch [34900/500000], Loss_T: 0.105802, Loss_data: 0.013337, Loss_physics: 0.081677, Loss_IC: 0.010788, b_pred (real): 0.827(0.5)
# Epoch [35000/500000], Loss_T: 0.111381, Loss_data: 0.013348, Loss_physics: 0.084640, Loss_IC: 0.013393, b_pred (real): 0.828(0.5)
# Epoch [35100/500000], Loss_T: 0.107999, Loss_data: 0.012905, Loss_physics: 0.069353, Loss_IC: 0.025741, b_pred (real): 0.827(0.5)
# Epoch [35200/500000], Loss_T: 0.109587, Loss_data: 0.012865, Loss_physics: 0.079109, Loss_IC: 0.017613, b_pred (real): 0.827(0.5)
# Epoch [35300/500000], Loss_T: 0.104599, Loss_data: 0.013332, Loss_physics: 0.082103, Loss_IC: 0.009164, b_pred (real): 0.827(0.5)
# Epoch [35400/500000], Loss_T: 0.106986, Loss_data: 0.013519, Loss_physics: 0.086366, Loss_IC: 0.007101, b_pred (real): 0.827(0.5)
# Epoch [35500/500000], Loss_T: 0.105563, Loss_data: 0.013113, Loss_physics: 0.083078, Loss_IC: 0.009372, b_pred (real): 0.827(0.5)
# Epoch [35600/500000], Loss_T: 0.109182, Loss_data: 0.013228, Loss_physics: 0.080981, Loss_IC: 0.014972, b_pred (real): 0.827(0.5)
# Epoch [35700/500000], Loss_T: 0.105851, Loss_data: 0.012890, Loss_physics: 0.076691, Loss_IC: 0.016271, b_pred (real): 0.827(0.5)
# Epoch [35800/500000], Loss_T: 0.106677, Loss_data: 0.012957, Loss_physics: 0.078045, Loss_IC: 0.015675, b_pred (real): 0.827(0.5)
# Epoch [35900/500000], Loss_T: 0.107111, Loss_data: 0.013041, Loss_physics: 0.080037, Loss_IC: 0.014033, b_pred (real): 0.826(0.5)
# Epoch [36000/500000], Loss_T: 0.108030, Loss_data: 0.013366, Loss_physics: 0.081662, Loss_IC: 0.013002, b_pred (real): 0.826(0.5)
# Epoch [36100/500000], Loss_T: 0.105511, Loss_data: 0.013126, Loss_physics: 0.082058, Loss_IC: 0.010327, b_pred (real): 0.826(0.5)
# Epoch [36200/500000], Loss_T: 0.104972, Loss_data: 0.013087, Loss_physics: 0.083198, Loss_IC: 0.008687, b_pred (real): 0.826(0.5)
# Epoch [36300/500000], Loss_T: 0.111151, Loss_data: 0.013184, Loss_physics: 0.081836, Loss_IC: 0.016130, b_pred (real): 0.825(0.5)
# Epoch [36400/500000], Loss_T: 0.109695, Loss_data: 0.013228, Loss_physics: 0.083832, Loss_IC: 0.012636, b_pred (real): 0.825(0.5)
# Epoch [36500/500000], Loss_T: 0.104339, Loss_data: 0.013299, Loss_physics: 0.085412, Loss_IC: 0.005628, b_pred (real): 0.825(0.5)
# Epoch [36600/500000], Loss_T: 0.108294, Loss_data: 0.012771, Loss_physics: 0.081512, Loss_IC: 0.014011, b_pred (real): 0.825(0.5)
# Epoch [36700/500000], Loss_T: 0.133384, Loss_data: 0.012821, Loss_physics: 0.095128, Loss_IC: 0.025434, b_pred (real): 0.824(0.5)
# Epoch [36800/500000], Loss_T: 0.103381, Loss_data: 0.013063, Loss_physics: 0.076839, Loss_IC: 0.013479, b_pred (real): 0.824(0.5)
# Epoch [36900/500000], Loss_T: 0.104657, Loss_data: 0.013224, Loss_physics: 0.084418, Loss_IC: 0.007015, b_pred (real): 0.824(0.5)
# ...
# Epoch [487800/500000], Loss_T: 0.033147, Loss_data: 0.000347, Loss_physics: 0.029996, Loss_IC: 0.002804, b_pred (real): 0.496(0.5)
# Epoch [487900/500000], Loss_T: 0.033973, Loss_data: 0.000320, Loss_physics: 0.026353, Loss_IC: 0.007301, b_pred (real): 0.496(0.5)
# Epoch [488000/500000], Loss_T: 0.033651, Loss_data: 0.000348, Loss_physics: 0.027847, Loss_IC: 0.005455, b_pred (real): 0.496(0.5)
# Epoch [488100/500000], Loss_T: 0.037240, Loss_data: 0.000426, Loss_physics: 0.024494, Loss_IC: 0.012321, b_pred (real): 0.496(0.5)
# Epoch [488200/500000], Loss_T: 0.034699, Loss_data: 0.000312, Loss_physics: 0.025782, Loss_IC: 0.008606, b_pred (real): 0.496(0.5)
# Epoch [488300/500000], Loss_T: 0.032396, Loss_data: 0.000424, Loss_physics: 0.025497, Loss_IC: 0.006474, b_pred (real): 0.496(0.5)
# Epoch [488400/500000], Loss_T: 0.033499, Loss_data: 0.000325, Loss_physics: 0.022672, Loss_IC: 0.010503, b_pred (real): 0.496(0.5)
# Epoch [488500/500000], Loss_T: 0.033963, Loss_data: 0.000334, Loss_physics: 0.024532, Loss_IC: 0.009096, b_pred (real): 0.496(0.5)
# Epoch [488600/500000], Loss_T: 0.034153, Loss_data: 0.000319, Loss_physics: 0.022144, Loss_IC: 0.011690, b_pred (real): 0.496(0.5)
# Epoch [488700/500000], Loss_T: 0.033704, Loss_data: 0.000404, Loss_physics: 0.027648, Loss_IC: 0.005651, b_pred (real): 0.496(0.5)
# Epoch [488800/500000], Loss_T: 0.033335, Loss_data: 0.000419, Loss_physics: 0.025418, Loss_IC: 0.007497, b_pred (real): 0.496(0.5)
# Epoch [488900/500000], Loss_T: 0.032370, Loss_data: 0.000381, Loss_physics: 0.025439, Loss_IC: 0.006550, b_pred (real): 0.496(0.5)
# Epoch [489000/500000], Loss_T: 0.037637, Loss_data: 0.000343, Loss_physics: 0.028203, Loss_IC: 0.009091, b_pred (real): 0.496(0.5)
# Epoch [489100/500000], Loss_T: 0.035676, Loss_data: 0.000353, Loss_physics: 0.025055, Loss_IC: 0.010268, b_pred (real): 0.496(0.5)
# Epoch [489200/500000], Loss_T: 0.033957, Loss_data: 0.000325, Loss_physics: 0.023839, Loss_IC: 0.009794, b_pred (real): 0.496(0.5)
# Epoch [489300/500000], Loss_T: 0.035558, Loss_data: 0.000409, Loss_physics: 0.030004, Loss_IC: 0.005145, b_pred (real): 0.496(0.5)
# Epoch [489400/500000], Loss_T: 0.032617, Loss_data: 0.000337, Loss_physics: 0.023087, Loss_IC: 0.009193, b_pred (real): 0.496(0.5)
# Epoch [489500/500000], Loss_T: 0.033348, Loss_data: 0.000338, Loss_physics: 0.029124, Loss_IC: 0.003885, b_pred (real): 0.496(0.5)
# Epoch [489600/500000], Loss_T: 0.033631, Loss_data: 0.000356, Loss_physics: 0.027079, Loss_IC: 0.006196, b_pred (real): 0.496(0.5)
# Epoch [489700/500000], Loss_T: 0.031875, Loss_data: 0.000346, Loss_physics: 0.025558, Loss_IC: 0.005971, b_pred (real): 0.496(0.5)
# Epoch [489800/500000], Loss_T: 0.034746, Loss_data: 0.000390, Loss_physics: 0.027126, Loss_IC: 0.007230, b_pred (real): 0.496(0.5)
# Epoch [489900/500000], Loss_T: 0.035995, Loss_data: 0.000418, Loss_physics: 0.027860, Loss_IC: 0.007716, b_pred (real): 0.496(0.5)
# Epoch [490000/500000], Loss_T: 0.033046, Loss_data: 0.000352, Loss_physics: 0.025227, Loss_IC: 0.007467, b_pred (real): 0.496(0.5)
# Epoch [490100/500000], Loss_T: 0.032848, Loss_data: 0.000327, Loss_physics: 0.023240, Loss_IC: 0.009281, b_pred (real): 0.496(0.5)
# Epoch [490200/500000], Loss_T: 0.038533, Loss_data: 0.000390, Loss_physics: 0.027251, Loss_IC: 0.010892, b_pred (real): 0.496(0.5)
# Epoch [490300/500000], Loss_T: 0.032499, Loss_data: 0.000317, Loss_physics: 0.023922, Loss_IC: 0.008260, b_pred (real): 0.496(0.5)
# Epoch [490400/500000], Loss_T: 0.031898, Loss_data: 0.000355, Loss_physics: 0.026670, Loss_IC: 0.004873, b_pred (real): 0.496(0.5)
# Epoch [490500/500000], Loss_T: 0.031506, Loss_data: 0.000386, Loss_physics: 0.026897, Loss_IC: 0.004223, b_pred (real): 0.496(0.5)
# Epoch [490600/500000], Loss_T: 0.038036, Loss_data: 0.000407, Loss_physics: 0.023383, Loss_IC: 0.014246, b_pred (real): 0.496(0.5)
# Epoch [490700/500000], Loss_T: 0.033802, Loss_data: 0.000397, Loss_physics: 0.029053, Loss_IC: 0.004352, b_pred (real): 0.496(0.5)
# Epoch [490800/500000], Loss_T: 0.032944, Loss_data: 0.000440, Loss_physics: 0.026230, Loss_IC: 0.006274, b_pred (real): 0.496(0.5)
# Epoch [490900/500000], Loss_T: 0.033011, Loss_data: 0.000391, Loss_physics: 0.024529, Loss_IC: 0.008091, b_pred (real): 0.496(0.5)
# Epoch [491000/500000], Loss_T: 0.032381, Loss_data: 0.000374, Loss_physics: 0.025608, Loss_IC: 0.006399, b_pred (real): 0.496(0.5)
# Epoch [491100/500000], Loss_T: 0.044535, Loss_data: 0.000330, Loss_physics: 0.030455, Loss_IC: 0.013750, b_pred (real): 0.496(0.5)
# Epoch [491200/500000], Loss_T: 0.032805, Loss_data: 0.000319, Loss_physics: 0.024947, Loss_IC: 0.007540, b_pred (real): 0.496(0.5)
# Epoch [491300/500000], Loss_T: 0.032866, Loss_data: 0.000349, Loss_physics: 0.022996, Loss_IC: 0.009522, b_pred (real): 0.496(0.5)
# Epoch [491400/500000], Loss_T: 0.035785, Loss_data: 0.000307, Loss_physics: 0.023244, Loss_IC: 0.012234, b_pred (real): 0.496(0.5)
# Epoch [491500/500000], Loss_T: 0.032800, Loss_data: 0.000363, Loss_physics: 0.026958, Loss_IC: 0.005478, b_pred (real): 0.496(0.5)
# Epoch [491600/500000], Loss_T: 0.032604, Loss_data: 0.000336, Loss_physics: 0.024227, Loss_IC: 0.008040, b_pred (real): 0.496(0.5)
# Epoch [491700/500000], Loss_T: 0.032124, Loss_data: 0.000390, Loss_physics: 0.025070, Loss_IC: 0.006664, b_pred (real): 0.496(0.5)
# Epoch [491800/500000], Loss_T: 0.033733, Loss_data: 0.000331, Loss_physics: 0.024108, Loss_IC: 0.009294, b_pred (real): 0.496(0.5)
# Epoch [491900/500000], Loss_T: 0.032972, Loss_data: 0.000438, Loss_physics: 0.030126, Loss_IC: 0.002408, b_pred (real): 0.496(0.5)
# Epoch [492000/500000], Loss_T: 0.035775, Loss_data: 0.000352, Loss_physics: 0.026682, Loss_IC: 0.008741, b_pred (real): 0.496(0.5)
# Epoch [492100/500000], Loss_T: 0.034000, Loss_data: 0.000432, Loss_physics: 0.028713, Loss_IC: 0.004856, b_pred (real): 0.496(0.5)
# Epoch [492200/500000], Loss_T: 0.032315, Loss_data: 0.000352, Loss_physics: 0.023013, Loss_IC: 0.008950, b_pred (real): 0.496(0.5)
# Epoch [492300/500000], Loss_T: 0.037982, Loss_data: 0.000374, Loss_physics: 0.027986, Loss_IC: 0.009622, b_pred (real): 0.496(0.5)
# Epoch [492400/500000], Loss_T: 0.032163, Loss_data: 0.000424, Loss_physics: 0.029516, Loss_IC: 0.002223, b_pred (real): 0.496(0.5)
# Epoch [492500/500000], Loss_T: 0.031911, Loss_data: 0.000344, Loss_physics: 0.026635, Loss_IC: 0.004932, b_pred (real): 0.496(0.5)
# Epoch [492600/500000], Loss_T: 0.034092, Loss_data: 0.000377, Loss_physics: 0.025152, Loss_IC: 0.008563, b_pred (real): 0.496(0.5)
# Epoch [492700/500000], Loss_T: 0.031970, Loss_data: 0.000398, Loss_physics: 0.026532, Loss_IC: 0.005040, b_pred (real): 0.496(0.5)
# Epoch [492800/500000], Loss_T: 0.036772, Loss_data: 0.000347, Loss_physics: 0.025713, Loss_IC: 0.010711, b_pred (real): 0.496(0.5)
# Epoch [492900/500000], Loss_T: 0.033284, Loss_data: 0.000378, Loss_physics: 0.027427, Loss_IC: 0.005479, b_pred (real): 0.496(0.5)
# Epoch [493000/500000], Loss_T: 0.032131, Loss_data: 0.000401, Loss_physics: 0.027390, Loss_IC: 0.004340, b_pred (real): 0.496(0.5)
# Epoch [493100/500000], Loss_T: 0.033118, Loss_data: 0.000362, Loss_physics: 0.024295, Loss_IC: 0.008461, b_pred (real): 0.496(0.5)
# Epoch [493200/500000], Loss_T: 0.032203, Loss_data: 0.000343, Loss_physics: 0.023240, Loss_IC: 0.008621, b_pred (real): 0.496(0.5)
# Epoch [493300/500000], Loss_T: 0.034137, Loss_data: 0.000335, Loss_physics: 0.024123, Loss_IC: 0.009678, b_pred (real): 0.496(0.5)
# Epoch [493400/500000], Loss_T: 0.035945, Loss_data: 0.000353, Loss_physics: 0.019331, Loss_IC: 0.016262, b_pred (real): 0.496(0.5)
# Epoch [493500/500000], Loss_T: 0.034546, Loss_data: 0.000311, Loss_physics: 0.025589, Loss_IC: 0.008646, b_pred (real): 0.495(0.5)
# Epoch [493600/500000], Loss_T: 0.033520, Loss_data: 0.000379, Loss_physics: 0.021575, Loss_IC: 0.011566, b_pred (real): 0.495(0.5)
# Epoch [493700/500000], Loss_T: 0.031972, Loss_data: 0.000341, Loss_physics: 0.026954, Loss_IC: 0.004677, b_pred (real): 0.496(0.5)
# Epoch [493800/500000], Loss_T: 0.032488, Loss_data: 0.000404, Loss_physics: 0.027978, Loss_IC: 0.004107, b_pred (real): 0.496(0.5)
# Epoch [493900/500000], Loss_T: 0.033498, Loss_data: 0.000330, Loss_physics: 0.024254, Loss_IC: 0.008915, b_pred (real): 0.495(0.5)
# Epoch [494000/500000], Loss_T: 0.033672, Loss_data: 0.000406, Loss_physics: 0.027994, Loss_IC: 0.005272, b_pred (real): 0.496(0.5)
# Epoch [494100/500000], Loss_T: 0.034426, Loss_data: 0.000410, Loss_physics: 0.026507, Loss_IC: 0.007509, b_pred (real): 0.496(0.5)
# Epoch [494200/500000], Loss_T: 0.034629, Loss_data: 0.000392, Loss_physics: 0.022815, Loss_IC: 0.011422, b_pred (real): 0.496(0.5)
# Epoch [494300/500000], Loss_T: 0.032934, Loss_data: 0.000339, Loss_physics: 0.024594, Loss_IC: 0.008002, b_pred (real): 0.496(0.5)
# Epoch [494400/500000], Loss_T: 0.032127, Loss_data: 0.000401, Loss_physics: 0.029553, Loss_IC: 0.002172, b_pred (real): 0.496(0.5)
# Epoch [494500/500000], Loss_T: 0.032399, Loss_data: 0.000359, Loss_physics: 0.028449, Loss_IC: 0.003592, b_pred (real): 0.496(0.5)
# Epoch [494600/500000], Loss_T: 0.034034, Loss_data: 0.000353, Loss_physics: 0.029730, Loss_IC: 0.003952, b_pred (real): 0.495(0.5)
# Epoch [494700/500000], Loss_T: 0.034442, Loss_data: 0.000366, Loss_physics: 0.025819, Loss_IC: 0.008256, b_pred (real): 0.496(0.5)
# Epoch [494800/500000], Loss_T: 0.037603, Loss_data: 0.000346, Loss_physics: 0.027534, Loss_IC: 0.009722, b_pred (real): 0.496(0.5)
# Epoch [494900/500000], Loss_T: 0.036638, Loss_data: 0.000328, Loss_physics: 0.030103, Loss_IC: 0.006206, b_pred (real): 0.496(0.5)
# Epoch [495000/500000], Loss_T: 0.032416, Loss_data: 0.000321, Loss_physics: 0.025795, Loss_IC: 0.006300, b_pred (real): 0.496(0.5)
# Epoch [495100/500000], Loss_T: 0.034658, Loss_data: 0.000405, Loss_physics: 0.026095, Loss_IC: 0.008158, b_pred (real): 0.496(0.5)
# Epoch [495200/500000], Loss_T: 0.033700, Loss_data: 0.000398, Loss_physics: 0.025589, Loss_IC: 0.007713, b_pred (real): 0.496(0.5)
# Epoch [495300/500000], Loss_T: 0.033034, Loss_data: 0.000366, Loss_physics: 0.029563, Loss_IC: 0.003105, b_pred (real): 0.496(0.5)
# Epoch [495400/500000], Loss_T: 0.034506, Loss_data: 0.000338, Loss_physics: 0.026572, Loss_IC: 0.007596, b_pred (real): 0.496(0.5)
# Epoch [495500/500000], Loss_T: 0.032375, Loss_data: 0.000342, Loss_physics: 0.023136, Loss_IC: 0.008896, b_pred (real): 0.495(0.5)
# Epoch [495600/500000], Loss_T: 0.033814, Loss_data: 0.000364, Loss_physics: 0.020379, Loss_IC: 0.013071, b_pred (real): 0.495(0.5)
# Epoch [495700/500000], Loss_T: 0.033374, Loss_data: 0.000329, Loss_physics: 0.026732, Loss_IC: 0.006313, b_pred (real): 0.496(0.5)
# Epoch [495800/500000], Loss_T: 0.031637, Loss_data: 0.000387, Loss_physics: 0.025782, Loss_IC: 0.005468, b_pred (real): 0.496(0.5)
# Epoch [495900/500000], Loss_T: 0.032825, Loss_data: 0.000369, Loss_physics: 0.026868, Loss_IC: 0.005589, b_pred (real): 0.496(0.5)
# Epoch [496000/500000], Loss_T: 0.032936, Loss_data: 0.000375, Loss_physics: 0.026425, Loss_IC: 0.006135, b_pred (real): 0.496(0.5)
# Epoch [496100/500000], Loss_T: 0.032454, Loss_data: 0.000362, Loss_physics: 0.023643, Loss_IC: 0.008448, b_pred (real): 0.495(0.5)
# Epoch [496200/500000], Loss_T: 0.034011, Loss_data: 0.000451, Loss_physics: 0.027830, Loss_IC: 0.005730, b_pred (real): 0.495(0.5)
# Epoch [496300/500000], Loss_T: 0.033736, Loss_data: 0.000365, Loss_physics: 0.027085, Loss_IC: 0.006286, b_pred (real): 0.495(0.5)
# Epoch [496400/500000], Loss_T: 0.035095, Loss_data: 0.000378, Loss_physics: 0.021443, Loss_IC: 0.013274, b_pred (real): 0.495(0.5)
# Epoch [496500/500000], Loss_T: 0.031628, Loss_data: 0.000390, Loss_physics: 0.027081, Loss_IC: 0.004158, b_pred (real): 0.496(0.5)
# Epoch [496600/500000], Loss_T: 0.034920, Loss_data: 0.000307, Loss_physics: 0.024655, Loss_IC: 0.009958, b_pred (real): 0.496(0.5)
# Epoch [496700/500000], Loss_T: 0.036193, Loss_data: 0.000373, Loss_physics: 0.022113, Loss_IC: 0.013707, b_pred (real): 0.496(0.5)
# Epoch [496800/500000], Loss_T: 0.033116, Loss_data: 0.000413, Loss_physics: 0.023461, Loss_IC: 0.009242, b_pred (real): 0.495(0.5)
# Epoch [496900/500000], Loss_T: 0.031703, Loss_data: 0.000375, Loss_physics: 0.025135, Loss_IC: 0.006192, b_pred (real): 0.496(0.5)
# Epoch [497000/500000], Loss_T: 0.032535, Loss_data: 0.000391, Loss_physics: 0.026628, Loss_IC: 0.005516, b_pred (real): 0.496(0.5)
# Epoch [497100/500000], Loss_T: 0.033288, Loss_data: 0.000332, Loss_physics: 0.029992, Loss_IC: 0.002964, b_pred (real): 0.496(0.5)
# Epoch [497200/500000], Loss_T: 0.032531, Loss_data: 0.000416, Loss_physics: 0.028328, Loss_IC: 0.003787, b_pred (real): 0.496(0.5)
# Epoch [497300/500000], Loss_T: 0.034407, Loss_data: 0.000345, Loss_physics: 0.030080, Loss_IC: 0.003982, b_pred (real): 0.496(0.5)
# Epoch [497400/500000], Loss_T: 0.031938, Loss_data: 0.000373, Loss_physics: 0.024951, Loss_IC: 0.006614, b_pred (real): 0.495(0.5)
# Epoch [497500/500000], Loss_T: 0.035334, Loss_data: 0.000292, Loss_physics: 0.025942, Loss_IC: 0.009100, b_pred (real): 0.496(0.5)
# Epoch [497600/500000], Loss_T: 0.032303, Loss_data: 0.000350, Loss_physics: 0.025507, Loss_IC: 0.006447, b_pred (real): 0.496(0.5)
# Epoch [497700/500000], Loss_T: 0.032294, Loss_data: 0.000365, Loss_physics: 0.027136, Loss_IC: 0.004793, b_pred (real): 0.496(0.5)
# Epoch [497800/500000], Loss_T: 0.031455, Loss_data: 0.000370, Loss_physics: 0.027536, Loss_IC: 0.003550, b_pred (real): 0.496(0.5)
# Epoch [497900/500000], Loss_T: 0.038115, Loss_data: 0.000298, Loss_physics: 0.032062, Loss_IC: 0.005755, b_pred (real): 0.496(0.5)
# Epoch [498000/500000], Loss_T: 0.032588, Loss_data: 0.000395, Loss_physics: 0.023999, Loss_IC: 0.008195, b_pred (real): 0.496(0.5)
# Epoch [498100/500000], Loss_T: 0.034051, Loss_data: 0.000342, Loss_physics: 0.026972, Loss_IC: 0.006737, b_pred (real): 0.496(0.5)
# Epoch [498200/500000], Loss_T: 0.032593, Loss_data: 0.000371, Loss_physics: 0.026701, Loss_IC: 0.005522, b_pred (real): 0.496(0.5)
# Epoch [498300/500000], Loss_T: 0.032932, Loss_data: 0.000324, Loss_physics: 0.025751, Loss_IC: 0.006857, b_pred (real): 0.496(0.5)
# Epoch [498400/500000], Loss_T: 0.031379, Loss_data: 0.000375, Loss_physics: 0.024518, Loss_IC: 0.006486, b_pred (real): 0.496(0.5)
# Epoch [498500/500000], Loss_T: 0.031845, Loss_data: 0.000371, Loss_physics: 0.022505, Loss_IC: 0.008969, b_pred (real): 0.496(0.5)
# Epoch [498600/500000], Loss_T: 0.033532, Loss_data: 0.000339, Loss_physics: 0.024209, Loss_IC: 0.008984, b_pred (real): 0.495(0.5)
# Epoch [498700/500000], Loss_T: 0.033333, Loss_data: 0.000383, Loss_physics: 0.027904, Loss_IC: 0.005046, b_pred (real): 0.496(0.5)
# Epoch [498800/500000], Loss_T: 0.034886, Loss_data: 0.000343, Loss_physics: 0.030924, Loss_IC: 0.003619, b_pred (real): 0.495(0.5)
# Epoch [498900/500000], Loss_T: 0.036725, Loss_data: 0.000412, Loss_physics: 0.023296, Loss_IC: 0.013017, b_pred (real): 0.495(0.5)
# Epoch [499000/500000], Loss_T: 0.037766, Loss_data: 0.000350, Loss_physics: 0.027880, Loss_IC: 0.009535, b_pred (real): 0.496(0.5)
# Epoch [499100/500000], Loss_T: 0.032674, Loss_data: 0.000375, Loss_physics: 0.024298, Loss_IC: 0.008001, b_pred (real): 0.496(0.5)
# Epoch [499200/500000], Loss_T: 0.032165, Loss_data: 0.000390, Loss_physics: 0.028672, Loss_IC: 0.003103, b_pred (real): 0.496(0.5)
# Epoch [499300/500000], Loss_T: 0.032437, Loss_data: 0.000389, Loss_physics: 0.025874, Loss_IC: 0.006174, b_pred (real): 0.496(0.5)
# Epoch [499400/500000], Loss_T: 0.033948, Loss_data: 0.000303, Loss_physics: 0.028545, Loss_IC: 0.005100, b_pred (real): 0.496(0.5)
# Epoch [499500/500000], Loss_T: 0.035824, Loss_data: 0.000404, Loss_physics: 0.029268, Loss_IC: 0.006152, b_pred (real): 0.496(0.5)
# Epoch [499600/500000], Loss_T: 0.034374, Loss_data: 0.000283, Loss_physics: 0.024423, Loss_IC: 0.009669, b_pred (real): 0.496(0.5)
# Epoch [499700/500000], Loss_T: 0.035382, Loss_data: 0.000369, Loss_physics: 0.028296, Loss_IC: 0.006717, b_pred (real): 0.496(0.5)
# Epoch [499800/500000], Loss_T: 0.031846, Loss_data: 0.000380, Loss_physics: 0.027902, Loss_IC: 0.003563, b_pred (real): 0.496(0.5)
# Epoch [499900/500000], Loss_T: 0.032094, Loss_data: 0.000344, Loss_physics: 0.024816, Loss_IC: 0.006935, b_pred (real): 0.496(0.5)

# %% [markdown]
# ## Evaluar resultados 📈

# %%
# Hacer predicciones
y_pred_adm = model_pinn_adm.dnn(X_test_adm).detach().numpy()

# Crear una figura con 2 subgráficos (1 fila, 3 columnas)
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# --- Gráfico 1: Predicción vs Real ---
axs[0].plot(X_test_adm[:, 0].numpy(), y_test_adm.numpy(), label='Real', linewidth=1.5, color = 'grey')
axs[0].plot(X_test_adm[:, 0].numpy(), y_pred_adm, label='Predicho', linewidth=1.5, color = 'blue')
axs[0].scatter(X_train_adm[:, 0], y_train_adm, color='orange', label='Puntos de evaluación', marker='o')
axs[0].scatter(X_train_phy_adm.detach().numpy(), np.zeros_like(X_collocation), color='red', label='Puntos de evaluación', marker= 'o')
axs[0].set_xlabel('Time (s)')
axs[0].set_ylabel('Displacement (m)')
axs[0].grid(True)
axs[0].set_title('Predicción de Desplazamiento')
axs[0].legend()

# --- Gráfico 2: Historial de pérdida ---
axs[1].semilogy(model_pinn_adm.loss_history["Total"], label='Loss', color='blue', linewidth=1.5)
axs[1].semilogy(model_pinn_adm.loss_history["Data"], label='Loss_data', color='red', linewidth=1.5)
axs[1].semilogy(model_pinn_adm.loss_history["Physics"], label='Loss_physics', color='green', linewidth=1.5)
axs[1].semilogy(model_pinn_adm.loss_history["IC"], label='Loss_IC', color='purple', linewidth=1.5)
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Loss')
axs[1].grid(True)
axs[1].set_title('Historial de Pérdida')
axs[1].legend()

# --- Grafico 3: Evolucion de b
axs[2].plot(model_pinn_adm.parameter_history["b"], label='b_pred', color='blue', linewidth=1.5)
# Grafica de b real
axs[2].plot(np.ones_like(model_pinn_adm.parameter_history["b"])*b, label='b_real', color='red', linewidth=1.5, linestyle = "dashed")
axs[2].set_xlabel('Epochs')
axs[2].set_ylabel('b')
axs[2].grid(True)
axs[2].set_title('Evolucion de b')
axs[2].legend()

# Ajustar diseño para evitar superposiciones
plt.tight_layout()

# Mostrar los gráficos
plt.show()
